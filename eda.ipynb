# %% [markdown]
# # Init

# %%
import pandas as pd
import numpy as np

seed = 18022004
np.random.seed(seed)

# %%
original_df = pd.read_parquet("official_original.parquet")
original_df
# Out:
#           id          fromLib                             toLib  \
# 0          0          ant:ant                org.apache.ant:ant
# 1          1          ant:ant                org.apache.ant:ant
# 2          2          ant:ant                org.apache.ant:ant
# 7          7          ant:ant                org.apache.ant:ant
# 8          8          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14329  14329  xstream:xstream  com.thoughtworks.xstream:xstream
# 14330  14330  xstream:xstream  com.thoughtworks.xstream:xstream
# 14331  14331  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                        repoName                                  fileName  \
# 0           bobmcwhirter_drools                                   pom.xml
# 1            wocommunity_wolips               woproject-ant-tasks/pom.xml
# 2                   teiid_teiid                                   pom.xml
# 7                 mulesoft_mule                        standalone/pom.xml
# 8                 mulesoft_mule          distributions/standalone/pom.xml
# ...                         ...                                       ...
# 14329  kiegroup_kogito-runtimes                       drools-core/pom.xml
# 14330        sakaiproject_sakai            gradebook/service/impl/pom.xml
# 14331        sakaiproject_sakai      gradebook/service/sakai-pack/pom.xml
# 14332            apache_shindig  1.0.x-incubating/java/social-api/pom.xml
# 14333            apache_shindig                  1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...
# 1      Using Ant 1.7.1 as dependency for woproject-an...
# 2                                 updating ant groupid\n
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...
# ...                                                  ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...      2010-10-20
# 1      Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 2                                 updating ant groupid\n      2009-01-19
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# ...                                                  ...             ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...      2007-08-25
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category     repoOwner    repoSplitName
# 0        2010-10-20         0  bobmcwhirter           drools
# 1        2008-09-06         0   wocommunity           wolips
# 2        2009-01-19         0         teiid            teiid
# 7        2012-05-29         0      mulesoft             mule
# 8        2012-05-29         0      mulesoft             mule
# ...             ...       ...           ...              ...
# 14329    2007-08-25        30      kiegroup  kogito-runtimes
# 14330    2007-01-30        30  sakaiproject            sakai
# 14331    2007-01-30        30  sakaiproject            sakai
# 14332    2009-01-12        30        apache          shindig
# 14333    2009-01-12        30        apache          shindig
#
# [13382 rows x 16 columns]

# %%
original_df["repoName"].nunique()
# Out:
# 1480

# %% [markdown]
# ## Insight about log test library

# %%
tolib_test_df = original_df[original_df["toLib"].str.contains("unit|test")]

tolib_test_df["repoName"].nunique()
# Out:
# 231

# %%
fromlib_test_df = original_df[original_df["fromLib"].str.contains("unit|test")]
fromlib_test_df["repoName"].nunique()
# Out:
# 260

# %%
tolib_test_df
# Out:
#           id                              fromLib  \
# 45        45                              ant:ant
# 731      731      com.google.android:android-test
# 1125    1125  com.jayway.restassured:rest-assured
# 1358    1358         com.sun.jersey:jersey-bundle
# 3084    3084                    httpunit:httpunit
# ...      ...                                  ...
# 14308  14308                      xmlunit:xmlunit
# 14309  14309                      xmlunit:xmlunit
# 14310  14310                      xmlunit:xmlunit
# 14311  14311                      xmlunit:xmlunit
# 14312  14312                      xmlunit:xmlunit
#
#                                                    toLib  \
# 45                              org.apache.ant:ant-junit
# 731           com.google.testing.compile:compile-testing
# 1125   org.glassfish.jersey.test-framework.providers:...
# 1358   org.glassfish.jersey.test-framework.providers:...
# 3084                   net.sourceforge.htmlunit:htmlunit
# ...                                                  ...
# 14308                         org.xmlunit:xmlunit-legacy
# 14309                         org.xmlunit:xmlunit-legacy
# 14310                         org.xmlunit:xmlunit-legacy
# 14311                         org.xmlunit:xmlunit-legacy
# 14312                         org.xmlunit:xmlunit-legacy
#
#                               repoName  \
# 45                  wocommunity_wolips
# 731                  hoko_hoko-android
# 1125       meridor_perspective-backend
# 1358   opensecuritycontroller_osc-core
# 3084                    apache_archiva
# ...                                ...
# 14308             opendaylight_netconf
# 14309             opendaylight_netconf
# 14310           opendaylight_yangtools
# 14311           opendaylight_yangtools
# 14312          opendaylight_controller
#
#                                                 fileName  \
# 45                           woproject-ant-tasks/pom.xml
# 731                                              pom.xml
# 1125                                             pom.xml
# 1358                                  osc-common/pom.xml
# 3084   archiva-modules/archiva-web/archiva-webdav/pom...
# ...                                                  ...
# 14308         netconf/netconf-notifications-impl/pom.xml
# 14309              netconf/sal-netconf-connector/pom.xml
# 14310                     yang/yang-model-export/pom.xml
# 14311                        yang/yang-data-impl/pom.xml
# 14312  opendaylight/md-sal/sal-clustering-commons/pom...
#
#                                     startCommit  \
# 45     1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 731    c59afec9c1d13c21c118373a5e972805a2db5649
# 1125   6595e1a76e4179f0cd732d65819c7902c4ac3c60
# 1358   1de6cb2c58551212d572f33f2cad36dc533c92b7
# 3084   4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                         ...
# 14308  652dada8b53d21c3eefb409b18365bbc29560afe
# 14309  652dada8b53d21c3eefb409b18365bbc29560afe
# 14310  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14311  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14312  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                       endCommit  \
# 45     1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 731    c59afec9c1d13c21c118373a5e972805a2db5649
# 1125   6595e1a76e4179f0cd732d65819c7902c4ac3c60
# 1358   1de6cb2c58551212d572f33f2cad36dc533c92b7
# 3084   4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                         ...
# 14308  652dada8b53d21c3eefb409b18365bbc29560afe
# 14309  652dada8b53d21c3eefb409b18365bbc29560afe
# 14310  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14311  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14312  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                       startCommitChanges  \
# 45     +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 731    +org.easytesting:fest-assert-core\n+com.square...
# 1125   +org.glassfish.jersey.test-framework.providers...
# 1358   +javax.ws.rs:javax.ws.rs-api\n+org.glassfish.j...
# 3084   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                  ...
# 14308      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14309      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14310      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14311      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14312      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                         endCommitChanges  \
# 45     +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 731    +org.easytesting:fest-assert-core\n+com.square...
# 1125   +org.glassfish.jersey.test-framework.providers...
# 1358   +javax.ws.rs:javax.ws.rs-api\n+org.glassfish.j...
# 3084   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                  ...
# 14308      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14309      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14310      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14311      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14312      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                       startCommitMessage  \
# 45     Using Ant 1.7.1 as dependency for woproject-an...
# 731            [Updated] Unit Testing with Robolectric\n
# 1125                           Switched to Jersey-test\n
# 1358                                 Jersey 2 changes.\n
# 3084   remove use of old httpunit library\n\ngit-svn-...
# ...                                                  ...
# 14308  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 14309  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 14310  Migrate to to newer xmlunit\n\nThis migrates t...
# 14311  Migrate to to newer xmlunit\n\nThis migrates t...
# 14312  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
#
#                                         endCommitMessage startCommitTime  \
# 45     Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 731            [Updated] Unit Testing with Robolectric\n      2015-03-11
# 1125                           Switched to Jersey-test\n      2015-05-15
# 1358                                 Jersey 2 changes.\n      2017-02-07
# 3084   remove use of old httpunit library\n\ngit-svn-...      2014-01-06
# ...                                                  ...             ...
# 14308  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 14309  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 14310  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 14311  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 14312  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-17
#
#       endCommitTime  Category               repoOwner        repoSplitName
# 45       2008-09-06         0             wocommunity               wolips
# 731      2015-03-11        24                    hoko         hoko-android
# 1125     2015-05-15        35                 meridor  perspective-backend
# 1358     2017-02-07        21  opensecuritycontroller             osc-core
# 3084     2014-01-06        28                  apache              archiva
# ...             ...       ...                     ...                  ...
# 14308    2018-08-20        43            opendaylight              netconf
# 14309    2018-08-20        43            opendaylight              netconf
# 14310    2018-08-17        43            opendaylight            yangtools
# 14311    2018-08-17        43            opendaylight            yangtools
# 14312    2018-08-17        43            opendaylight           controller
#
# [1383 rows x 16 columns]

# %%
fromlib_test_df
# Out:
#           id                          fromLib  \
# 731      731  com.google.android:android-test
# 732      732  com.google.android:android-test
# 733      733  com.google.android:android-test
# 3084    3084                httpunit:httpunit
# 3085    3085                httpunit:httpunit
# ...      ...                              ...
# 14308  14308                  xmlunit:xmlunit
# 14309  14309                  xmlunit:xmlunit
# 14310  14310                  xmlunit:xmlunit
# 14311  14311                  xmlunit:xmlunit
# 14312  14312                  xmlunit:xmlunit
#
#                                             toLib                 repoName  \
# 731    com.google.testing.compile:compile-testing        hoko_hoko-android
# 732                   org.robolectric:robolectric        hoko_hoko-android
# 733                   org.robolectric:robolectric             BUS-Team_bus
# 3084            net.sourceforge.htmlunit:htmlunit           apache_archiva
# 3085    org.apache.tomcat.embed:tomcat-embed-core           apache_archiva
# ...                                           ...                      ...
# 14308                  org.xmlunit:xmlunit-legacy     opendaylight_netconf
# 14309                  org.xmlunit:xmlunit-legacy     opendaylight_netconf
# 14310                  org.xmlunit:xmlunit-legacy   opendaylight_yangtools
# 14311                  org.xmlunit:xmlunit-legacy   opendaylight_yangtools
# 14312                  org.xmlunit:xmlunit-legacy  opendaylight_controller
#
#                                                 fileName  \
# 731                                              pom.xml
# 732                                              pom.xml
# 733                                      android/pom.xml
# 3084   archiva-modules/archiva-web/archiva-webdav/pom...
# 3085   archiva-modules/archiva-web/archiva-webdav/pom...
# ...                                                  ...
# 14308         netconf/netconf-notifications-impl/pom.xml
# 14309              netconf/sal-netconf-connector/pom.xml
# 14310                     yang/yang-model-export/pom.xml
# 14311                        yang/yang-data-impl/pom.xml
# 14312  opendaylight/md-sal/sal-clustering-commons/pom...
#
#                                     startCommit  \
# 731    c59afec9c1d13c21c118373a5e972805a2db5649
# 732    c59afec9c1d13c21c118373a5e972805a2db5649
# 733    cb50f8e47cbbf550e2421c9be86f14a96acfea2b
# 3084   4825f8eb88ef35ca265903515ae715014bb4d597
# 3085   4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                         ...
# 14308  652dada8b53d21c3eefb409b18365bbc29560afe
# 14309  652dada8b53d21c3eefb409b18365bbc29560afe
# 14310  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14311  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14312  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                       endCommit  \
# 731    c59afec9c1d13c21c118373a5e972805a2db5649
# 732    c59afec9c1d13c21c118373a5e972805a2db5649
# 733    cb50f8e47cbbf550e2421c9be86f14a96acfea2b
# 3084   4825f8eb88ef35ca265903515ae715014bb4d597
# 3085   4825f8eb88ef35ca265903515ae715014bb4d597
# ...                                         ...
# 14308  652dada8b53d21c3eefb409b18365bbc29560afe
# 14309  652dada8b53d21c3eefb409b18365bbc29560afe
# 14310  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14311  e1057eac909eb2b1968557a2d0ad4b8d631e1682
# 14312  e8c4d500b42c1b9b5d49b2f72a0c1cd9bcc42261
#
#                                       startCommitChanges  \
# 731    +org.easytesting:fest-assert-core\n+com.square...
# 732    +org.easytesting:fest-assert-core\n+com.square...
# 733    +org.roboguice:roboguice\n+org.robolectric:rob...
# 3084   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# 3085   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                  ...
# 14308      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14309      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14310      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14311      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14312      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                         endCommitChanges  \
# 731    +org.easytesting:fest-assert-core\n+com.square...
# 732    +org.easytesting:fest-assert-core\n+com.square...
# 733    +org.roboguice:roboguice\n+org.robolectric:rob...
# 3084   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# 3085   +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# ...                                                  ...
# 14308      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14309      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14310      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14311      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
# 14312      +org.xmlunit:xmlunit-legacy\n-xmlunit:xmlunit
#
#                                       startCommitMessage  \
# 731            [Updated] Unit Testing with Robolectric\n
# 732            [Updated] Unit Testing with Robolectric\n
# 733    Change architetype structure to a simple struc...
# 3084   remove use of old httpunit library\n\ngit-svn-...
# 3085   remove use of old httpunit library\n\ngit-svn-...
# ...                                                  ...
# 14308  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 14309  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
# 14310  Migrate to to newer xmlunit\n\nThis migrates t...
# 14311  Migrate to to newer xmlunit\n\nThis migrates t...
# 14312  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...
#
#                                         endCommitMessage startCommitTime  \
# 731            [Updated] Unit Testing with Robolectric\n      2015-03-11
# 732            [Updated] Unit Testing with Robolectric\n      2015-03-11
# 733    Change architetype structure to a simple struc...      2013-12-03
# 3084   remove use of old httpunit library\n\ngit-svn-...      2014-01-06
# 3085   remove use of old httpunit library\n\ngit-svn-...      2014-01-06
# ...                                                  ...             ...
# 14308  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 14309  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-20
# 14310  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 14311  Migrate to to newer xmlunit\n\nThis migrates t...      2018-08-17
# 14312  WIP: Neon MRI changes\n\nThis patch bumps:\n- ...      2018-08-17
#
#       endCommitTime  Category     repoOwner repoSplitName
# 731      2015-03-11        24          hoko  hoko-android
# 732      2015-03-11        24          hoko  hoko-android
# 733      2013-12-03        24      BUS-Team           bus
# 3084     2014-01-06        28        apache       archiva
# 3085     2014-01-06        28        apache       archiva
# ...             ...       ...           ...           ...
# 14308    2018-08-20        43  opendaylight       netconf
# 14309    2018-08-20        43  opendaylight       netconf
# 14310    2018-08-17        43  opendaylight     yangtools
# 14311    2018-08-17        43  opendaylight     yangtools
# 14312    2018-08-17        43  opendaylight    controller
#
# [1453 rows x 16 columns]

# %%
print(tolib_test_df.index)
# Out:
# Index([   45,   731,  1125,  1358,  3084,  3088,  3089,  3090,  3091,  3092,
#        ...
#        14303, 14304, 14305, 14306, 14307, 14308, 14309, 14310, 14311, 14312],
#       dtype='int64', length=1383)

# %%
print(fromlib_test_df.index)
# Out:
# Index([  731,   732,   733,  3084,  3085,  3086,  3087,  3088,  3089,  3090,
#        ...
#        14303, 14304, 14305, 14306, 14307, 14308, 14309, 14310, 14311, 14312],
#       dtype='int64', length=1453)

# %%
print(len(set(tolib_test_df.index).intersection(set(fromlib_test_df.index))))
print(len(set(tolib_test_df.index).union(set(fromlib_test_df.index))))
# Out:
# 1297
# 1539

# %%
1297 / len(tolib_test_df)
# Out:
# 0.9378163412870572

# %%
original_df[original_df["id"] == 3084].iloc[0]
# Out:
# id                                                                 3084
# fromLib                                               httpunit:httpunit
# toLib                                 net.sourceforge.htmlunit:htmlunit
# repoName                                                 apache_archiva
# fileName              archiva-modules/archiva-web/archiva-webdav/pom...
# startCommit                    4825f8eb88ef35ca265903515ae715014bb4d597
# endCommit                      4825f8eb88ef35ca265903515ae715014bb4d597
# startCommitChanges    +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# endCommitChanges      +org.apache.tomcat:tomcat-juli\n+xerces:xerces...
# startCommitMessage    remove use of old httpunit library\n\ngit-svn-...
# endCommitMessage      remove use of old httpunit library\n\ngit-svn-...
# startCommitTime                                              2014-01-06
# endCommitTime                                                2014-01-06
# Category                                                             28
# repoOwner                                                        apache
# repoSplitName                                                   archiva
# Name: 3084, dtype: object

# %%
i = 3084

print(original_df.loc[i, "fromLib"])
print(original_df.loc[i, "toLib"])
print(original_df.loc[i, "repoName"])
print(original_df.loc[i, "fileName"])
# Out:
# httpunit:httpunit
# net.sourceforge.htmlunit:htmlunit
# apache_archiva
# archiva-modules/archiva-web/archiva-webdav/pom.xml

# %%
i = 3085

print(original_df.loc[i, "fromLib"])
print(original_df.loc[i, "toLib"])
print(original_df.loc[i, "repoName"])
print(original_df.loc[i, "fileName"])
# Out:
# httpunit:httpunit
# org.apache.tomcat.embed:tomcat-embed-core
# apache_archiva
# archiva-modules/archiva-web/archiva-webdav/pom.xml

# %%
i = 3086

print(original_df.loc[i, "fromLib"])
print(original_df.loc[i, "toLib"])
print(original_df.loc[i, "repoName"])
print(original_df.loc[i, "fileName"])
# Out:
# httpunit:httpunit
# org.apache.tomcat.embed:tomcat-embed-logging-juli
# apache_archiva
# archiva-modules/archiva-web/archiva-webdav/pom.xml

# %%
i = 3087

print(original_df.loc[i, "fromLib"])
print(original_df.loc[i, "toLib"])
print(original_df.loc[i, "repoName"])
print(original_df.loc[i, "fileName"])
# Out:
# httpunit:httpunit
# org.apache.tomcat:tomcat-juli
# apache_archiva
# archiva-modules/archiva-web/archiva-webdav/pom.xml

# %%
i = 3088

print(original_df.loc[i, "fromLib"])
print(original_df.loc[i, "toLib"])
print(original_df.loc[i, "repoName"])
print(original_df.loc[i, "fileName"])
# Out:
# httpunit:httpunit
# org.httpunit:httpunit
# webx_citrus
# test/util/pom.xml

# %%
set(tolib_test_df.index) - set(fromlib_test_df.index)
# Out:
# {45,
#  1125,
#  1358,
#  3223,
#  3224,
#  3225,
#  4255,
#  4256,
#  4257,
#  4258,
#  4259,
#  4260,
#  4261,
#  4262,
#  4263,
#  4264,
#  4265,
#  4266,
#  4267,
#  4268,
#  4269,
#  4270,
#  4271,
#  4272,
#  4273,
#  4274,
#  4275,
#  4276,
#  4277,
#  4278,
#  4279,
#  4280,
#  4281,
#  6432,
#  9157,
#  9158,
#  9485,
#  9577,
#  9588,
#  9657,
#  9658,
#  9659,
#  9660,
#  9661,
#  9662,
#  9663,
#  9664,
#  9673,
#  9674,
#  9675,
#  9676,
#  9677,
#  9678,
#  9679,
#  9680,
#  9681,
#  9682,
#  9683,
#  9684,
#  9685,
#  9700,
#  9701,
#  9702,
#  9703,
#  9707,
#  10216,
#  10471,
#  10506,
#  10507,
#  10509,
#  10510,
#  10512,
#  10513,
#  10581,
#  10582,
#  10593,
#  10594,
#  10595,
#  11170,
#  11173,
#  11293,
#  13785,
#  13786,
#  13787,
#  13788,
#  13789}

# %%
set(fromlib_test_df.index) - set(tolib_test_df.index)
# Out:
# {732,
#  733,
#  3085,
#  3086,
#  3087,
#  3093,
#  5250,
#  5251,
#  5252,
#  5286,
#  9211,
#  9212,
#  9213,
#  9214,
#  9215,
#  9216,
#  9217,
#  9218,
#  9219,
#  9220,
#  9221,
#  9222,
#  9223,
#  9224,
#  9225,
#  9226,
#  9227,
#  9228,
#  9229,
#  9230,
#  9231,
#  9232,
#  9233,
#  9234,
#  9235,
#  9236,
#  9237,
#  9238,
#  9239,
#  9240,
#  9241,
#  9242,
#  9243,
#  9244,
#  9245,
#  9246,
#  9247,
#  9248,
#  9249,
#  9250,
#  9251,
#  9252,
#  9253,
#  9254,
#  9255,
#  9256,
#  9257,
#  9258,
#  9259,
#  9260,
#  9261,
#  9262,
#  9263,
#  9264,
#  9265,
#  9266,
#  9267,
#  9268,
#  9269,
#  9270,
#  9271,
#  9272,
#  9273,
#  9274,
#  9275,
#  9276,
#  9277,
#  9278,
#  9279,
#  9280,
#  9281,
#  9282,
#  9283,
#  9284,
#  9285,
#  9286,
#  9287,
#  9288,
#  9289,
#  9290,
#  9291,
#  9292,
#  9293,
#  9294,
#  9295,
#  9296,
#  9297,
#  9306,
#  9307,
#  9308,
#  9309,
#  9310,
#  9311,
#  9312,
#  9313,
#  9314,
#  9315,
#  9316,
#  9317,
#  9318,
#  9319,
#  9320,
#  9321,
#  9322,
#  9323,
#  9324,
#  9326,
#  9327,
#  9328,
#  9329,
#  9920,
#  10217,
#  10218,
#  10219,
#  10220,
#  10221,
#  10222,
#  10223,
#  10359,
#  10360,
#  10377,
#  10378,
#  10379,
#  10380,
#  10381,
#  10382,
#  11267,
#  11268,
#  11269,
#  11270,
#  11271,
#  11272,
#  11273,
#  11274,
#  11275,
#  11276,
#  11277,
#  11278,
#  11279,
#  11280,
#  11281,
#  11282,
#  11283,
#  11284,
#  11285,
#  11286}

# %%
i = 9158
print(original_df.loc[i, "fromLib"])
print(original_df.loc[i, "toLib"])
print(original_df.loc[i, "repoName"])
print(original_df.loc[i, "fileName"])
# Out:
# org.dom4j:dom4j
# org.xmlunit:xmlunit-matchers
# apache_maven-archetype
# archetype-common/pom.xml

# %% [markdown]
# ***Cases that fromLib has different function than toLib***
#
# - 1358
#
# com.sun.jersey:jersey-bundle
#
# org.glassfish.jersey.test-framework.providers:jersey-test-framework-provider-grizzly2
#
# opensecuritycontroller_osc-core
#
# osc-common/pom.xml
#
# - 45
# ant:ant
#
# org.apache.ant:ant-junit
#
# wocommunity_wolips
#
# woproject-ant-tasks/pom.xml
#
# - 3093
#
# httpunit:httpunit
#
# xerces:xercesImpl
#
# apache_archiva
#
# archiva-modules/archiva-web/archiva-webdav/pom.xml
#
# - 5286
#
# junit:junit
#
# org.springframework.boot:spring-boot-starter-web
#
# VIPJoey_doe
#
# mmc-dubbo-provider/pom.xml
#
# - 6432
#
# net.htmlparser.jericho:jericho-html
#
# net.sourceforge.htmlunit:htmlunit
#
# apache_cxf-fediz
#
# systests/tests/pom.xml
#
# - 9158
#
# org.dom4j:dom4j
#
# org.xmlunit:xmlunit-matchers
#
# apache_maven-archetype
#
# archetype-common/pom.xml

# %% [markdown]
# ***Testing framework that not has test|unit***
# com.jayway.restassured:rest-assured
#
# org.robolectric:robolectric
#
# io.rest-assured:rest-assured
#
# jmock:jmock
#
# org.mockito:mockito-core
#
# org.assertj:assertj-core

# %%
tolib_log_df = original_df[original_df["toLib"].str.contains("log|slf4j")]

tolib_log_df["repoName"].nunique()
# Out:
# 426

# %%
fromlib_log_df = original_df[original_df["toLib"].str.contains("log|slf4j")]

fromlib_log_df["repoName"].nunique()
# Out:
# 426

# %%
tolib_log_df
# Out:
#           id                                            fromLib  \
# 180      180                      ch.qos.logback:logback-access
# 181      181                      ch.qos.logback:logback-access
# 182      182                      ch.qos.logback:logback-access
# 183      183                      ch.qos.logback:logback-access
# 184      184                      ch.qos.logback:logback-access
# ...      ...                                                ...
# 13789  13789                             org.slf4j:slf4j-simple
# 13836  13836  org.springframework.boot:spring-boot-starter-l...
# 13837  13837  org.springframework.boot:spring-boot-starter-l...
# 13838  13838  org.springframework.boot:spring-boot-starter-l...
# 13839  13839  org.springframework.boot:spring-boot-starter-l...
#
#                                      toLib  \
# 180     org.apache.logging.log4j:log4j-api
# 181     org.apache.logging.log4j:log4j-api
# 182    org.apache.logging.log4j:log4j-core
# 183    org.apache.logging.log4j:log4j-core
# 184     org.apache.logging.log4j:log4j-jcl
# ...                                    ...
# 13789           org.spf4j:spf4j-slf4j-test
# 13836       ch.qos.logback:logback-classic
# 13837       ch.qos.logback:logback-classic
# 13838   org.apache.logging.log4j:log4j-api
# 13839      commons-logging:commons-logging
#
#                                      repoName  \
# 180               flipkart-incubator_Poseidon
# 181               flipkart-incubator_Poseidon
# 182               flipkart-incubator_Poseidon
# 183               flipkart-incubator_Poseidon
# 184               flipkart-incubator_Poseidon
# ...                                       ...
# 13789                        zolyfarkas_spf4j
# 13836               HotelsDotCom_circus-train
# 13837               HotelsDotCom_circus-train
# 13838                         eclipse_hawkbit
# 13839  spring-cloud_spring-cloud-cloudfoundry
#
#                                           fileName  \
# 180                                        pom.xml
# 181                              container/pom.xml
# 182                                        pom.xml
# 183                              container/pom.xml
# 184                                        pom.xml
# ...                                            ...
# 13789                            spf4j-zel/pom.xml
# 13836         circus-train-s3-mapreduce-cp/pom.xml
# 13837                    circus-train-core/pom.xml
# 13838         examples/hawkbit-example-app/pom.xml
# 13839  spring-cloud-cloudfoundry-discovery/pom.xml
#
#                                     startCommit  \
# 180    2552502ec262f35c76d95856dbdec902884a9567
# 181    2552502ec262f35c76d95856dbdec902884a9567
# 182    2552502ec262f35c76d95856dbdec902884a9567
# 183    2552502ec262f35c76d95856dbdec902884a9567
# 184    2552502ec262f35c76d95856dbdec902884a9567
# ...                                         ...
# 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
# 13836  407ec931245c21503c0f13216129b114e8b3bd35
# 13837  407ec931245c21503c0f13216129b114e8b3bd35
# 13838  9d6527a3e29567c0c0b55951121d1356a65d7a3b
# 13839  1a55cc1c716d7fca26adeddea5a70575ad60f005
#
#                                       endCommit  \
# 180    2552502ec262f35c76d95856dbdec902884a9567
# 181    2552502ec262f35c76d95856dbdec902884a9567
# 182    2552502ec262f35c76d95856dbdec902884a9567
# 183    2552502ec262f35c76d95856dbdec902884a9567
# 184    2552502ec262f35c76d95856dbdec902884a9567
# ...                                         ...
# 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
# 13836  407ec931245c21503c0f13216129b114e8b3bd35
# 13837  407ec931245c21503c0f13216129b114e8b3bd35
# 13838  9d6527a3e29567c0c0b55951121d1356a65d7a3b
# 13839  1a55cc1c716d7fca26adeddea5a70575ad60f005
#
#                                       startCommitChanges  \
# 180    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 181    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 182    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 183    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 184    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# ...                                                  ...
# 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 13836  +ch.qos.logback:logback-classic\n-org.springfr...
# 13837  +ch.qos.logback:logback-classic\n-org.springfr...
# 13838  +org.slf4j:jul-to-slf4j\n+org.slf4j:jcl-over-s...
# 13839  +commons-logging:commons-logging\n-org.springf...
#
#                                         endCommitChanges  \
# 180    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 181    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 182    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 183    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 184    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# ...                                                  ...
# 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 13836  +ch.qos.logback:logback-classic\n-org.springfr...
# 13837  +ch.qos.logback:logback-classic\n-org.springfr...
# 13838  +org.slf4j:jul-to-slf4j\n+org.slf4j:jcl-over-s...
# 13839  +commons-logging:commons-logging\n-org.springf...
#
#                                       startCommitMessage  \
# 180    Using Log4J over logback (for both access and ...
# 181    Using Log4J over logback (for both access and ...
# 182    Using Log4J over logback (for both access and ...
# 183    Using Log4J over logback (for both access and ...
# 184    Using Log4J over logback (for both access and ...
# ...                                                  ...
# 13789                 [add] new spf4j-slf4j-test module!
# 13836        attempt to use logback (work in progress)\n
# 13837        attempt to use logback (work in progress)\n
# 13838  Switched back to Boots default logger: logback...
# 13839                         Fix logging dependencies\n
#
#                                         endCommitMessage startCommitTime  \
# 180    Using Log4J over logback (for both access and ...      2016-09-01
# 181    Using Log4J over logback (for both access and ...      2016-09-01
# 182    Using Log4J over logback (for both access and ...      2016-09-01
# 183    Using Log4J over logback (for both access and ...      2016-09-01
# 184    Using Log4J over logback (for both access and ...      2016-09-01
# ...                                                  ...             ...
# 13789                 [add] new spf4j-slf4j-test module!      2018-01-22
# 13836        attempt to use logback (work in progress)\n      2018-01-09
# 13837        attempt to use logback (work in progress)\n      2018-01-09
# 13838  Switched back to Boots default logger: logback...      2016-05-18
# 13839                         Fix logging dependencies\n      2015-05-21
#
#       endCommitTime  Category           repoOwner              repoSplitName
# 180      2016-09-01        11  flipkart-incubator                   Poseidon
# 181      2016-09-01        11  flipkart-incubator                   Poseidon
# 182      2016-09-01        11  flipkart-incubator                   Poseidon
# 183      2016-09-01        11  flipkart-incubator                   Poseidon
# 184      2016-09-01        11  flipkart-incubator                   Poseidon
# ...             ...       ...                 ...                        ...
# 13789    2018-01-22        11          zolyfarkas                      spf4j
# 13836    2018-01-09        11        HotelsDotCom               circus-train
# 13837    2018-01-09        11        HotelsDotCom               circus-train
# 13838    2016-05-18        11             eclipse                    hawkbit
# 13839    2015-05-21        11        spring-cloud  spring-cloud-cloudfoundry
#
# [4023 rows x 16 columns]

# %%
fromlib_log_df
# Out:
#           id                                            fromLib  \
# 180      180                      ch.qos.logback:logback-access
# 181      181                      ch.qos.logback:logback-access
# 182      182                      ch.qos.logback:logback-access
# 183      183                      ch.qos.logback:logback-access
# 184      184                      ch.qos.logback:logback-access
# ...      ...                                                ...
# 13789  13789                             org.slf4j:slf4j-simple
# 13836  13836  org.springframework.boot:spring-boot-starter-l...
# 13837  13837  org.springframework.boot:spring-boot-starter-l...
# 13838  13838  org.springframework.boot:spring-boot-starter-l...
# 13839  13839  org.springframework.boot:spring-boot-starter-l...
#
#                                      toLib  \
# 180     org.apache.logging.log4j:log4j-api
# 181     org.apache.logging.log4j:log4j-api
# 182    org.apache.logging.log4j:log4j-core
# 183    org.apache.logging.log4j:log4j-core
# 184     org.apache.logging.log4j:log4j-jcl
# ...                                    ...
# 13789           org.spf4j:spf4j-slf4j-test
# 13836       ch.qos.logback:logback-classic
# 13837       ch.qos.logback:logback-classic
# 13838   org.apache.logging.log4j:log4j-api
# 13839      commons-logging:commons-logging
#
#                                      repoName  \
# 180               flipkart-incubator_Poseidon
# 181               flipkart-incubator_Poseidon
# 182               flipkart-incubator_Poseidon
# 183               flipkart-incubator_Poseidon
# 184               flipkart-incubator_Poseidon
# ...                                       ...
# 13789                        zolyfarkas_spf4j
# 13836               HotelsDotCom_circus-train
# 13837               HotelsDotCom_circus-train
# 13838                         eclipse_hawkbit
# 13839  spring-cloud_spring-cloud-cloudfoundry
#
#                                           fileName  \
# 180                                        pom.xml
# 181                              container/pom.xml
# 182                                        pom.xml
# 183                              container/pom.xml
# 184                                        pom.xml
# ...                                            ...
# 13789                            spf4j-zel/pom.xml
# 13836         circus-train-s3-mapreduce-cp/pom.xml
# 13837                    circus-train-core/pom.xml
# 13838         examples/hawkbit-example-app/pom.xml
# 13839  spring-cloud-cloudfoundry-discovery/pom.xml
#
#                                     startCommit  \
# 180    2552502ec262f35c76d95856dbdec902884a9567
# 181    2552502ec262f35c76d95856dbdec902884a9567
# 182    2552502ec262f35c76d95856dbdec902884a9567
# 183    2552502ec262f35c76d95856dbdec902884a9567
# 184    2552502ec262f35c76d95856dbdec902884a9567
# ...                                         ...
# 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
# 13836  407ec931245c21503c0f13216129b114e8b3bd35
# 13837  407ec931245c21503c0f13216129b114e8b3bd35
# 13838  9d6527a3e29567c0c0b55951121d1356a65d7a3b
# 13839  1a55cc1c716d7fca26adeddea5a70575ad60f005
#
#                                       endCommit  \
# 180    2552502ec262f35c76d95856dbdec902884a9567
# 181    2552502ec262f35c76d95856dbdec902884a9567
# 182    2552502ec262f35c76d95856dbdec902884a9567
# 183    2552502ec262f35c76d95856dbdec902884a9567
# 184    2552502ec262f35c76d95856dbdec902884a9567
# ...                                         ...
# 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
# 13836  407ec931245c21503c0f13216129b114e8b3bd35
# 13837  407ec931245c21503c0f13216129b114e8b3bd35
# 13838  9d6527a3e29567c0c0b55951121d1356a65d7a3b
# 13839  1a55cc1c716d7fca26adeddea5a70575ad60f005
#
#                                       startCommitChanges  \
# 180    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 181    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 182    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 183    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 184    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# ...                                                  ...
# 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 13836  +ch.qos.logback:logback-classic\n-org.springfr...
# 13837  +ch.qos.logback:logback-classic\n-org.springfr...
# 13838  +org.slf4j:jul-to-slf4j\n+org.slf4j:jcl-over-s...
# 13839  +commons-logging:commons-logging\n-org.springf...
#
#                                         endCommitChanges  \
# 180    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 181    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 182    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# 183    +org.apache.logging.log4j:log4j-core\n+org.apa...
# 184    +org.apache.logging.log4j:log4j-jcl\n+org.apac...
# ...                                                  ...
# 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# 13836  +ch.qos.logback:logback-classic\n-org.springfr...
# 13837  +ch.qos.logback:logback-classic\n-org.springfr...
# 13838  +org.slf4j:jul-to-slf4j\n+org.slf4j:jcl-over-s...
# 13839  +commons-logging:commons-logging\n-org.springf...
#
#                                       startCommitMessage  \
# 180    Using Log4J over logback (for both access and ...
# 181    Using Log4J over logback (for both access and ...
# 182    Using Log4J over logback (for both access and ...
# 183    Using Log4J over logback (for both access and ...
# 184    Using Log4J over logback (for both access and ...
# ...                                                  ...
# 13789                 [add] new spf4j-slf4j-test module!
# 13836        attempt to use logback (work in progress)\n
# 13837        attempt to use logback (work in progress)\n
# 13838  Switched back to Boots default logger: logback...
# 13839                         Fix logging dependencies\n
#
#                                         endCommitMessage startCommitTime  \
# 180    Using Log4J over logback (for both access and ...      2016-09-01
# 181    Using Log4J over logback (for both access and ...      2016-09-01
# 182    Using Log4J over logback (for both access and ...      2016-09-01
# 183    Using Log4J over logback (for both access and ...      2016-09-01
# 184    Using Log4J over logback (for both access and ...      2016-09-01
# ...                                                  ...             ...
# 13789                 [add] new spf4j-slf4j-test module!      2018-01-22
# 13836        attempt to use logback (work in progress)\n      2018-01-09
# 13837        attempt to use logback (work in progress)\n      2018-01-09
# 13838  Switched back to Boots default logger: logback...      2016-05-18
# 13839                         Fix logging dependencies\n      2015-05-21
#
#       endCommitTime  Category           repoOwner              repoSplitName
# 180      2016-09-01        11  flipkart-incubator                   Poseidon
# 181      2016-09-01        11  flipkart-incubator                   Poseidon
# 182      2016-09-01        11  flipkart-incubator                   Poseidon
# 183      2016-09-01        11  flipkart-incubator                   Poseidon
# 184      2016-09-01        11  flipkart-incubator                   Poseidon
# ...             ...       ...                 ...                        ...
# 13789    2018-01-22        11          zolyfarkas                      spf4j
# 13836    2018-01-09        11        HotelsDotCom               circus-train
# 13837    2018-01-09        11        HotelsDotCom               circus-train
# 13838    2016-05-18        11             eclipse                    hawkbit
# 13839    2015-05-21        11        spring-cloud  spring-cloud-cloudfoundry
#
# [4023 rows x 16 columns]

# %%
print(tolib_log_df.index)
print(fromlib_log_df.index)
# Out:
# Index([  180,   181,   182,   183,   184,   185,   186,   187,   188,   189,
#        ...
#        13784, 13785, 13786, 13787, 13788, 13789, 13836, 13837, 13838, 13839],
#       dtype='int64', length=4023)
# Index([  180,   181,   182,   183,   184,   185,   186,   187,   188,   189,
#        ...
#        13784, 13785, 13786, 13787, 13788, 13789, 13836, 13837, 13838, 13839],
#       dtype='int64', length=4023)

# %%
for lib in original_df["toLib"].sample(n=500):
    print(lib)
# Out:
# org.awaitility:awaitility
# log4j:log4j
# org.apache.logging.log4j:log4j-api
# org.postgresql:postgresql
# org.mockito:mockito-core
# com.fasterxml.jackson.core:jackson-core
# org.junit.platform:junit-platform-launcher
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-annotations
# org.kevoree:org.kevoree.log
# org.easytesting:fest-assert
# org.slf4j:slf4j-api
# org.glassfish.jersey.core:jersey-server
# org.apache.httpcomponents:httpclient
# org.apache.commons:commons-configuration2
# org.junit.jupiter:junit-jupiter-api
# com.sun.jersey:jersey-core
# org.eclipse.jetty:jetty-servlets
# org.mybatis:mybatis
# ch.qos.logback:logback-classic
# org.apache.commons:commons-collections4
# javax.ws.rs:javax.ws.rs-api
# org.mortbay.jetty:jetty
# org.eclipse.jetty:jetty-webapp
# org.apache.commons:commons-io
# log4j:log4j
# com.carrotsearch:hppc
# com.fasterxml.jackson.core:jackson-core
# com.jayway.restassured:rest-assured
# io.cucumber:cucumber-java
# com.fasterxml.jackson.core:jackson-annotations
# org.glassfish.jersey.core:jersey-client
# jakarta.enterprise:jakarta.enterprise.cdi-api
# com.github.spotbugs:spotbugs-annotations
# org.apache.logging.log4j:log4j-api
# io.netty:netty
# org.assertj:assertj-core
# com.fasterxml.jackson.core:jackson-core
# org.junit.jupiter:junit-jupiter-engine
# org.hsqldb:hsqldb
# org.mockito:mockito-core
# org.eclipse.jetty:jetty-util
# org.apache.commons:commons-lang3
# org.apache.logging.log4j:log4j-slf4j-impl
# org.mockito:mockito-core
# com.fasterxml.jackson.core:jackson-databind
# com.google.code.gson:gson
# ch.qos.logback:logback-classic
# org.apache.commons:commons-lang3
# org.junit.platform:junit-platform-launcher
# org.junit.vintage:junit-vintage-engine
# org.junit.jupiter:junit-jupiter-params
# jakarta.json:jakarta.json-api
# com.fasterxml.jackson.core:jackson-databind
# org.checkerframework:checker-qual
# org.apache.logging.log4j:log4j-api
# org.junit.jupiter:junit-jupiter-engine
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-databind
# org.postgresql:postgresql
# org.glassfish.jaxb:jaxb-runtime
# org.hibernate.validator:hibernate-validator
# com.fasterxml.jackson.core:jackson-annotations
# org.hsqldb:hsqldb
# asm:asm
# jakarta.json:jakarta.json-api
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-databind
# org.junit.vintage:junit-vintage-engine
# ch.qos.logback:logback-classic
# com.squareup.okhttp3:okhttp
# org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.0_spec
# org.apache.logging.log4j:log4j-slf4j-impl
# org.glassfish:javax.faces
# org.apache.geronimo.specs:geronimo-stax-api_1.0_spec
# org.slf4j:slf4j-simple
# org.glassfish.jersey.core:jersey-server
# com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider
# org.springframework:spring-context
# org.junit.platform:junit-platform-launcher
# org.hamcrest:hamcrest-all
# com.fasterxml.jackson.core:jackson-core
# org.junit.platform:junit-platform-runner
# com.fasterxml.jackson.core:jackson-databind
# com.fasterxml.jackson.core:jackson-core
# org.xmlunit:xmlunit-legacy
# org.slf4j:slf4j-api
# org.asynchttpclient:async-http-client
# org.junit.jupiter:junit-jupiter-engine
# org.postgresql:postgresql
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-databind
# org.slf4j:slf4j-api
# org.junit.vintage:junit-vintage-engine
# org.apache.logging.log4j:log4j-core
# jakarta.ws.rs:jakarta.ws.rs-api
# org.apache.logging.log4j:log4j-slf4j-impl
# log4j:log4j
# jakarta.ws.rs:jakarta.ws.rs-api
# org.slf4j:log4j-over-slf4j
# com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider
# com.101tec:zkclient
# org.testng:testng
# org.testng:testng
# org.apache.logging.log4j:log4j-core
# org.mockito:mockito-core
# jakarta.ws.rs:jakarta.ws.rs-api
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.logging.log4j:log4j-api
# org.apache.logging.log4j:log4j-core
# org.apache.logging.log4j:log4j-core
# org.apache.logging.log4j:log4j-1.2-api
# org.junit.platform:junit-platform-surefire-provider
# org.eclipse.jetty:jetty-util-ajax
# org.apache.logging.log4j:log4j-api
# org.junit.vintage:junit-vintage-engine
# org.glassfish.jersey.containers:jersey-container-servlet-core
# org.easymock:easymock
# org.junit.jupiter:junit-jupiter-engine
# com.google.collections:google-collections
# org.assertj:assertj-core
# org.eclipse.jetty:jetty-server
# jakarta.validation:jakarta.validation-api
# org.apache.logging.log4j:log4j-api
# org.apache.logging.log4j:log4j-core
# log4j:log4j
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-core
# org.apache.logging.log4j:log4j-api
# org.javassist:javassist
# com.fasterxml.jackson.datatype:jackson-datatype-guava
# org.apache.logging.log4j:log4j-core
# org.junit.jupiter:junit-jupiter-api
# com.fasterxml.jackson.core:jackson-databind
# ch.qos.logback:logback-classic
# jakarta.el:jakarta.el-api
# com.github.stephenc.findbugs:findbugs-annotations
# org.apache.logging.log4j:log4j-api
# javax.servlet.jsp:jsp-api
# org.slf4j:slf4j-api
# org.glassfish.jersey.media:jersey-media-multipart
# org.apache.logging.log4j:log4j-slf4j-impl
# jakarta.el:jakarta.el-api
# org.apache.logging.log4j:log4j-core
# org.glassfish.jersey.core:jersey-client
# org.junit.jupiter:junit-jupiter-api
# org.testng:testng
# com.fasterxml.jackson.dataformat:jackson-dataformat-yaml
# org.apache.httpcomponents:httpclient
# javax.servlet:javax.servlet-api
# com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider
# org.glassfish.jersey.core:jersey-client
# org.dom4j:dom4j
# com.fasterxml.jackson.core:jackson-databind
# org.junit.vintage:junit-vintage-engine
# org.apache.commons:commons-text
# org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.0_spec
# org.hsqldb:hsqldb
# com.fasterxml.jackson.datatype:jackson-datatype-joda
# org.junit.platform:junit-platform-runner
# org.junit.jupiter:junit-jupiter-engine
# org.jboss.logging:jboss-logging-annotations
# org.codehaus.castor:castor
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.velocity:velocity-tools
# com.googlecode.json-simple:json-simple
# org.eclipse.jetty.websocket:websocket-server
# org.apache.tomcat:tomcat-servlet-api
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-annotations
# com.fasterxml.jackson.core:jackson-annotations
# org.glassfish.jersey.core:jersey-server
# com.fasterxml.jackson.core:jackson-databind
# org.slf4j:slf4j-simple
# com.fasterxml.jackson.module:jackson-module-jaxb-annotations
# org.apache.logging.log4j:log4j-slf4j-impl
# jakarta.validation:jakarta.validation-api
# jakarta.servlet:jakarta.servlet-api
# commons-io:commons-io
# junit:junit
# ch.qos.logback:logback-classic
# io.dropwizard.metrics:metrics-ganglia
# ch.qos.logback:logback-classic
# org.junit.jupiter:junit-jupiter-api
# javax.cache:cache-api
# javax.servlet.jsp.jstl:jstl-api
# io.netty:netty-all
# jakarta.el:jakarta.el-api
# com.baomidou:mybatis-plus-boot-starter
# com.fasterxml.jackson:jackson-bom
# io.reactivex.rxjava2:rxjava
# jakarta.ws.rs:jakarta.ws.rs-api
# org.ow2.asm:asm
# javax.persistence:javax.persistence-api
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.logging.log4j:log4j-slf4j-impl
# org.junit.platform:junit-platform-runner
# jakarta.ws.rs:jakarta.ws.rs-api
# org.apache.logging.log4j:log4j-slf4j-impl
# org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.0_spec
# org.apache.logging.log4j:log4j-api
# org.checkerframework:checker-qual
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.logging.log4j:log4j-api
# org.junit.vintage:junit-vintage-engine
# io.cucumber:cucumber-java
# org.jline:jline
# org.wildfly:wildfly-arquillian-container-managed
# org.apache.logging.log4j:log4j-api
# org.apache.geronimo.specs:geronimo-jta_1.1_spec
# org.slf4j:slf4j-api
# com.fasterxml.jackson.core:jackson-annotations
# junit:junit
# postgresql:postgresql
# org.apache.logging.log4j:log4j-api
# org.apache.logging.log4j:log4j-api
# commons-io:commons-io
# log4j:log4j
# org.eclipse.jetty:jetty-util
# ch.qos.logback:logback-classic
# org.slf4j:slf4j-log4j12
# com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider
# com.rometools:rome
# org.apache.httpcomponents:httpclient
# org.glassfish.jersey.core:jersey-client
# com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider
# org.mockito:mockito-core
# org.apache.commons:commons-lang3
# org.asynchttpclient:async-http-client
# ch.qos.logback:logback-classic
# org.apache.logging.log4j:log4j-api
# org.hsqldb:hsqldb
# com.mchange:c3p0
# org.assertj:assertj-core
# io.lettuce:lettuce-core
# org.mortbay.jetty:jetty
# com.fasterxml.jackson.core:jackson-databind
# javax.servlet.jsp.jstl:jstl-api
# org.apache.ant:ant
# org.eclipse.jetty:jetty-jsp
# org.asynchttpclient:async-http-client
# org.apache.commons:commons-io
# org.apache.logging.log4j:log4j-core
# org.apache.logging.log4j:log4j-slf4j-impl
# org.junit.jupiter:junit-jupiter-engine
# com.fasterxml.jackson.core:jackson-databind
# org.javassist:javassist
# org.codehaus.woodstox:woodstox-core-asl
# org.jboss.spec.javax.el:jboss-el-api_2.2_spec
# junit:junit
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.logging.log4j:log4j-core
# org.glassfish.jersey.core:jersey-server
# org.slf4j:slf4j-api
# javax.xml.stream:stax-api
# org.apache.httpcomponents:httpclient
# org.mockito:mockito-core
# org.jline:jline-terminal
# com.google.protobuf:protobuf-java
# org.apache.logging.log4j:log4j-core
# org.apache.maven.resolver:maven-resolver-connector-basic
# mysql:mysql-connector-java
# org.junit.vintage:junit-vintage-engine
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-api
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-slf4j-impl
# com.fasterxml.jackson.core:jackson-annotations
# org.apache.logging.log4j:log4j-slf4j-impl
# org.junit.jupiter:junit-jupiter-engine
# org.iq80.snappy:snappy
# com.thoughtworks.xstream:xstream
# org.checkerframework:checker-qual
# org.eclipse.jetty:jetty-server
# com.tngtech.java:junit-dataprovider
# com.fasterxml.jackson.core:jackson-core
# org.apache.logging.log4j:log4j-slf4j-impl
# com.fasterxml.jackson.core:jackson-databind
# ch.qos.logback:logback-classic
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.logging.log4j:log4j-slf4j-impl
# org.glassfish.jersey.core:jersey-client
# org.hsqldb:hsqldb
# ch.qos.logback:logback-classic
# org.jboss.spec.javax.ws.rs:jboss-jaxrs-api_2.0_spec
# com.baomidou:mybatis-plus-generator
# com.fasterxml.jackson.core:jackson-databind
# com.fasterxml.jackson.module:jackson-module-jaxb-annotations
# org.sonatype.sisu:sisu-guice
# ch.qos.logback:logback-classic
# org.jboss.spec.javax.faces:jboss-jsf-api_2.1_spec
# org.junit.jupiter:junit-jupiter-api
# ch.qos.logback:logback-classic
# org.postgresql:postgresql
# ch.qos.logback:logback-classic
# ch.qos.logback:logback-classic
# org.junit.jupiter:junit-jupiter-api
# org.apache.logging.log4j:log4j-1.2-api
# org.apache.logging.log4j:log4j-core
# org.hamcrest:hamcrest-core
# jakarta.json:jakarta.json-api
# org.slf4j:slf4j-api
# org.junit.vintage:junit-vintage-engine
# org.eclipse.jetty:jetty-servlet
# org.apache.logging.log4j:log4j-slf4j-impl
# org.jboss.resteasy:resteasy-jackson2-provider
# org.apache.logging.log4j:log4j-core
# jakarta.el:jakarta.el-api
# com.fasterxml.jackson.core:jackson-core
# javax.servlet.jsp.jstl:jstl-api
# org.jclouds.driver:jclouds-sshj
# ch.qos.logback:logback-classic
# org.junit.vintage:junit-vintage-engine
# ch.qos.logback:logback-classic
# ch.qos.logback:logback-classic
# org.apache.commons:commons-lang3
# org.apache.johnzon:johnzon-jsonb
# jakarta.enterprise:jakarta.enterprise.cdi-api
# org.junit.jupiter:junit-jupiter-api
# com.fasterxml.jackson.core:jackson-annotations
# com.fasterxml.jackson.jaxrs:jackson-jaxrs-json-provider
# io.dropwizard.metrics:metrics-core
# ch.qos.logback:logback-classic
# io.cucumber:cucumber-java
# jakarta.ws.rs:jakarta.ws.rs-api
# org.glassfish.jersey.test-framework.providers:jersey-test-framework-provider-jetty
# org.mockito:mockito-core
# net.minidev:json-smart
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.tomcat.embed:tomcat-embed-core
# com.h2database:h2
# com.fasterxml.jackson.core:jackson-databind
# org.slf4j:slf4j-api
# javax.persistence:javax.persistence-api
# org.junit.platform:junit-platform-launcher
# org.apache.logging.log4j:log4j-slf4j-impl
# org.slf4j:jcl-over-slf4j
# org.apache.logging.log4j:log4j-core
# org.checkerframework:checker-qual
# org.apache.logging.log4j:log4j-api
# org.testng:testng
# com.fasterxml.jackson.core:jackson-databind
# org.mockito:mockito-core
# com.fasterxml.jackson.core:jackson-databind
# org.apache.atlas:atlas-hbase-client-shaded
# org.junit.jupiter:junit-jupiter-api
# ch.qos.logback:logback-classic
# org.junit.vintage:junit-vintage-engine
# com.fasterxml.jackson.core:jackson-core
# org.apache.logging.log4j:log4j-api
# jakarta.ws.rs:jakarta.ws.rs-api
# org.glassfish:javax.faces
# ch.qos.logback:logback-classic
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-core
# com.fasterxml.jackson.core:jackson-annotations
# org.slf4j:slf4j-simple
# commons-logging:commons-logging
# ch.qos.logback:logback-classic
# org.apache.logging.log4j:log4j-core
# ch.qos.logback:logback-core
# org.junit.platform:junit-platform-launcher
# org.jboss.resteasy:resteasy-jackson2-provider
# org.apache.logging.log4j:log4j-api
# com.fasterxml.jackson.core:jackson-core
# org.slf4j:slf4j-log4j12
# org.easymock:easymock
# org.apache.commons:commons-lang3
# org.apache.logging.log4j:log4j-slf4j-impl
# org.eclipse.jetty:jetty-util-ajax
# org.apache.logging.log4j:log4j-slf4j-impl
# ch.qos.logback:logback-core
# org.slf4j:slf4j-api
# org.apache.logging.log4j:log4j-api
# org.apache.logging.log4j:log4j-api
# com.fasterxml.jackson.core:jackson-annotations
# org.apache.logging.log4j:log4j-slf4j-impl
# org.glassfish.jersey.containers:jersey-container-grizzly2-http
# org.xmlunit:xmlunit-legacy
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-databind
# org.apache.logging.log4j:log4j-core
# com.sun.activation:javax.activation
# org.eclipse.jetty:jetty-util
# jakarta.enterprise:jakarta.enterprise.cdi-api
# org.mybatis.generator:mybatis-generator-core
# io.swagger.core.v3:swagger-annotations
# com.fasterxml.jackson.core:jackson-databind
# com.fasterxml.jackson.core:jackson-databind
# com.fasterxml.jackson.core:jackson-databind
# org.apache.commons:commons-lang3
# org.springframework.cloud:spring-cloud-starter-stream-rabbit
# com.fasterxml.jackson.core:jackson-core
# org.apache.commons:commons-lang3
# com.fasterxml.jackson.core:jackson-databind
# org.mozilla:rhino
# org.slf4j:slf4j-api
# org.glassfish.jaxb:jaxb-runtime
# org.junit.vintage:junit-vintage-engine
# org.apache.maven.resolver:maven-resolver-api
# org.spf4j:spf4j-slf4j-test
# org.glassfish.jaxb:jaxb-runtime
# org.slf4j:slf4j-api
# org.apache.logging.log4j:log4j-api
# org.apache.logging.log4j:log4j-api
# org.springframework.boot:spring-boot-starter-web
# ch.qos.logback:logback-classic
# org.junit.jupiter:junit-jupiter-engine
# org.testng:testng
# ch.qos.logback:logback-classic
# org.slf4j:slf4j-api
# org.glassfish:javax.el
# javax.xml.stream:stax-api
# org.apache.commons:commons-lang3
# org.apache.ant:ant
# jakarta.ws.rs:jakarta.ws.rs-api
# org.postgresql:postgresql
# org.postgresql:postgresql
# org.jmockit:jmockit
# io.reactivex.rxjava2:rxjava
# org.apache.commons:commons-lang3
# org.glassfish.jaxb:jaxb-runtime
# com.fasterxml.jackson.core:jackson-annotations
# com.google.dagger:dagger
# org.apache.logging.log4j:log4j-core
# log4j:log4j
# org.jboss.spec.javax.faces:jboss-jsf-api_2.2_spec
# jakarta.enterprise:jakarta.enterprise.cdi-api
# io.jsonwebtoken:jjwt
# com.fasterxml.jackson.core:jackson-databind
# org.apache.maven.resolver:maven-resolver-transport-wagon
# com.fasterxml.jackson.core:jackson-annotations
# com.fasterxml.jackson.core:jackson-databind
# org.mortbay.jetty:jetty
# com.fasterxml.jackson.core:jackson-core
# org.apache.logging.log4j:log4j-api
# javax.servlet.jsp.jstl:jstl-api
# com.fasterxml.jackson.core:jackson-databind
# org.apache.pdfbox:pdfbox
# org.testng:testng
# org.testng:testng
# org.junit.jupiter:junit-jupiter-api
# org.apache.atlas:atlas-hbase-server-shaded
# org.glassfish.jersey.core:jersey-server
# com.fasterxml.jackson.core:jackson-databind
# org.postgresql:postgresql
# org.slf4j:slf4j-log4j12
# org.glassfish:javax.faces
# javax.servlet.jsp.jstl:javax.servlet.jsp.jstl-api
# ch.qos.logback:logback-core
# org.apache.logging.log4j:log4j-1.2-api
# org.apache.logging.log4j:log4j-core
# org.apache.logging.log4j:log4j-api
# org.junit.vintage:junit-vintage-engine
# org.apache.logging.log4j:log4j-slf4j-impl
# ch.qos.logback:logback-classic
# junit:junit
# org.junit.jupiter:junit-jupiter-api
# com.fasterxml.jackson.core:jackson-core
# org.eclipse.jetty:jetty-util
# javax.ejb:javax.ejb-api
# org.apache.logging.log4j:log4j-slf4j-impl
# com.mchange:c3p0
# org.eclipse.jetty:jetty-jsp
# org.assertj:assertj-core
# org.apache.logging.log4j:log4j-slf4j-impl
# com.squareup.okhttp3:okhttp
# org.apache.logging.log4j:log4j-api
# org.slf4j:log4j-over-slf4j
# ch.qos.logback:logback-core
# org.jmock:jmock-junit4
# javax.xml.stream:stax-api
# org.apache.logging.log4j:log4j-core
# org.jboss.logging:jboss-logging
# org.eclipse.jetty.aggregate:jetty-all-server
# org.apache.logging.log4j:log4j-slf4j-impl
# org.apache.logging.log4j:log4j-api
# org.eclipse.jetty:jetty-server
# org.eclipse.jetty:jetty-server
# com.fasterxml.jackson.core:jackson-core
# org.apache.commons:commons-lang3
# org.apache.hbase.thirdparty:hbase-shaded-netty
# org.glassfish.jersey.containers:jersey-container-servlet
# io.airlift:log
# org.junit.jupiter:junit-jupiter-migrationsupport
# io.dropwizard.metrics:metrics-core
# org.junit.jupiter:junit-jupiter-migrationsupport
# com.opencsv:opencsv
# com.fasterxml.jackson.core:jackson-databind
# org.hsqldb:hsqldb
# org.junit.jupiter:junit-jupiter-api
# javax.persistence:javax.persistence-api
# javax.persistence:javax.persistence-api
# org.junit.vintage:junit-vintage-engine
# org.hamcrest:hamcrest-core
# org.apache.logging.log4j:log4j-core
# jakarta.enterprise:jakarta.enterprise.cdi-api
# org.codehaus.groovy:groovy

# %%
hard_remove_log_test_repos = (
    set(original_df["repoName"].unique())
    - set(fromlib_log_df["repoName"].unique())
    - set(tolib_log_df["repoName"].unique())
    - set(fromlib_test_df["repoName"].unique())
    - set(tolib_test_df["repoName"].unique())
)
len(hard_remove_log_test_repos)
# Out:
# 844

# %%
# com.jayway.restassured:rest-assured
# org.robolectric:robolectric
# io.rest-assured:rest-assured
# jmock:jmock
# org.mockito:mockito-core
# org.assertj:assertj-core

# %%
fromlib_addition_test_df = original_df[
    original_df["fromLib"].str.contains("rest-assured|robolectric|mock|assert")
]
fromlib_addition_test_df
# Out:
#           id                                fromLib  \
# 982      982         com.googlecode.jmockit:jmockit
# 983      983         com.googlecode.jmockit:jmockit
# 984      984         com.googlecode.jmockit:jmockit
# 985      985         com.googlecode.jmockit:jmockit
# 986      986         com.googlecode.jmockit:jmockit
# ...      ...                                    ...
# 11285  11285  org.powermock:powermock-module-junit4
# 11286  11286  org.powermock:powermock-module-junit4
# 11287  11287  org.powermock:powermock-module-junit4
# 11288  11288  org.powermock:powermock-module-junit4
# 11289  11289  org.powermock:powermock-module-junit4
#
#                                                    toLib  \
# 982                                  org.jmockit:jmockit
# 983                                  org.jmockit:jmockit
# 984                                  org.jmockit:jmockit
# 985                                  org.jmockit:jmockit
# 986                                  org.jmockit:jmockit
# ...                                                  ...
# 11285                           org.mockito:mockito-core
# 11286                           org.mockito:mockito-core
# 11287  org.springframework.boot:spring-boot-starter-test
# 11288  org.springframework.boot:spring-boot-starter-test
# 11289  org.springframework.boot:spring-boot-starter-test
#
#                                    repoName  \
# 982                    RUB-NDS_TLS-Attacker
# 983                            apache_drill
# 984                           DSpace_DSpace
# 985                           DSpace_DSpace
# 986                        javaee_glassfish
# ...                                     ...
# 11285              bonitasoft_bonita-engine
# 11286  codecentric_chaos-monkey-spring-boot
# 11287                         gazbert_bxbot
# 11288                         gazbert_bxbot
# 11289                         gazbert_bxbot
#
#                                                 fileName  \
# 982                                              pom.xml
# 983                                              pom.xml
# 984                                              pom.xml
# 985                              dspace-services/pom.xml
# 986                                      nucleus/pom.xml
# ...                                                  ...
# 11285  bpm/bonita-core/bonita-parameter/bonita-parame...
# 11286                   chaos-monkey-spring-boot/pom.xml
# 11287                         bxbot-exchange-api/pom.xml
# 11288                          bxbot-trading-api/pom.xml
# 11289                       bxbot-domain-objects/pom.xml
#
#                                     startCommit  \
# 982    5c9d3ca9df2c61908d1f6bcce90df32bef3bf7a1
# 983    8fe8f2cc25fa183d36fcb06ed533ffc9e501322c
# 984    b810b99c89119f7338e168c0dffae50d822e06a7
# 985    b810b99c89119f7338e168c0dffae50d822e06a7
# 986    f010602d24f25aaa33fe1119d71ccfea2afecc2c
# ...                                         ...
# 11285  bb5bf02b270077645139dedcb064f27f92d6b740
# 11286  faf715e32ba8d87da9e14ff4154af2940627689b
# 11287  3c163531f279ffee3c66f2659ad20d6f464e9c86
# 11288  3c163531f279ffee3c66f2659ad20d6f464e9c86
# 11289  3c163531f279ffee3c66f2659ad20d6f464e9c86
#
#                                       endCommit  \
# 982    5c9d3ca9df2c61908d1f6bcce90df32bef3bf7a1
# 983    8fe8f2cc25fa183d36fcb06ed533ffc9e501322c
# 984    b810b99c89119f7338e168c0dffae50d822e06a7
# 985    b810b99c89119f7338e168c0dffae50d822e06a7
# 986    f010602d24f25aaa33fe1119d71ccfea2afecc2c
# ...                                         ...
# 11285  bb5bf02b270077645139dedcb064f27f92d6b740
# 11286  faf715e32ba8d87da9e14ff4154af2940627689b
# 11287  3c163531f279ffee3c66f2659ad20d6f464e9c86
# 11288  3c163531f279ffee3c66f2659ad20d6f464e9c86
# 11289  3c163531f279ffee3c66f2659ad20d6f464e9c86
#
#                                       startCommitChanges  \
# 982    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 983    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 984    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 985    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 986    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# ...                                                  ...
# 11285  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11286  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11287  +org.springframework.boot:spring-boot-starter-...
# 11288  +org.springframework.boot:spring-boot-starter-...
# 11289  +org.springframework.boot:spring-boot-starter-...
#
#                                         endCommitChanges  \
# 982    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 983    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 984    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 985    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# 986    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# ...                                                  ...
# 11285  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11286  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11287  +org.springframework.boot:spring-boot-starter-...
# 11288  +org.springframework.boot:spring-boot-starter-...
# 11289  +org.springframework.boot:spring-boot-starter-...
#
#                                       startCommitMessage  \
# 982    New jmockit and jacoco versions included, repo...
# 983       DRILL-6363: Upgrade jmockit and mockito libs\n
# 984           Upgrade to latest JUnit, JMockit and H2.\n
# 985           Upgrade to latest JUnit, JMockit and H2.\n
# 986                                   updating jmockit\n
# ...                                                  ...
# 11285  test(mockito): upgrade mockito to version 2 (#...
# 11286    Upgrade to mockito 2 and get rid of powermock\n
# 11287  Removed PowerMock dependency stack from projec...
# 11288  Removed PowerMock dependency stack from projec...
# 11289  Removed PowerMock dependency stack from projec...
#
#                                         endCommitMessage startCommitTime  \
# 982    New jmockit and jacoco versions included, repo...      2016-11-16
# 983       DRILL-6363: Upgrade jmockit and mockito libs\n      2018-05-12
# 984           Upgrade to latest JUnit, JMockit and H2.\n      2014-08-07
# 985           Upgrade to latest JUnit, JMockit and H2.\n      2014-08-07
# 986                                   updating jmockit\n      2017-10-27
# ...                                                  ...             ...
# 11285  test(mockito): upgrade mockito to version 2 (#...      2017-05-09
# 11286    Upgrade to mockito 2 and get rid of powermock\n      2019-08-08
# 11287  Removed PowerMock dependency stack from projec...      2017-09-09
# 11288  Removed PowerMock dependency stack from projec...      2017-09-09
# 11289  Removed PowerMock dependency stack from projec...      2017-09-09
#
#       endCommitTime  Category    repoOwner             repoSplitName
# 982      2016-11-16        29      RUB-NDS              TLS-Attacker
# 983      2018-05-12        29       apache                     drill
# 984      2014-08-07        29       DSpace                    DSpace
# 985      2014-08-07        29       DSpace                    DSpace
# 986      2017-10-27        29       javaee                 glassfish
# ...             ...       ...          ...                       ...
# 11285    2017-05-09        29   bonitasoft             bonita-engine
# 11286    2019-08-08        29  codecentric  chaos-monkey-spring-boot
# 11287    2017-09-09        29      gazbert                     bxbot
# 11288    2017-09-09        29      gazbert                     bxbot
# 11289    2017-09-09        29      gazbert                     bxbot
#
# [518 rows x 16 columns]

# %%
tolib_addition_test_df = original_df[
    original_df["toLib"].str.contains("rest-assured|robolectric|mock|assert")
]
tolib_addition_test_df
# Out:
#           id                                fromLib  \
# 730      730             com.google.android:android
# 732      732        com.google.android:android-test
# 733      733        com.google.android:android-test
# 981      981                 com.google.truth:truth
# 982      982         com.googlecode.jmockit:jmockit
# ...      ...                                    ...
# 11282  11282  org.powermock:powermock-module-junit4
# 11283  11283  org.powermock:powermock-module-junit4
# 11284  11284  org.powermock:powermock-module-junit4
# 11285  11285  org.powermock:powermock-module-junit4
# 11286  11286  org.powermock:powermock-module-junit4
#
#                              toLib                              repoName  \
# 730    org.robolectric:android-all             serso_android-messengerpp
# 732    org.robolectric:robolectric                     hoko_hoko-android
# 733    org.robolectric:robolectric                          BUS-Team_bus
# 981       org.assertj:assertj-core                      RyanSusana_elepy
# 982            org.jmockit:jmockit                  RUB-NDS_TLS-Attacker
# ...                            ...                                   ...
# 11282     org.mockito:mockito-core              bonitasoft_bonita-engine
# 11283     org.mockito:mockito-core              bonitasoft_bonita-engine
# 11284     org.mockito:mockito-core              bonitasoft_bonita-engine
# 11285     org.mockito:mockito-core              bonitasoft_bonita-engine
# 11286     org.mockito:mockito-core  codecentric_chaos-monkey-spring-boot
#
#                                                 fileName  \
# 730                                              pom.xml
# 732                                              pom.xml
# 733                                      android/pom.xml
# 981                                        tests/pom.xml
# 982                                              pom.xml
# ...                                                  ...
# 11282                   services/bonita-incident/pom.xml
# 11283                                            pom.xml
# 11284  services/bonita-scheduler/bonita-scheduler-imp...
# 11285  bpm/bonita-core/bonita-parameter/bonita-parame...
# 11286                   chaos-monkey-spring-boot/pom.xml
#
#                                     startCommit  \
# 730    d82e76b8ae0d90f59e0ce7a404855738fef6b3be
# 732    c59afec9c1d13c21c118373a5e972805a2db5649
# 733    cb50f8e47cbbf550e2421c9be86f14a96acfea2b
# 981    6d5a498a1c92d79a1816ada5a8703ad41bf0544c
# 982    5c9d3ca9df2c61908d1f6bcce90df32bef3bf7a1
# ...                                         ...
# 11282  bb5bf02b270077645139dedcb064f27f92d6b740
# 11283  bb5bf02b270077645139dedcb064f27f92d6b740
# 11284  bb5bf02b270077645139dedcb064f27f92d6b740
# 11285  bb5bf02b270077645139dedcb064f27f92d6b740
# 11286  faf715e32ba8d87da9e14ff4154af2940627689b
#
#                                       endCommit  \
# 730    d82e76b8ae0d90f59e0ce7a404855738fef6b3be
# 732    c59afec9c1d13c21c118373a5e972805a2db5649
# 733    cb50f8e47cbbf550e2421c9be86f14a96acfea2b
# 981    6d5a498a1c92d79a1816ada5a8703ad41bf0544c
# 982    5c9d3ca9df2c61908d1f6bcce90df32bef3bf7a1
# ...                                         ...
# 11282  bb5bf02b270077645139dedcb064f27f92d6b740
# 11283  bb5bf02b270077645139dedcb064f27f92d6b740
# 11284  bb5bf02b270077645139dedcb064f27f92d6b740
# 11285  bb5bf02b270077645139dedcb064f27f92d6b740
# 11286  faf715e32ba8d87da9e14ff4154af2940627689b
#
#                                       startCommitChanges  \
# 730    +org.robolectric:android-all\n+android:android...
# 732    +org.easytesting:fest-assert-core\n+com.square...
# 733    +org.roboguice:roboguice\n+org.robolectric:rob...
# 981    +org.assertj:assertj-core\n-com.google.truth:t...
# 982    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# ...                                                  ...
# 11282  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11283  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11284  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11285  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11286  +org.mockito:mockito-core\n-org.mockito:mockit...
#
#                                         endCommitChanges  \
# 730    +org.robolectric:android-all\n+android:android...
# 732    +org.easytesting:fest-assert-core\n+com.square...
# 733    +org.roboguice:roboguice\n+org.robolectric:rob...
# 981    +org.assertj:assertj-core\n-com.google.truth:t...
# 982    +org.jmockit:jmockit\n-com.googlecode.jmockit:...
# ...                                                  ...
# 11282  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11283  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11284  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11285  +org.mockito:mockito-core\n-org.mockito:mockit...
# 11286  +org.mockito:mockito-core\n-org.mockito:mockit...
#
#                                       startCommitMessage  \
# 730          Android SDK version upgraded, tests fixed\n
# 732            [Updated] Unit Testing with Robolectric\n
# 733    Change architetype structure to a simple struc...
# 981    (enhancement) switched from  Google Truth to A...
# 982    New jmockit and jacoco versions included, repo...
# ...                                                  ...
# 11282  test(mockito): upgrade mockito to version 2 (#...
# 11283  test(mockito): upgrade mockito to version 2 (#...
# 11284  test(mockito): upgrade mockito to version 2 (#...
# 11285  test(mockito): upgrade mockito to version 2 (#...
# 11286    Upgrade to mockito 2 and get rid of powermock\n
#
#                                         endCommitMessage startCommitTime  \
# 730          Android SDK version upgraded, tests fixed\n      2014-04-03
# 732            [Updated] Unit Testing with Robolectric\n      2015-03-11
# 733    Change architetype structure to a simple struc...      2013-12-03
# 981    (enhancement) switched from  Google Truth to A...      2019-11-12
# 982    New jmockit and jacoco versions included, repo...      2016-11-16
# ...                                                  ...             ...
# 11282  test(mockito): upgrade mockito to version 2 (#...      2017-05-09
# 11283  test(mockito): upgrade mockito to version 2 (#...      2017-05-09
# 11284  test(mockito): upgrade mockito to version 2 (#...      2017-05-09
# 11285  test(mockito): upgrade mockito to version 2 (#...      2017-05-09
# 11286    Upgrade to mockito 2 and get rid of powermock\n      2019-08-08
#
#       endCommitTime  Category    repoOwner             repoSplitName
# 730      2014-04-03        23        serso       android-messengerpp
# 732      2015-03-11        24         hoko              hoko-android
# 733      2013-12-03        24     BUS-Team                       bus
# 981      2019-11-12        29   RyanSusana                     elepy
# 982      2016-11-16        29      RUB-NDS              TLS-Attacker
# ...             ...       ...          ...                       ...
# 11282    2017-05-09        29   bonitasoft             bonita-engine
# 11283    2017-05-09        29   bonitasoft             bonita-engine
# 11284    2017-05-09        29   bonitasoft             bonita-engine
# 11285    2017-05-09        29   bonitasoft             bonita-engine
# 11286    2019-08-08        29  codecentric  chaos-monkey-spring-boot
#
# [525 rows x 16 columns]

# %%
hard_remove_log_test_repos = (
    hard_remove_log_test_repos
    - set(fromlib_addition_test_df["repoName"].unique())
    - set(tolib_addition_test_df["repoName"].unique())
)
print(len(hard_remove_log_test_repos))
# Out:
# 782

# %%
hard_remove_log_test_repos
# Out:
# {'1and1_cosmo',
#  '42BV_jarb',
#  '52North_SOS',
#  '52North_series-rest-api',
#  '55minutes_fiftyfive-wicket',
#  'Accenture_mercury',
#  'Alfresco_alfresco-sdk',
#  'AmyAssist_Amy',
#  'Appverse_appverse-web',
#  'ArtificerRepo_artificer',
#  'Asqatasun_Asqatasun',
#  'Atmosphere_nettosphere',
#  'AvanzaBank_astrix',
#  'Azure_autorest-clientruntime-for-java',
#  'Azure_azure-functions-java-worker',
#  'Azure_azure-sdk-for-java',
#  'BSC-RUS_AuTe-Framework',
#  'Bammerbom_UltimateCore',
#  'BatooOrg_BatooJPA',
#  'Blazebit_blaze-persistence',
#  'BorderTech_wcomponents',
#  'BroadleafCommerce_BroadleafCommerce',
#  'BrunoEberhard_minimal-j',
#  'BrynCooke_cdi-unit',
#  'BuycraftPlugin_BuycraftX',
#  'CCI-MIT_XCoLab',
#  'CUTR-at-USF_gtfs-realtime-validator',
#  'CenterForOpenScience_cas-overlay',
#  'ChargeTimeEU_Java-OCA-OCPP',
#  'ClearTK_cleartk',
#  'CloudSlang_score',
#  'Cloudname_cloudname',
#  'CloverETL_CloverETL-Engine',
#  'CodeSolid_tutorials',
#  'Cognifide_Slice',
#  'Consonance_consonance',
#  'CoreMedia_jangaroo-tools',
#  'Dempsy_dempsy',
#  'Diorite_Diorite',
#  'Dromara_hmily',
#  'DuanJiaNing_BlogSystem',
#  'EmiteGWT_emite',
#  'Erudika_para',
#  'EvidentSolutions_dalesbred',
#  'Exrick_xboot',
#  'Fabric3_fabric3-core',
#  'FasterXML_jackson-jaxrs-providers',
#  'FudanSELab_train-ticket',
#  'FundRequest_platform',
#  'GeneralElectric_snowizard',
#  'Geomatys_constellation',
#  'Geomatys_geotoolkit',
#  'GoogleCloudPlatform_cloud-bigtable-examples',
#  'GoogleContainerTools_jib',
#  'HPI-Information-Systems_Metanome',
#  'Hack23_cia',
#  'HeZiCong_Photo',
#  'HotelsDotCom_bull',
#  'HotelsDotCom_data-highway',
#  'HubSpot_Horizon',
#  'HubSpot_Singularity',
#  'IBMStreams_streamsx.messaging',
#  'Impetus_jumbune',
#  'InnovateUKGitHub_innovation-funding-service',
#  'Intel-bigdata_SSM',
#  'Internet2_grouper',
#  'IoT-Technology_Groza',
#  'JULIELab_jcore-base',
#  'Jahia_dxm',
#  'JakeWharton_ActionBarSherlock',
#  'JetBrains_teamcity-vmware-plugin',
#  'JoeCao_qbike',
#  'JumpMind_symmetric-ds',
#  'Kurento_kurento-java',
#  'KuroChan1998_Student-Information-Administration-System',
#  'LearnLib_learnlib',
#  'LibrePlan_libreplan',
#  'ManfredTremmel_gwt-bean-validators',
#  'Nepxion_Aquarius',
#  'Netcentric_accesscontroltool',
#  'NumberFour_n4js',
#  'ORCID_ORCID-Source',
#  'OfficeDev_ews-java-api',
#  'OpenAPITools_openapi-generator',
#  'OpenClinica_OpenClinica',
#  'OpenNMS_newts',
#  'OpenRock_OpenAM',
#  'OpenSextant_Xponents',
#  'OpenTOSCA_container',
#  'OpenWiseSolutions_openhub-framework',
#  'OryxProject_oryx',
#  'PantheonTechnologies_lighty-core',
#  'PerficientDigital_AEM-DataLayer',
#  'ProjectAGI_agi',
#  'RIPE-NCC_whois',
#  'RankSys_RankSys',
#  'Renanse_Ardor3D',
#  'RestComm_Restcomm-Connect',
#  'RestComm_jain-slee',
#  'RestComm_sip-servlets',
#  'RxGirlz_OpenYspider',
#  'ScaCap_spring-auto-restdocs',
#  'SeleniumHQ_selenium',
#  'SeqWare_seqware',
#  'SiGuiyang_spring-cloud-shop',
#  'SmartDataAnalytics_Sparqlify',
#  'SmartDataAnalytics_jena-sparql-api',
#  'Stratio_cassandra-lucene-index',
#  'Stratio_deep-spark',
#  'Tanaguru_Tanaguru',
#  'TechEmpower_FrameworkBenchmarks',
#  'TechnionYP5777_UpAndGo',
#  'TechzoneMC_SonarPet',
#  'Teradata_kylo',
#  'TexasDigitalLibrary_Vireo',
#  'Top-Q_jsystem',
#  'Transitime_core',
#  'US-CBP_GTAS',
#  'Unicon_cas-addons',
#  'VueGWT_vue-gwt',
#  'YahooArchive_oozie',
#  'YunaiV_onemall',
#  'Zubnix_trinityshell',
#  'a466350665_smart',
#  'actiontech_txle',
#  'adamkewley_jobson',
#  'adobe_S3Mock',
#  'adobe_aem-core-wcm-components',
#  'aerogear_aerogear-simplepush-server',
#  'aerogear_aerogear-unifiedpush-server',
#  'afimb_chouette',
#  'agilebirds_openflexo',
#  'ahars_spark-jhipster',
#  'alibaba_Sentinel',
#  'alibaba_canal',
#  'aliyun_alibabacloud-microservice-demo',
#  'aliyun_aliyun-openapi-java-sdk',
#  'aliyun_aliyun-oss-android-sdk',
#  'anno4j_anno4j',
#  'antlr_antlr4',
#  'apache_abdera',
#  'apache_ace',
#  'apache_activemq-artemis',
#  'apache_ambari',
#  'apache_ant',
#  'apache_aries',
#  'apache_atlas',
#  'apache_avro',
#  'apache_cloudstack',
#  'apache_cocoon',
#  'apache_commons-jcs',
#  'apache_curator',
#  'apache_directory-fortress-core',
#  'apache_directory-server',
#  'apache_dubbo-admin',
#  'apache_dubbo-samples',
#  'apache_dubbo-spring-boot-project',
#  'apache_geode',
#  'apache_giraph',
#  'apache_hadoop',
#  'apache_hadoop-common',
#  'apache_hama',
#  'apache_ignite',
#  'apache_incubator-atlas',
#  'apache_incubator-blur',
#  'apache_incubator-dlab',
#  'apache_incubator-iotdb',
#  'apache_incubator-rya',
#  'apache_incubator-sentry',
#  'apache_jackrabbit-oak',
#  'apache_james-jdkim',
#  'apache_jclouds',
#  'apache_jena',
#  'apache_karaf-cellar',
#  'apache_kylin',
#  'apache_logging-log4j-audit',
#  'apache_marmotta',
#  'apache_maven-indexer',
#  'apache_maven-resolver',
#  'apache_metamodel',
#  'apache_myfaces',
#  'apache_nifi',
#  'apache_nifi-minifi',
#  'apache_nifi-registry',
#  'apache_olingo-odata2',
#  'apache_olingo-odata4',
#  'apache_oltu',
#  'apache_openjpa',
#  'apache_openwebbeans',
#  'apache_phoenix',
#  'apache_ranger',
#  'apache_rave',
#  'apache_reef',
#  'apache_rocketmq-externals',
#  'apache_servicecomb-samples',
#  'apache_servicemix',
#  'apache_shindig',
#  'apache_sling-org-apache-sling-app-cms',
#  'apache_synapse',
#  'apache_tika',
#  'apache_tomee',
#  'apache_uima-uimafit',
#  'apache_velocity-tools',
#  'apache_zeppelin',
#  'apifest_apifest',
#  'apiman_apiman',
#  'arquillian_arquillian-container-tomcat',
#  'arquillian_arquillian-core',
#  'arquillian_arquillian-extension-drone',
#  'arquillian_continuous-enterprise-development',
#  'arteam_unitils',
#  'aseovic_coherence-tools',
#  'astefanutti_metrics-aspectj',
#  'ata4_disunity',
#  'atlasmap_atlasmap',
#  'att_AJSC',
#  'azagniotov_stubby4j',
#  'bage2014_study',
#  'basho_riak-java-client',
#  'batfish_batfish',
#  'bcdev_beam',
#  'bcsoft_bc-framework',
#  'ben-manes_caffeine',
#  'betfair_cougar',
#  'bitsofproof_supernode',
#  'blazegraph_database',
#  'bonigarcia_mastering-junit5',
#  'box_mojito',
#  'brutall_brut.apktool',
#  'buschmais_extended-objects',
#  'bytemanproject_byteman',
#  'cai3178940_youran',
#  'calrissian_accumulo-recipes',
#  'camelinaction_camelinaction2',
#  'camsys_onebusaway-nyc',
#  'candlepin_candlepin',
#  'carrot2_carrot2',
#  'castlabs_dashencrypt',
#  'cb372_metrics-sigar',
#  'cbeust_testng',
#  'ccavanaugh_jgnash',
#  'ccfish86_sctalk',
#  'cdapio_cdap',
#  'cegeka_batchers',
#  'cerner_beadledom',
#  'cero-t_e-commerce-example',
#  'choerodon_choerodon-starters',
#  'chrismattmann_lucene-geo-gazetteer',
#  'citerus_dddsample-core',
#  'cjbi_wetech-admin',
#  'cjm0000000_mmt',
#  'cloudera-labs_phoenix',
#  'cloudera_mahout',
#  'cloudfoundry-incubator_multiapps',
#  'cloudfoundry-incubator_multiapps-controller',
#  'cloudfoundry_cf-java-client',
#  'cloudstore_cloudstore',
#  'code4craft_webmagic',
#  'codehaus-cargo_cargo',
#  'codelibs_fess-crawler',
#  'codenjoyme_codenjoy',
#  'codice_alliance',
#  'codingapi_tx-lcn',
#  'coheigea_testcases',
#  'colddew_micro-service',
#  'confluentinc_camus',
#  'contentful_contentful-management.java',
#  'contentful_contentful.java',
#  'contentful_vault',
#  'couchbase_CouchbaseMock',
#  'couchbase_couchbase-lite-android',
#  'couchbase_couchbase-lite-java',
#  'cowtowncoder_ClusterMate',
#  'cowtowncoder_java-merge-sort',
#  'cpesch_RouteConverter',
#  'ctpconsulting_query',
#  'dCache_nfs4j',
#  'dadoonet_legacy-search',
#  'daijiejay_daijie',
#  'dana-i2cat_opennaas',
#  'dansimpson_chronos',
#  'darkmi_rtspserver',
#  'dashbuilder_dashbuilder',
#  'dashorst_wicket-stuff-markup-validator',
#  'data-integrations_wrangler',
#  'datacite_mds',
#  'datacleaner_DataCleaner',
#  'dayatang_dddlib',
#  'daydreamdev_seconds-kill',
#  'dbpedia_topicmodel-extractor',
#  'dcm4che_dcm4chee-arc-cdi',
#  'dcm4che_dcm4chee-arc-light',
#  'deluan_shiro-faces',
#  'delving_delving',
#  'denghuichao_proxy-pool',
#  'denimgroup_threadfix',
#  'denkbar_djigger',
#  'dianping_cat',
#  'dianping_pigeon1',
#  'diennea_herddb',
#  'difi_datahotel',
#  'difi_oxalis',
#  'digitalfondue_lavagna',
#  'digitalpetri_modbus',
#  'dkpro_dkpro-uby',
#  'dockstore_dockstore',
#  'dolfdijkstra_gst-foundation',
#  'dschadow_Java-Web-Security',
#  'dstl_baleen',
#  'e-ucm_eadventure',
#  'eclipse-ee4j_eclipselink',
#  'eclipse-ee4j_glassfish-hk2',
#  'eclipse-ee4j_jaxb-ri',
#  'eclipse-ee4j_jaxrs-api',
#  'eclipse-ee4j_jersey',
#  'eclipse-ee4j_jsonp',
#  'eclipse-ee4j_krazo',
#  'eclipse-ee4j_mojarra',
#  'eclipse-ee4j_security-api',
#  'eclipse_microprofile-open-api',
#  'eclipse_microprofile-opentracing',
#  'eclipse_microprofile-rest-client',
#  'eclipse_milo',
#  'eclipse_rdf4j-storage',
#  'eclipse_sisu.inject',
#  'egovernments_egov-smartcity-suite',
#  'ekoontz_hadoop-common',
#  'elaatifi_orika',
#  'elasticinbox_elasticinbox',
#  'eliep_elasticsearch-multiple-metric-aggregation',
#  'enioka_jqm',
#  'entando_entando-archetypes',
#  'epimorphics_elda',
#  'errai_errai',
#  'esl-client_esl-client',
#  'estatio_estatio',
#  'eugenp_tutorials',
#  'everit-org_json-schema',
#  'fang-yan-peng_eagle',
#  'fcrepo4_fcrepo4',
#  'ff4j_ff4j',
#  'find-sec-bugs_find-sec-bugs',
#  'flaxsearch_BioSolr',
#  'florinpatrascu_micro',
#  'flowersinthesand_portal-java',
#  'forge_core',
#  'fortify-ps_FortifyBugTrackerUtility',
#  'frenchc_jetm',
#  'future-architect_uroborosql',
#  'gatein_gatein-portal',
#  'gavin-guo_spring-cloud-demo',
#  'gbif_checklistbank',
#  'gchq_Gaffer',
#  'gchq_koryphe',
#  'geophile_geophile',
#  'geosdi_geo-platform',
#  'geoserver_geoserver',
#  'geosolutions-it_jai-ext',
#  'geotools_geotools',
#  'gephi_gephi',
#  'ggeorgovassilis_spring-rest-invoker',
#  'ghillert_botanic-ng',
#  'giiwa_giiwa',
#  'gisgraphy_gisgraphy',
#  'gocd_go-plugins',
#  'gocd_gocd',
#  'goldmansachs_obevo',
#  'gooddata_gooddata-java',
#  'google_google-java-format',
#  'google_guice',
#  'google_openrtb-doubleclick',
#  'google_truth',
#  'googleapis_google-oauth-java-client',
#  'gotify_android',
#  'gravitee-io_gravitee-gateway',
#  'gravitee-io_graviteeio-access-management',
#  'gridgain_gridgain',
#  'groovy_gmaven',
#  'groupe-sii_ogham',
#  'gt-health_GT-FHIR',
#  'gudaoxuri_dew',
#  'gvlasov_inflectible',
#  'haifeiWu_lightconf',
#  'hammacher_javaslicer',
#  'hammock-project_hammock',
#  'hank-whu_rpc-benchmark',
#  'hantsy_spring4-sandbox',
#  'happygiraffe_jslint4java',
#  'hawkular_hawkular-agent',
#  'hawkular_hawkular-apm',
#  'hawkular_hawkular-datamining',
#  'hazelcast_hazelcast',
#  'hcoles_pitest',
#  'headsupdev_agile',
#  'hekate-io_hekate',
#  'helun_Ektorp',
#  'heroku_heroku.jar',
#  'hhru_nuts-and-bolts',
#  'hibernate_hibernate-ogm',
#  'hibernate_hibernate-ogm-ignite',
#  'hippo-band_hippo',
#  'home-climate-control_dz',
#  'hosuaby_example-restful-project',
#  'httpcache4j_httpcache4j',
#  'hudec_sql-processor',
#  'hudson_hudson-2.x',
#  'huxi_lilith',
#  'hyperic_hq',
#  'hyperic_hqapi',
#  'iBotPeaches_Apktool',
#  'ibinti_bugvm',
#  'igor-baiborodine_java-various-examples',
#  'ihaolin_antares',
#  'imglib_imglib2',
#  'imrabti_gwtp-spring-security',
#  'inbloom_secure-data-service',
#  'indeedeng_proctor',
#  'indeedeng_status',
#  'inspire-software_yes-cart',
#  'intendia-oss_autorest',
#  'intendia-oss_rxjava-gwt',
#  'internetarchive_heritrix3',
#  'ippontech_nantes-mobi-parkings',
#  'ippontech_tatami',
#  'itesla_ipst',
#  'iyzico_iyzipay-java',
#  'jadler-mocking_jadler',
#  'jamesagnew_hapi-fhir',
#  'javaee-samples_javaee8-samples',
#  'javaee_jaxb-v2',
#  'javafx-maven-plugin_javafx-rest-archetype',
#  'javahongxi_whatsmars',
#  'javalite_activejdbc',
#  'javanna_elasticsearch-river-solr',
#  'jaycekon_SpringBoot',
#  'jbehave_jbehave-core',
#  'jberet_jsr352',
#  'jboss-developer_jboss-jdg-quickstarts',
#  'jboss-switchyard_components',
#  'jboss-switchyard_quickstarts',
#  'jboss-switchyard_switchyard',
#  'jbufu_openid4java',
#  'jclouds_jclouds',
#  'jclouds_legacy-jclouds',
#  'jdemetra_jdemetra-app',
#  'jdemetra_jdemetra-core',
#  'jdillon_gossip',
#  'jdillon_gshell',
#  'jdillon_mvnsh',
#  'jenkinsci_analysis-model',
#  'jenkinsci_git-client-plugin',
#  'jenkinsci_java-client-api',
#  'jenkinsci_swarm-plugin',
#  'jeppetto_jeppetto',
#  'jeremylong_DependencyCheck',
#  'jetoile_hadoop-unit',
#  'jibx_core',
#  'jimmoores_quandl4j',
#  'jitlogic_zorka',
#  'jklingsporn_vertx-jooq',
#  'jknack_handlebars.java',
#  'jloisel_elastic-crud',
#  'jobxhub_JobX',
#  'jogetworkflow_jw-community',
#  'johnewart_gearman-java',
#  'joinfaces_joinfaces',
#  'jooby-project_jooby',
#  'joshdrummond_webpasswordsafe',
#  'joshlong_the-spring-rest-stack',
#  'joshsh_ripple',
#  'jpatanooga_Canova',
#  'jpmml_jpmml-evaluator',
#  'jpmml_jpmml-model',
#  'jprante_elasticsearch-jdbc',
#  'js-cookie_java-cookie',
#  'jsonld-java_jsonld-java',
#  'jtransc_jtransc',
#  'julianhyde_optiq',
#  'junit_sb-framework',
#  'karussell_Jetwick',
#  'kazuki43zoo_spring-boot-multi-sample',
#  'kbastani_event-sourcing-microservices-example',
#  'keets2012_Spring-Boot-Samples',
#  'kermitt2_entity-fishing',
#  'keycloak_keycloak',
#  'kiegroup_droolsjbpm-knowledge',
#  'kiegroup_jbpm-wb',
#  'kiegroup_jbpm-work-items',
#  'kiegroup_kie-wb-distributions',
#  'kiegroup_optaweb-employee-rostering',
#  'killme2008_Metamorphosis',
#  'kislayverma_Rulette',
#  'kite-sdk_kite',
#  'klarna_HiveRunner',
#  'konsoletyper_teavm-flavour',
#  'krasserm_ipf',
#  'kuali_kfs',
#  'kuali_rice',
#  'kubernetes-client_java',
#  'kunai-consulting_KeyStor',
#  'laforge49_JASocket',
#  'leadpony_justify',
#  'lennartkoopmann_nzyme',
#  'lenskit_lenskit',
#  'lievendoclo_Valkyrie-RCP',
#  'link-it_GovPay',
#  'linkedin_sensei',
#  'linlinjava_litemall',
#  'liquibase_liquibase',
#  'lkrnac_book-eiws-code-samples',
#  'locationtech_geowave',
#  'locationtech_spatial4j',
#  'lodsve_lodsve-framework',
#  'logicalclocks_hopsworks',
#  'looly_hutool',
#  'ltsopensource_light-task-scheduler',
#  'lucmoreau_ProvToolbox',
#  'ludup_hypersocket-framework',
#  'luontola_cqrs-hotel',
#  'luposdate_luposdate',
#  'lveci_nest',
#  'marcelstoer_open-data-smn',
#  'mars-sim_mars-sim',
#  'marytts_marytts',
#  'mbedward_jaitools',
#  'menacher_java-game-server',
#  'mesosphere_cassandra-mesos-deprecated',
#  'metawidget_metawidget',
#  'mheath_adbcj',
#  'micromata_JiraRestClient',
#  'microsoft_spring-cloud-azure',
#  'mifos_head',
#  'migtavares_owmClient',
#  'minnal_minnal',
#  'miso-lims_miso-lims',
#  'mojohaus_webstart',
#  'monkeyk_spring-oauth-server',
#  'moxi624_mogu_blog_v2',
#  'mozilla-metrics_akela',
#  'mp911de_logstash-gelf',
#  'mpusher_mpush',
#  'mulesoft_mule-maven-plugin',
#  'my2iu_Jinq',
#  'mybatis_migrations-maven-plugin',
#  'mycila_guice',
#  'n8han_Databinder-for-Wicket',
#  'naver_ngrinder',
#  'naver_pinpoint',
#  'nbfujx_Goku.WebService',
#  'nebhale_JsonPath',
#  'neo4j_neo4j-ogm',
#  'neophob_PixelController',
#  'netceteragroup_valdr-bean-validation',
#  'networknt_light-4j',
#  'ngageoint_mrgeo',
#  'nielsbasjes_yauaa',
#  'nilzao_soapbox-race',
#  'ning_Arecibo',
#  'ninjaframework_ninja',
#  'noctarius_Lightning',
#  'nowina-solutions_nexu',
#  'nutzam_nutzboot',
#  'nuxeo-archives_nuxeo-features',
#  'oberasoftware_jasdb',
#  'oblac_jodd',
#  'olivergierke_spring-restbucks-training',
#  'onepiecex_session-share',
#  'opencb_opencga',
#  'opencit_opencit',
#  'opendatatrentino_jackan',
#  'opendaylight_aaa',
#  'opendaylight_bgpcep',
#  'opengeospatial_teamengine',
#  'opennetworkinglab_onos',
#  'opennetworkinglab_onos-app-samples',
#  'openpnp_openpnp',
#  'opensagres_xdocreport',
#  'openscoring_openscoring',
#  'openxc_openxc-android',
#  'ops4j_org.ops4j.pax.jdbc',
#  'oracle_helidon',
#  'orfjackal_jumi-actors',
#  'osiam_server',
#  'outbrain_ob1k',
#  'owlcs_owlapi',
#  'palominolabs_sf-api-connector',
#  'paritytrading_parity',
#  'paritytrading_philadelphia',
#  'payara_Payara',
#  'paypal_SeLion',
#  'pentaho_big-data-plugin',
#  'pentaho_marketplace',
#  'pentaho_pentaho-kettle',
#  'pentaho_pentaho-platform',
#  'pentaho_pentaho-reporting',
#  'peshkira_c3po',
#  'phax_ph-ubl',
#  'phenotips_phenotips',
#  'phoenixctms_ctsms',
#  'picocontainer_picocontainer',
#  'pietermartin_sqlg',
#  'pingidentity_scim',
#  'pixmob_httpclient',
#  'pjklauser_protobuf-rpc-pro',
#  'plan-player-analytics_Plan',
#  'planetlabs_staccato',
#  'playn_playn',
#  'plus-provenance_plus',
#  'pocrd_net.pocrd.core',
#  'powsybl_powsybl-core',
#  'prestodb_presto',
#  'proarc_proarc',
#  'project-ncl_pnc',
#  'projectodd_stilts',
#  'pulsarIO_jetstream',
#  'puppetlabs_geppetto',
#  'pxb1988_dex2jar',
#  'qalingo_qalingo-engine',
#  'qcri-social_AIDR',
#  'qos-ch_logback',
#  'ragnor_simple-spring-memcached',
#  'rakam-io_rakam',
#  'ralscha_spring4ws-demos',
#  'raphw_byte-buddy',
#  'raskasa_metrics-okhttp',
#  'raydac_mvn-golang',
#  'release-engineering_pom-manipulation-ext',
#  'researchstudio-sat_webofneeds',
#  'resty-gwt_resty-gwt',
#  'rhq-project_rhq',
#  'richardrodgers_mds',
#  'richfaces4_build',
#  'richfaces4_components',
#  'richfaces4_dev-examples',
#  'richfaces_richfaces',
#  'richfaces_richfaces-archetypes',
#  'roboguice_roboguice',
#  'robovm_robovm',
#  'ron190_jsql-injection',
#  'saalfeldlab_render',
#  'sabomichal_immutable-xjc',
#  'sanluan_PublicCMS',
#  'scribejava_scribejava',
#  'sdl_dxa-web-application-java',
#  'seam_solder',
#  'seata_seata',
#  'sebastianbenz_Jnario',
#  'senbox-org_s2tbx',
#  'senbox-org_s3tbx',
#  'seznam_euphoria',
#  'shrinkwrap_resolver',
#  'shuzheng_zheng',
#  'signalfx_signalfx-java',
#  'silb_shiro-jersey',
#  'smallrye_smallrye-jwt',
#  'smallrye_smallrye-metrics',
#  'sofastack_sofa-rpc',
#  'sonatype_nexus-public',
#  'sonatype_sisu',
#  'sonatype_sisu-guice',
#  'spotify_ffwd',
#  'spotify_flo',
#  'spotify_heroic',
#  'spotify_semantic-metrics',
#  'spotify_zoltar',
#  'spring-cloud-samples_spring-cloud-contract-samples',
#  'spring-cloud_spring-cloud-gcp',
#  'spring-cloud_spring-cloud-netflix',
#  'spring-cloud_spring-cloud-openfeign',
#  'spring-cloud_spring-cloud-stream-app-starters',
#  'spring-cloud_spring-cloud-stream-binder-kafka',
#  'spring-cloud_spring-cloud-task',
#  'spring-cloud_spring-cloud-vault',
#  'spring-io_initializr',
#  'spring-petclinic_spring-petclinic-angularjs',
#  'spring-projects_spring-android-samples',
#  'spring-projects_spring-data-cassandra',
#  'spring-projects_spring-data-examples',
#  'spring-projects_spring-petclinic',
#  'spring-projects_spring-restdocs',
#  'spring-projects_spring-roo',
#  'spring-projects_spring-social-samples',
#  'spring-projects_spring-ws',
#  'spring-social_spring-social-google',
#  'springdoc_springdoc-openapi',
#  'sqshq_piggymetrics',
#  'square_keywhiz',
#  'square_okhttp',
#  'stanfordnlp_CoreNLP',
#  'stapler_stapler',
#  'stephanenicolas_robospice',
#  'stoicflame_enunciate',
#  'stormpath_stormpath-sdk-java',
#  'stratosphere_metadata-ms',
#  'subes_invesdwin-context-persistence',
#  'subutai-io_peer-os',
#  'suninformation_ymateplatform',
#  'support-project_knowledge',
#  'swagger-api_swagger-core',
#  'swagger-api_swagger-socket',
#  'swri-robotics_bag-database',
#  'syndesisio_syndesis',
#  'takari_io.takari.incrementalbuild',
#  'takari_takari-plugin-testing-project',
#  'te-con_ehour',
#  'tech-advantage_sonar-gerrit-plugin',
#  'techa03_goodsKill',
#  'teiid_teiid',
#  'teiid_teiid-spring-boot',
#  'terasolunaorg_terasoluna-gfw',
#  'terasolunaorg_terasoluna-tourreservation',
#  'terasolunaorg_terasoluna-tourreservation-mybatis3',
#  'terrestris_shogun-core',
#  'terrier-org_terrier-core',
#  'thelinmichael_spotify-web-api-java',
#  'thubbo_jmeter-plugins-for-apache-dubbo',
#  'timboudreau_nb-nodejs',
#  'tomoya92_pybbs',
#  'tony19_logback-android',
#  'torakiki_pdfsam',
#  'torakiki_sejda',
#  'tropo_tropo-webapi-java',
#  'tunnelvisionlabs_antlr4',
#  'twitter_ambrose',
#  'twitter_hraven',
#  'twosigma_webtau',
#  'tylanbin_platform-ng',
#  'tyndale_step',
#  'ucarGroup_DataLink',
#  'unidal_frameworks',
#  'urbanairship_java-library',
#  'uwolfer_gerrit-intellij-plugin',
#  'uwolfer_gerrit-rest-java-client',
#  'veraPDF_veraPDF-library',
#  'vivo-project_Vitro',
#  'vladmihalcea_flexy-pool',
#  'vmi_selenese-runner-java',
#  'vmware-serengeti_serengeti-ws',
#  'vmware_declarative-cluster-management',
#  'vmware_hillview',
#  'vt-middleware_ldaptive',
#  'vvakame_JsonPullParser',
#  'watson-developer-cloud_java-sdk',
#  'wayshall_onetwo',
#  'weiboad_fiery',
#  'wfh45678_radar',
#  'wikimedia_wikidata-query-rdf',
#  'wildfly-extras_wildfly-camel-examples',
#  'wildfly-extras_wildfly-microprofile-config',
#  'wildfly_wildfly-arquillian',
#  'wocommunity_wonder',
#  'woemler_spring-blog',
#  'woorea_openstack-java-sdk',
#  'wooti_onedrive-java-client',
#  'workhabitinc_dandy',
#  'wso2-attic_carbon-identity',
#  'wso2-attic_product-emm',
#  'wso2_ballerina-integrator',
#  'wso2_ballerina-message-broker',
#  'wso2_wso2-synapse',
#  'wuic_wuic',
#  'x-stream_xstream',
#  'xenit-eu_dynamic-extensions-for-alfresco',
#  'xianrendzw_EasyReport',
#  'xiaolanglang_easypoi',
#  'xubinux_xbin-store',
#  'xuxueli_xxl-api',
#  'xuxueli_xxl-conf',
#  'xuxueli_xxl-job',
#  'xwiki_xwiki-rendering',
#  'yahoo_athenz',
#  'yandex-qatools_hamcrest-pojo-matcher-generator',
#  'yandex_yoctodb',
#  'yegor256_rexsl',
#  'yuboon_Aooms',
#  'zauberlabs_gnip4j',
#  'zavtech_morpheus-core',
#  'zccodere_study-imooc',
#  'zhangfei19841004_zmock',
#  'zhoutaoo_SpringCloud',
#  'zinin_tomcat-redis-session',
#  'zkoss_zk'}

# %%
hard_remove_log_test_df = original_df[
    original_df["repoName"].isin(hard_remove_log_test_repos)
]
hard_remove_log_test_df
# Out:
#           id          fromLib                             toLib  \
# 2          2          ant:ant                org.apache.ant:ant
# 10        10          ant:ant                org.apache.ant:ant
# 11        11          ant:ant                org.apache.ant:ant
# 13        13          ant:ant                org.apache.ant:ant
# 14        14          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14316  14316  xstream:xstream  com.thoughtworks.xstream:xstream
# 14317  14317  xstream:xstream  com.thoughtworks.xstream:xstream
# 14327  14327  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                   repoName                                   fileName  \
# 2              teiid_teiid                                    pom.xml
# 10           Top-Q_jsystem  jsystem-core-projects/jsystemCore/pom.xml
# 11           Top-Q_jsystem                     jsystem-parent/pom.xml
# 13     geoserver_geoserver                                src/pom.xml
# 14     geoserver_geoserver                        src/release/pom.xml
# ...                    ...                                        ...
# 14316           apache_ace         ace-client-repository-impl/pom.xml
# 14317           apache_ace    ace-client-repository-useradmin/pom.xml
# 14327           bcdev_beam                                    pom.xml
# 14332       apache_shindig   1.0.x-incubating/java/social-api/pom.xml
# 14333       apache_shindig                   1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 10     69e5982631fb1a4932789e81ef19291780c8b05c
# 11     69e5982631fb1a4932789e81ef19291780c8b05c
# 13     8e51ce269eaab07cfa04b700e2dcb909133675ed
# 14     8e51ce269eaab07cfa04b700e2dcb909133675ed
# ...                                         ...
# 14316  3df4226489929e6ab565f99481826acd9e7a0b4f
# 14317  3df4226489929e6ab565f99481826acd9e7a0b4f
# 14327  769b9c89c3173be4fd174e374f08c762c8005edd
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 10     69e5982631fb1a4932789e81ef19291780c8b05c
# 11     69e5982631fb1a4932789e81ef19291780c8b05c
# 13     8e51ce269eaab07cfa04b700e2dcb909133675ed
# 14     8e51ce269eaab07cfa04b700e2dcb909133675ed
# ...                                         ...
# 14316  3df4226489929e6ab565f99481826acd9e7a0b4f
# 14317  3df4226489929e6ab565f99481826acd9e7a0b4f
# 14327  769b9c89c3173be4fd174e374f08c762c8005edd
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 2                          +org.apache.ant:ant\n-ant:ant
# 10                         +org.apache.ant:ant\n-ant:ant
# 11                         +org.apache.ant:ant\n-ant:ant
# 13                         +org.apache.ant:ant\n-ant:ant
# 14                         +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14316  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14317  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14327  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 2                          +org.apache.ant:ant\n-ant:ant
# 10                         +org.apache.ant:ant\n-ant:ant
# 11                         +org.apache.ant:ant\n-ant:ant
# 13                         +org.apache.ant:ant\n-ant:ant
# 14                         +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14316  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14317  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14327  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 2                                 updating ant groupid\n
# 10                     Updated to the new ant group id\n
# 11                     Updated to the new ant group id\n
# 13     Fixed broken ant groupId, which appears to hav...
# 14     Fixed broken ant groupId, which appears to hav...
# ...                                                  ...
# 14316  ACE-93 fixed. Happened due to the fact that gr...
# 14317  ACE-93 fixed. Happened due to the fact that gr...
# 14327  xstream --> com.thoughtworks.xstream\n\ngit-sv...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 2                                 updating ant groupid\n      2009-01-19
# 10                     Updated to the new ant group id\n      2012-12-23
# 11                     Updated to the new ant group id\n      2012-12-23
# 13     Fixed broken ant groupId, which appears to hav...      2012-07-31
# 14     Fixed broken ant groupId, which appears to hav...      2012-07-31
# ...                                                  ...             ...
# 14316  ACE-93 fixed. Happened due to the fact that gr...      2010-10-04
# 14317  ACE-93 fixed. Happened due to the fact that gr...      2010-10-04
# 14327  xstream --> com.thoughtworks.xstream\n\ngit-sv...      2007-08-20
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category  repoOwner repoSplitName
# 2        2009-01-19         0      teiid         teiid
# 10       2012-12-23         0      Top-Q       jsystem
# 11       2012-12-23         0      Top-Q       jsystem
# 13       2012-07-31         0  geoserver     geoserver
# 14       2012-07-31         0  geoserver     geoserver
# ...             ...       ...        ...           ...
# 14316    2010-10-04        30     apache           ace
# 14317    2010-10-04        30     apache           ace
# 14327    2007-08-20        30      bcdev          beam
# 14332    2009-01-12        30     apache       shindig
# 14333    2009-01-12        30     apache       shindig
#
# [3677 rows x 16 columns]

# %% [markdown]
# # Insight about number of pair fromLib-toLib per repo

# %%
migration_in_repo = dict(hard_remove_log_test_df["repoName"].value_counts())

# %%
len(list(filter(lambda x: migration_in_repo[x] > 1, migration_in_repo)))
# Out:
# 414

# %%
repo_with_only_one_migration = list(
    filter(lambda x: migration_in_repo[x] == 1, migration_in_repo)
)
repo_with_only_one_migration
# Out:
# ['gocd_go-plugins',
#  'EmiteGWT_emite',
#  'a466350665_smart',
#  'thubbo_jmeter-plugins-for-apache-dubbo',
#  'opennetworkinglab_onos-app-samples',
#  'darkmi_rtspserver',
#  'dianping_cat',
#  'alibaba_Sentinel',
#  'esl-client_esl-client',
#  'mheath_adbcj',
#  'menacher_java-game-server',
#  'wfh45678_radar',
#  'naver_ngrinder',
#  'jboss-switchyard_components',
#  'everit-org_json-schema',
#  'wso2_wso2-synapse',
#  'apifest_apifest',
#  'uwolfer_gerrit-intellij-plugin',
#  'ChargeTimeEU_Java-OCA-OCPP',
#  'ibinti_bugvm',
#  'mulesoft_mule-maven-plugin',
#  'robovm_robovm',
#  'gchq_Gaffer',
#  'uwolfer_gerrit-rest-java-client',
#  'apache_incubator-iotdb',
#  'suninformation_ymateplatform',
#  'SmartDataAnalytics_Sparqlify',
#  'apache_karaf-cellar',
#  'VueGWT_vue-gwt',
#  'ata4_disunity',
#  'arquillian_arquillian-core',
#  'arquillian_arquillian-container-tomcat',
#  'swri-robotics_bag-database',
#  'zauberlabs_gnip4j',
#  'dcm4che_dcm4chee-arc-light',
#  'marytts_marytts',
#  'apache_incubator-dlab',
#  'joshsh_ripple',
#  'kuali_kfs',
#  'wooti_onedrive-java-client',
#  'CUTR-at-USF_gtfs-realtime-validator',
#  'eclipse-ee4j_jaxb-ri',
#  'teiid_teiid-spring-boot',
#  'gavin-guo_spring-cloud-demo',
#  'dadoonet_legacy-search',
#  'codelibs_fess-crawler',
#  'logicalclocks_hopsworks',
#  'apache_directory-fortress-core',
#  'US-CBP_GTAS',
#  'Bammerbom_UltimateCore',
#  'shuzheng_zheng',
#  'paypal_SeLion',
#  'jitlogic_zorka',
#  'project-ncl_pnc',
#  'ihaolin_antares',
#  'kiegroup_jbpm-work-items',
#  'apache_dubbo-samples',
#  'cai3178940_youran',
#  'apache_commons-jcs',
#  'delving_delving',
#  'Appverse_appverse-web',
#  'js-cookie_java-cookie',
#  'apache_dubbo-admin',
#  'GoogleContainerTools_jib',
#  'micromata_JiraRestClient',
#  'apache_servicemix',
#  'workhabitinc_dandy',
#  'Erudika_para',
#  'microsoft_spring-cloud-azure',
#  'HotelsDotCom_bull',
#  'ManfredTremmel_gwt-bean-validators',
#  'ScaCap_spring-auto-restdocs',
#  'Consonance_consonance',
#  'codingapi_tx-lcn',
#  'basho_riak-java-client',
#  'aliyun_alibabacloud-microservice-demo',
#  'apache_nifi-registry',
#  'googleapis_google-oauth-java-client',
#  'denkbar_djigger',
#  'sonatype_sisu-guice',
#  'spring-projects_spring-restdocs',
#  'gephi_gephi',
#  'bage2014_study',
#  'keets2012_Spring-Boot-Samples',
#  'codenjoyme_codenjoy',
#  'richardrodgers_mds',
#  'spring-projects_spring-petclinic',
#  'joshlong_the-spring-rest-stack',
#  'monkeyk_spring-oauth-server',
#  'zhangfei19841004_zmock',
#  'spring-petclinic_spring-petclinic-angularjs',
#  'hosuaby_example-restful-project',
#  'nbfujx_Goku.WebService',
#  'imrabti_gwtp-spring-security',
#  'apache_rocketmq-externals',
#  'outbrain_ob1k',
#  'cb372_metrics-sigar',
#  'planetlabs_staccato',
#  'apache_velocity-tools',
#  'geophile_geophile',
#  'zhoutaoo_SpringCloud',
#  'gravitee-io_graviteeio-access-management',
#  'openpnp_openpnp',
#  'lievendoclo_Valkyrie-RCP',
#  'mars-sim_mars-sim',
#  'denghuichao_proxy-pool',
#  'epimorphics_elda',
#  'opencb_opencga',
#  'mojohaus_webstart',
#  'yandex-qatools_hamcrest-pojo-matcher-generator',
#  'apache_jackrabbit-oak',
#  'picocontainer_picocontainer',
#  'happygiraffe_jslint4java',
#  'veraPDF_veraPDF-library',
#  'Exrick_xboot',
#  'ghillert_botanic-ng',
#  'cloudera-labs_phoenix',
#  'jprante_elasticsearch-jdbc',
#  'terasolunaorg_terasoluna-tourreservation-mybatis3',
#  'pietermartin_sqlg',
#  'gt-health_GT-FHIR',
#  'javalite_activejdbc',
#  'cloudfoundry-incubator_multiapps-controller',
#  'EvidentSolutions_dalesbred',
#  'flaxsearch_BioSolr',
#  'lennartkoopmann_nzyme',
#  'actiontech_txle',
#  'spring-cloud_spring-cloud-vault',
#  'home-climate-control_dz',
#  'kbastani_event-sourcing-microservices-example',
#  'jknack_handlebars.java',
#  'apache_kylin',
#  'my2iu_Jinq',
#  'apache_openwebbeans',
#  'jtransc_jtransc',
#  'egovernments_egov-smartcity-suite',
#  'migtavares_owmClient',
#  'ccfish86_sctalk',
#  'raydac_mvn-golang',
#  'hammacher_javaslicer',
#  'jibx_core',
#  'phax_ph-ubl',
#  'tropo_tropo-webapi-java',
#  'apache_ranger',
#  'daijiejay_daijie',
#  'InnovateUKGitHub_innovation-funding-service',
#  'kislayverma_Rulette',
#  'sabomichal_immutable-xjc',
#  'apache_incubator-blur',
#  'nowina-solutions_nexu',
#  'apache_cloudstack',
#  'arteam_unitils',
#  'hcoles_pitest',
#  'FundRequest_platform',
#  'takari_io.takari.incrementalbuild',
#  'jogetworkflow_jw-community',
#  'choerodon_choerodon-starters',
#  'FudanSELab_train-ticket',
#  'RxGirlz_OpenYspider',
#  'eclipse_sisu.inject',
#  'cero-t_e-commerce-example',
#  'jaycekon_SpringBoot',
#  'sonatype_sisu',
#  'noctarius_Lightning',
#  'geosolutions-it_jai-ext',
#  'digitalfondue_lavagna',
#  'laforge49_JASocket',
#  'oblac_jodd',
#  'Cognifide_Slice',
#  'dstl_baleen',
#  'gchq_koryphe',
#  'BrynCooke_cdi-unit',
#  'wuic_wuic',
#  'apache_reef',
#  'spotify_ffwd',
#  'GeneralElectric_snowizard',
#  'dschadow_Java-Web-Security',
#  'jpmml_jpmml-evaluator',
#  'spring-projects_spring-roo',
#  'OpenClinica_OpenClinica',
#  'contentful_vault',
#  'tomoya92_pybbs',
#  'apache_myfaces',
#  'BrunoEberhard_minimal-j',
#  'dCache_nfs4j',
#  'paritytrading_parity',
#  'future-architect_uroborosql',
#  'paritytrading_philadelphia',
#  'imglib_imglib2',
#  'thelinmichael_spotify-web-api-java',
#  '52North_series-rest-api',
#  'headsupdev_agile',
#  'jdillon_mvnsh',
#  'JakeWharton_ActionBarSherlock',
#  'pixmob_httpclient',
#  'dkpro_dkpro-uby',
#  'TechnionYP5777_UpAndGo',
#  'google_openrtb-doubleclick',
#  'ippontech_nantes-mobi-parkings',
#  'Atmosphere_nettosphere',
#  'dbpedia_topicmodel-extractor',
#  'kiegroup_droolsjbpm-knowledge',
#  'lkrnac_book-eiws-code-samples',
#  'senbox-org_s3tbx',
#  'senbox-org_s2tbx',
#  'ron190_jsql-injection',
#  'marcelstoer_open-data-smn',
#  'HotelsDotCom_data-highway',
#  'plan-player-analytics_Plan',
#  'Stratio_deep-spark',
#  'bitsofproof_supernode',
#  'IBMStreams_streamsx.messaging',
#  'pxb1988_dex2jar',
#  'giiwa_giiwa',
#  'tunnelvisionlabs_antlr4',
#  'antlr_antlr4',
#  'dashorst_wicket-stuff-markup-validator',
#  'ClearTK_cleartk',
#  'RankSys_RankSys',
#  'Diorite_Diorite',
#  'zavtech_morpheus-core',
#  'spotify_flo',
#  'couchbase_CouchbaseMock',
#  'gravitee-io_gravitee-gateway',
#  'eclipse_microprofile-open-api',
#  'bonigarcia_mastering-junit5',
#  'apache_activemq-artemis',
#  'spring-cloud_spring-cloud-stream-app-starters',
#  'looly_hutool',
#  'weiboad_fiery',
#  'support-project_knowledge',
#  'Hack23_cia',
#  'HubSpot_Singularity',
#  'stanfordnlp_CoreNLP',
#  'jamesagnew_hapi-fhir',
#  'yandex_yoctodb',
#  'apache_jclouds',
#  'joshdrummond_webpasswordsafe',
#  'deluan_shiro-faces',
#  'TechzoneMC_SonarPet',
#  'wildfly_wildfly-arquillian',
#  'CCI-MIT_XCoLab',
#  'miso-lims_miso-lims',
#  'opensagres_xdocreport',
#  'elaatifi_orika',
#  'spring-cloud_spring-cloud-netflix',
#  'yuboon_Aooms',
#  'AmyAssist_Amy',
#  'tony19_logback-android',
#  'opengeospatial_teamengine',
#  'richfaces4_components',
#  'mp911de_logstash-gelf',
#  'eclipse-ee4j_jaxrs-api',
#  'Kurento_kurento-java',
#  'spring-cloud_spring-cloud-openfeign',
#  'kiegroup_kie-wb-distributions',
#  'azagniotov_stubby4j',
#  'kazuki43zoo_spring-boot-multi-sample',
#  'intendia-oss_autorest',
#  'nilzao_soapbox-race',
#  'ippontech_tatami',
#  'gisgraphy_gisgraphy',
#  'Alfresco_alfresco-sdk',
#  'ben-manes_caffeine',
#  'YahooArchive_oozie',
#  'RestComm_sip-servlets',
#  'gudaoxuri_dew',
#  'stapler_stapler',
#  'datacleaner_DataCleaner',
#  'adamkewley_jobson',
#  'JoeCao_qbike',
#  'code4craft_webmagic',
#  'difi_oxalis',
#  'chrismattmann_lucene-geo-gazetteer',
#  'brutall_brut.apktool',
#  'Netcentric_accesscontroltool',
#  'hawkular_hawkular-apm',
#  'wso2-attic_carbon-identity',
#  'oracle_helidon',
#  'Tanaguru_Tanaguru',
#  'att_AJSC',
#  'twitter_hraven',
#  '42BV_jarb',
#  'iBotPeaches_Apktool',
#  'flowersinthesand_portal-java',
#  'JULIELab_jcore-base',
#  'box_mojito',
#  'xenit-eu_dynamic-extensions-for-alfresco',
#  'linlinjava_litemall',
#  'luontola_cqrs-hotel',
#  'httpcache4j_httpcache4j',
#  'alibaba_canal',
#  'estatio_estatio',
#  'BorderTech_wcomponents',
#  'killme2008_Metamorphosis',
#  'hawkular_hawkular-datamining',
#  'cloudera_mahout',
#  'raphw_byte-buddy',
#  'ludup_hypersocket-framework',
#  'vladmihalcea_flexy-pool',
#  'spotify_semantic-metrics',
#  'urbanairship_java-library',
#  'digitalpetri_modbus',
#  'signalfx_signalfx-java',
#  'cjm0000000_mmt',
#  'seam_solder',
#  'jeremylong_DependencyCheck',
#  'aliyun_aliyun-openapi-java-sdk',
#  'bcsoft_bc-framework',
#  'apache_hama',
#  'neophob_PixelController',
#  'ragnor_simple-spring-memcached',
#  'osiam_server',
#  'calrissian_accumulo-recipes',
#  'junit_sb-framework',
#  'oberasoftware_jasdb',
#  'dansimpson_chronos',
#  'ahars_spark-jhipster',
#  'xiaolanglang_easypoi',
#  'subutai-io_peer-os',
#  'hazelcast_hazelcast',
#  'wso2_ballerina-integrator',
#  'lucmoreau_ProvToolbox',
#  'GoogleCloudPlatform_cloud-bigtable-examples',
#  'cdapio_cdap',
#  'ctpconsulting_query',
#  'klarna_HiveRunner',
#  'vmware_declarative-cluster-management',
#  'wso2_ballerina-message-broker',
#  'jeppetto_jeppetto',
#  'PerficientDigital_AEM-DataLayer',
#  'luposdate_luposdate',
#  'stratosphere_metadata-ms',
#  'cloudfoundry-incubator_multiapps',
#  'Teradata_kylo',
#  'data-integrations_wrangler',
#  'jpatanooga_Canova',
#  'gvlasov_inflectible',
#  'jenkinsci_analysis-model',
#  'seata_seata',
#  'raskasa_metrics-okhttp',
#  'groupe-sii_ogham',
#  'mifos_head',
#  'aliyun_aliyun-oss-android-sdk',
#  'twosigma_webtau',
#  'zinin_tomcat-redis-session',
#  'hawkular_hawkular-agent',
#  'apache_incubator-rya',
#  'google_google-java-format',
#  'eclipse_milo',
#  'hippo-band_hippo',
#  'JetBrains_teamcity-vmware-plugin',
#  'jenkinsci_java-client-api',
#  'eliep_elasticsearch-multiple-metric-aggregation',
#  'spring-cloud-samples_spring-cloud-contract-samples',
#  'torakiki_pdfsam',
#  'julianhyde_optiq',
#  'researchstudio-sat_webofneeds',
#  'vvakame_JsonPullParser',
#  'cegeka_batchers',
#  'karussell_Jetwick',
#  'enioka_jqm',
#  'ninjaframework_ninja',
#  'scribejava_scribejava',
#  'daydreamdev_seconds-kill',
#  'spring-cloud_spring-cloud-stream-binder-kafka',
#  'watson-developer-cloud_java-sdk',
#  'peshkira_c3po']

# %%
len(repo_with_only_one_migration)
# Out:
# 368

# %%
check = dict(original_df["repoName"].value_counts())
check
# Out:
# {'apache_camel': 1216,
#  'keycloak_keycloak': 297,
#  'Governance_rtgov': 226,
#  'nuxeo_nuxeo': 194,
#  'apache_usergrid': 191,
#  'neo4j_neo4j': 183,
#  'apache_knox': 180,
#  'apache_hbase': 173,
#  'apache_cxf': 166,
#  'CamelCookbook_camel-cookbook-examples': 136,
#  'Sage-Bionetworks_Synapse-Repository-Services': 130,
#  'thorntail_thorntail': 121,
#  'apache_james-project': 120,
#  'sakaiproject_sakai': 111,
#  'wicketstuff_core': 109,
#  'Fabric3_fabric3-core': 107,
#  'payara_Payara': 103,
#  'opendaylight_controller': 93,
#  'apache_hadoop': 89,
#  'iluwatar_java-design-patterns': 87,
#  'apache_flume': 85,
#  'apache_syncope': 81,
#  'Activiti_Activiti': 79,
#  'Intel-bigdata_SSM': 77,
#  'strongbox_strongbox': 72,
#  'opencit_opencit': 69,
#  'weld_core': 68,
#  'kiegroup_kogito-runtimes': 66,
#  'mulesoft_mule': 63,
#  'infinispan_infinispan': 63,
#  'MyCoRe-Org_mycore': 63,
#  'apache_archiva': 62,
#  'apiman_apiman': 61,
#  'cucumber_cucumber-jvm': 59,
#  'spring-projects_spring-boot': 58,
#  'apache_storm': 58,
#  'apache_servicecomb-java-chassis': 57,
#  'wildfly_wildfly': 56,
#  'fcrepo3_fcrepo': 56,
#  'airlift_airlift': 53,
#  'esig_dss': 53,
#  'ProgrammeVitam_vitam': 51,
#  'apache_airavata': 51,
#  'zanata_zanata-platform': 51,
#  'resteasy_Resteasy': 50,
#  'OpenNMS_opennms': 50,
#  'proofpoint_platform': 49,
#  'eclipse-ee4j_eclipselink': 48,
#  'eclipse-ee4j_jersey': 47,
#  'appfuse_appfuse': 46,
#  'apache_beam': 46,
#  'apache_geronimo': 45,
#  'ikasanEIP_ikasan': 45,
#  'Unidata_netcdf-java': 44,
#  'nano-projects_nano-framework': 42,
#  'openengsb_openengsb': 42,
#  'EnMasseProject_enmasse': 40,
#  'apache_struts': 40,
#  'flowable_flowable-engine': 40,
#  'RoboZonky_robozonky': 39,
#  'Graylog2_graylog2-server': 39,
#  'apache_hive': 37,
#  'syndesisio_syndesis': 36,
#  'apache_oozie': 36,
#  'apache_marmotta': 35,
#  'europeana_Europeana-Cloud': 35,
#  'kiegroup_droolsjbpm-integration': 34,
#  'javaee_glassfish': 32,
#  'apache_directory-server': 32,
#  'apache_activemq': 32,
#  'cdk_cdk': 32,
#  'apache_isis': 32,
#  'ngageoint_mrgeo': 32,
#  'apache_accumulo': 32,
#  'apache_stanbol': 31,
#  'apache_wicket': 30,
#  'Geomatys_geotoolkit': 30,
#  'apache_avro': 30,
#  'atlasmap_atlasmap': 30,
#  'webanno_webanno': 29,
#  'apache_jackrabbit': 29,
#  'JanusGraph_janusgraph': 29,
#  'apache_portals-pluto': 29,
#  'apache_nifi': 28,
#  'hibernate_hibernate-validator': 28,
#  'kiegroup_jbpm': 28,
#  'opennetworkinglab_onos': 28,
#  'spring-projects_spring-integration-samples': 28,
#  'richfaces_richfaces': 27,
#  'wildfly_quickstart': 27,
#  'apache_cxf-fediz': 27,
#  'TIBCOSoftware_jasperreports': 26,
#  'bonitasoft_bonita-engine': 26,
#  'apache_asterixdb': 26,
#  'opensecuritycontroller_osc-core': 26,
#  'apache_qpid-broker-j': 26,
#  'errai_errai': 26,
#  'apache_karaf': 26,
#  'Jasig_uPortal': 25,
#  'openl-tablets_openl-tablets': 25,
#  'dropwizard_dropwizard': 25,
#  'xwiki_xwiki-platform': 25,
#  'eclipse_kapua': 25,
#  'svenkubiak_mangooio': 25,
#  'ning_Arecibo': 24,
#  'SonarSource_sonarqube': 24,
#  'joliciel-informatique_talismane': 24,
#  'marschall_threeten-jpa': 24,
#  'ops4j_org.ops4j.pax.exam2': 24,
#  'premium-minds_billy': 24,
#  'dropwizard_metrics': 24,
#  'geoserver_geoserver': 23,
#  'Jasig_CoursesPortlet': 22,
#  'DSpace_DSpace': 22,
#  'gocd_gocd': 22,
#  'apache_tez': 22,
#  'apache_ambari': 22,
#  'dkpro_dkpro-core': 22,
#  'eclipse_hawkbit': 21,
#  'Terracotta-OSS_terracotta-core': 21,
#  'jclouds_legacy-jclouds': 21,
#  'jdemetra_jdemetra-core': 21,
#  'apache_incubator-pinot': 21,
#  'wildfly_wildfly-core': 21,
#  'fabric8io_kubernetes-client': 21,
#  'apache_ignite': 21,
#  'geosdi_geo-platform': 21,
#  'ModeShape_modeshape': 21,
#  'ops4j_org.ops4j.pax.url': 21,
#  'opendaylight_aaa': 20,
#  'JumpMind_symmetric-ds': 20,
#  'pentaho_pentaho-kettle': 20,
#  'apache_incubator-brooklyn': 20,
#  'jboss-fuse_fabric8': 20,
#  'graphhopper_graphhopper': 20,
#  'eclipse-ee4j_glassfish-hk2': 19,
#  'hawkular_hawkular-alerts': 19,
#  'apache_shindig': 19,
#  'flipkart-incubator_Poseidon': 19,
#  'apache_brooklyn-server': 19,
#  'codenvy-legacy_ide': 18,
#  'apache_aries': 18,
#  'xwiki_xwiki-commons': 18,
#  'sculptor_sculptor': 18,
#  'inbloom_secure-data-service': 18,
#  'doanduyhai_Achilles': 17,
#  'NitorCreations_nflow': 17,
#  'apache_helix': 17,
#  'spring-projects_spring-security': 17,
#  'apache_ant': 17,
#  'opentripplanner_OpenTripPlanner': 17,
#  'YunaiV_onemall': 17,
#  'apache_directmemory': 17,
#  'geoserver_geofence': 17,
#  'apache_chemistry-opencmis': 17,
#  'qaprosoft_carina': 17,
#  'eclipse_leshan': 16,
#  'jbosstm_quickstart': 16,
#  'glowroot_glowroot': 16,
#  'linux-china_dubbo3': 16,
#  'flink-tpc-ds_flink': 16,
#  'PantheonTechnologies_lighty-core': 16,
#  'igniterealtime_Openfire': 16,
#  'ralscha_extdirectspring': 16,
#  'davemckain_qtiworks': 16,
#  'apache_sqoop': 16,
#  'Azure_azure-sdk-for-java': 16,
#  'springside_springside4': 16,
#  'cloudera_sqoop2': 16,
#  'apache_shiro': 16,
#  'camunda_camunda-bpm-platform': 16,
#  'jbufu_openid4java': 16,
#  'cryptomator_cryptomator': 15,
#  'Wimmics_corese': 15,
#  'hudec_sql-processor': 15,
#  'apache_flink': 15,
#  'HubSpot_Baragon': 15,
#  'apache_metamodel': 15,
#  'hibernate_hibernate-ogm-ignite': 15,
#  'intuit_Tank': 15,
#  'pentaho_pentaho-reporting': 15,
#  'LearnLib_learnlib': 15,
#  'hibernate_hibernate-ogm': 15,
#  'Geomatys_constellation': 15,
#  'spotify_apollo': 14,
#  'matthoffman_blast-shell': 14,
#  'dCache_dcache': 14,
#  'speedment_speedment': 14,
#  'rapidoid_rapidoid': 14,
#  'jrtom_jung': 14,
#  'phenotips_phenotips': 14,
#  'myabc_appfuse': 14,
#  'wgybzbrobot_sentiment-search': 14,
#  'metawidget_metawidget': 14,
#  'bobmcwhirter_drools': 14,
#  'deegree_deegree3': 14,
#  'prestodb_presto': 14,
#  'OpenGamma_Strata': 14,
#  'hortonworks_streamline': 14,
#  'mock-server_mockserver': 14,
#  'apache_dubbo': 13,
#  'apache_maven-wagon': 13,
#  'hibernate_hibernate-search': 13,
#  'apache_tika': 13,
#  'apache_oltu': 13,
#  'membrane_service-proxy': 13,
#  'apache_activemq-apollo': 13,
#  'apache_tomee': 13,
#  'kuali_rice': 13,
#  'knowm_XChange': 13,
#  'jmxtrans_jmxtrans': 13,
#  'eclipse_hono': 13,
#  'eclipse-ee4j_mojarra': 13,
#  'pentaho_pentaho-platform': 13,
#  'fcrepo4_fcrepo4': 13,
#  'citrusframework_citrus': 13,
#  'oskariorg_oskari-server': 13,
#  'blazegraph_database': 12,
#  'spring-projects_spring-insight-plugins': 12,
#  'opendaylight_bgpcep': 12,
#  'j-easy_easy-random': 12,
#  'ArtificerRepo_artificer': 12,
#  'opendatatrentino_jackan': 12,
#  'openzipkin_zipkin': 12,
#  'nosan_embedded-cassandra': 12,
#  'mybatis_migrations-maven-plugin': 12,
#  'couchbase_couchbase-lite-android': 12,
#  'jbosstm_narayana': 12,
#  'gridgain_gridgain': 12,
#  'ccheneau_Holmes': 12,
#  'apache_httpcomponents-client': 12,
#  'rhq-project_rhq': 12,
#  'astefanutti_camel-cdi': 12,
#  'ballerina-platform_ballerina-lang': 12,
#  'apache_jspwiki': 12,
#  'xianrendzw_EasyReport': 11,
#  'LibrePlan_libreplan': 11,
#  'bmwcarit_joynr': 11,
#  'zccodere_study-imooc': 11,
#  'mybatis_generator': 11,
#  'eclipse_jetty.project': 11,
#  'OpenRock_OpenAM': 11,
#  'GluuFederation_oxTrust': 11,
#  'ops4j_org.ops4j.pax.web': 11,
#  'openmrs_openmrs-core': 11,
#  'spring-projects_spring-batch': 11,
#  'opendaylight_netconf': 11,
#  'exomiser_Exomiser': 11,
#  '52North_SOS': 11,
#  'psi-probe_psi-probe': 11,
#  'apache_manifoldcf': 11,
#  'Jasig_WebproxyPortlet': 10,
#  'joachimvda_jtransfo': 10,
#  'apache_clerezza': 10,
#  'forcedotcom_java-sdk': 10,
#  'apereo_cas': 10,
#  'dekorateio_dekorate': 10,
#  'salahsheikh_jpushbullet': 10,
#  'geosolutions-it_geobatch': 10,
#  'GluuFederation_oxAuth': 10,
#  'smooks_smooks': 10,
#  'dhanji_sitebricks': 10,
#  'kiegroup_appformer': 10,
#  'apache_logging-log4j2': 10,
#  'calibre2opds_calibre2opds': 10,
#  'Waffle_waffle': 9,
#  'jclouds_jclouds': 9,
#  'smallrye_smallrye-reactive-messaging': 9,
#  'Flipkart_phantom': 9,
#  'morimekta_providence': 9,
#  'RestComm_jain-sip': 9,
#  'square_keywhiz': 9,
#  'platformlayer_platformlayer': 9,
#  'sonatype_nexus-public': 9,
#  'apache_parquet-mr': 9,
#  'apache_lens': 9,
#  'webmetrics_browsermob-proxy': 9,
#  'mapstruct_mapstruct': 9,
#  'spring-projects_spring-ws': 9,
#  'jtablesaw_tablesaw': 9,
#  'orfjackal_jumi': 9,
#  'vsilaev_tascalate-javaflow': 9,
#  'teiid_teiid': 9,
#  'MyCollab_mycollab': 9,
#  'wso2_jaggery': 9,
#  'apache_httpcomponents-core': 9,
#  'BioPAX_Paxtools': 9,
#  'dayatang_dddlib': 9,
#  'browserup_browserup-proxy': 9,
#  'Azure_azure-libraries-for-java': 9,
#  'SeqWare_seqware': 9,
#  'elasticinbox_elasticinbox': 9,
#  'vaadin_vaadin-connect': 9,
#  'adobe_aem-project-archetype': 9,
#  'Terracotta-OSS_terracotta-platform': 9,
#  'apache_maven': 8,
#  'jenkinsci_jenkins': 8,
#  'fenix-framework_fenix-framework': 8,
#  'griffon_griffon': 8,
#  'resthub_resthub-spring-stack': 8,
#  'Cognifide_bobcat': 8,
#  'hawkular_hawkular-metrics': 8,
#  'apache_pulsar': 8,
#  'carrot2_carrot2': 8,
#  'SiGuiyang_spring-cloud-shop': 8,
#  'Dromara_hmily': 8,
#  'cloudstore_cloudstore': 8,
#  'liveontologies_elk-reasoner': 8,
#  'richfaces4_dev-examples': 8,
#  'structr_structr': 8,
#  'LSIR_gsn': 8,
#  'qcri-social_AIDR': 8,
#  'penguin-statistics_backend': 8,
#  'jberet_jsr352': 8,
#  'FINRAOS_herd': 8,
#  'a-schild_jave2': 8,
#  'oVirt_ovirt-engine': 8,
#  'codice_ddf': 8,
#  'feuyeux_jax-rs2-atup': 8,
#  'InMobi_grill': 8,
#  'locationtech_geogig': 8,
#  'apache_groovy': 8,
#  'redpen-cc_redpen': 8,
#  'martinschneider_justtestlah': 8,
#  'hudson_hudson-2.x': 8,
#  'sarl_sarl': 8,
#  'arcuri82_testing_security_development_enterprise_systems': 8,
#  'tyndale_step': 8,
#  'openscoring_openscoring': 8,
#  'apache_maven-resolver': 8,
#  'HPI-Information-Systems_Metanome': 8,
#  'gbif_checklistbank': 8,
#  'swagger-api_swagger-socket': 8,
#  'palominolabs_sf-api-connector': 8,
#  'AvanzaBank_astrix': 8,
#  'Cloudname_cloudname': 8,
#  'square_retrofit': 8,
#  'camsys_onebusaway-nyc': 8,
#  'aerogear_aerogear-unifiedpush-server': 8,
#  'qalingo_qalingo-engine': 8,
#  'FluentLenium_FluentLenium': 8,
#  'wocommunity_wonder': 8,
#  'shrinkwrap_resolver': 7,
#  'JRakNet_JRakNet': 7,
#  'littlefishercoder_littlefisher-system': 7,
#  'apache_openjpa': 7,
#  'keeps_roda': 7,
#  'johnewart_gearman-java': 7,
#  'apache_oodt': 7,
#  'openzipkin_brave': 7,
#  'mysticfall_pivot4j': 7,
#  'dcm4che_dcm4chee-arc-cdi': 7,
#  'networknt_light-4j': 7,
#  'protegeproject_protege': 7,
#  'krasserm_ipf': 7,
#  'scalecube_scalecube-services': 7,
#  'europeana_corelib': 7,
#  'eclipse_californium': 7,
#  'sdl_dxa-web-application-java': 7,
#  'bitronix_btm': 7,
#  'pingidentity_scim': 7,
#  'spring-projects_spring-data-examples': 7,
#  'apache_maven-indexer': 7,
#  'nuxeo-archives_nuxeo-features': 7,
#  'smartparam_smartparam': 7,
#  'apache_cayenne': 7,
#  'wso2-attic_product-emm': 7,
#  'DbMaintain_dbmaintain': 7,
#  'locationtech_geowave': 7,
#  'ZyorTaelon_eveapi': 7,
#  'tballison_lucene-addons': 7,
#  'knightliao_disconf': 7,
#  'dreedyman_Rio': 7,
#  'buschmais_extended-objects': 7,
#  'apache_geode': 7,
#  'Impetus_jumbune': 7,
#  'apache_commons-vfs': 7,
#  'JMaNGOS_JMaNGOS': 7,
#  'apache_plc4x': 7,
#  'appfuse_appfuse-light': 7,
#  'heroku_heroku.jar': 7,
#  'OpenRock_OpenIDM': 7,
#  'CONNECT-Solution_CONNECT': 7,
#  'RIPE-NCC_whois': 7,
#  'schemacrawler_SchemaCrawler': 7,
#  'richfaces_richfaces-sandbox': 7,
#  'lodsve_lodsve-framework': 7,
#  'colddew_micro-service': 7,
#  'stoicflame_enunciate': 7,
#  'twitter_ambrose': 6,
#  'JWebUnit_jwebunit': 6,
#  'helun_Ektorp': 6,
#  'jdillon_gshell': 6,
#  'dswarm_dswarm': 6,
#  'betfair_cougar': 6,
#  'apache_dubbo-spring-boot-project': 6,
#  'kiegroup_optaplanner': 6,
#  'HeZiCong_Photo': 6,
#  'elastic_support-diagnostics': 6,
#  'eugenp_tutorials': 6,
#  'gatein_gatein-portal': 6,
#  'Asqatasun_Contrast-Finder': 6,
#  'jboss-switchyard_switchyard': 6,
#  'e-ucm_eadventure': 6,
#  'hhru_nuts-and-bolts': 6,
#  'orfjackal_jumi-actors': 6,
#  'batfish_batfish': 6,
#  'couchbase_couchbase-lite-java': 6,
#  'astefanutti_metrics-cdi': 6,
#  'bcdev_beam': 6,
#  'florinpatrascu_micro': 6,
#  'techa03_goodsKill': 6,
#  'TNG_junit-dataprovider': 6,
#  'atlanmod_NeoEMF': 6,
#  'spring-projects_spring-data-mongodb': 6,
#  'apache_maven-archetype': 6,
#  'diennea_herddb': 6,
#  'jboss-switchyard_quickstarts': 6,
#  'vertigo-io_vertigo': 6,
#  'zkoss_zk': 6,
#  'apache_openmeetings': 6,
#  'GeoWebCache_geowebcache': 6,
#  'opendaylight_sfc': 6,
#  'rest-assured_rest-assured': 6,
#  'alien4cloud_alien4cloud': 6,
#  'eclipse_microprofile-health': 6,
#  'terrestris_shogun-core': 6,
#  'eclipse_microprofile-metrics': 6,
#  'liuxx001_bird-java': 6,
#  'OryxProject_oryx': 6,
#  'apache_jena': 6,
#  'Blazebit_blaze-persistence': 6,
#  'hekate-io_hekate': 6,
#  'apache_curator': 6,
#  'candlepin_candlepin': 6,
#  'forge_core': 6,
#  'eclipse_microprofile-jwt-auth': 6,
#  'cjbi_wetech-admin': 6,
#  'kevoree_kevoree': 6,
#  'kiegroup_drools': 6,
#  'apache_bval': 6,
#  'internetarchive_heritrix3': 6,
#  'ecsec_open-ecard': 6,
#  'lveci_nest': 5,
#  'jboss-developer_jboss-brms-quickstarts': 5,
#  'cowtowncoder_ClusterMate': 5,
#  'ronenhamias_scalecube-services': 5,
#  'korpling_ANNIS': 5,
#  'spring-projects_spring-data-cassandra': 5,
#  'kyriosdata_exemplo': 5,
#  'denimgroup_threadfix': 5,
#  'CoreMedia_jangaroo-tools': 5,
#  'SparkPost_java-sparkpost': 5,
#  'emsouza_gilead': 5,
#  'apache_synapse': 5,
#  'motown-io_motown': 5,
#  'apache_calcite': 5,
#  'spotify_heroic': 5,
#  'x-stream_xstream': 5,
#  'ff4j_ff4j': 5,
#  'apache_wink': 5,
#  'sialcasa_mvvmFX': 5,
#  'adobe_aem-core-wcm-components': 5,
#  'facebookarchive_swift': 5,
#  'esigate_esigate': 5,
#  'projectodd_wunderboss': 5,
#  'apache_incubator-atlas': 5,
#  'BroadleafCommerce_BroadleafCommerce': 5,
#  'projectodd_stilts': 5,
#  'RBGKew_Reconciliation-and-Matching-Framework': 5,
#  'SeleniumHQ_selenium': 5,
#  'qos-ch_logback': 5,
#  'fakereplace_fakereplace': 5,
#  'json-path_JsonPath': 5,
#  'joelittlejohn_jsonschema2pojo': 5,
#  'Alfresco_gytheio': 5,
#  'inspire-software_yes-cart': 5,
#  'apache_atlas': 5,
#  'jbosstools_jbosstools-openshift': 5,
#  'yahoo_omid': 5,
#  'societies_SOCIETIES-Platform': 5,
#  'gazbert_bxbot': 5,
#  'visallo_vertexium': 5,
#  'eclipse_microprofile-opentracing': 5,
#  'johncarl81_transfuse': 5,
#  'webx_citrus': 5,
#  'softwaremill_softwaremill-common': 5,
#  'SR-G_sonos-java': 5,
#  'apache_tinkerpop': 5,
#  'buddycloud_buddycloud-media-server': 5,
#  'SonarSource_sonar-java': 5,
#  'OpenAPITools_openapi-generator': 5,
#  'spring-cloud_spring-cloud-task': 5,
#  'fuinorg_event-store-commons': 5,
#  'arquillian_arquillian-extension-persistence': 5,
#  'dkpro_dkpro-jwpl': 5,
#  'nlpie_biomedicus': 5,
#  'apache_tiles': 5,
#  'zolyfarkas_spf4j': 5,
#  'dockstore_dockstore': 5,
#  'codehaus-cargo_cargo': 4,
#  'fi-muni_PA165': 4,
#  'smallrye_smallrye-metrics': 4,
#  'PhoenicisOrg_phoenicis': 4,
#  'hal_elemento': 4,
#  'KengoTODA_findbugs-slf4j': 4,
#  'apache_olingo-odata4': 4,
#  'c2mon_c2mon': 4,
#  'powermock_powermock': 4,
#  'Azure_autorest-clientruntime-for-java': 4,
#  'eclipse_microprofile-rest-client': 4,
#  'geotools_geotools': 4,
#  '55minutes_fiftyfive-wicket': 4,
#  'dhis2_dhis2-core': 4,
#  'eclipse_microprofile-fault-tolerance': 4,
#  'wildfly-extras_wildfly-camel-examples': 4,
#  'OpenWiseSolutions_openhub-framework': 4,
#  'wso2_carbon-kernel': 4,
#  'la-team_light-admin': 4,
#  'CloudSlang_score': 4,
#  'SAP_olingo-jpa-processor-v4': 4,
#  'wildfly-extras_wildfly-microprofile-config': 4,
#  'apache_tapestry-5': 4,
#  'apache_rave': 4,
#  'spring-projects_spring-social-samples': 4,
#  'graphaware_neo4j-framework': 4,
#  'hyperledger_quilt': 4,
#  'sonyxperiadev_gerrit-events': 4,
#  'RestComm_Restcomm-Connect': 4,
#  'easymock_easymock': 4,
#  'jsonld-java_jsonld-java': 4,
#  'OpenIotOrg_openiot': 4,
#  'eclipse_rdf4j': 4,
#  'salesforce_kafka-junit': 4,
#  'jdemetra_jdemetra-app': 4,
#  'locationtech_spatial4j': 4,
#  'pulsarIO_jetstream': 4,
#  'apache_incubator-sentry': 4,
#  'Silverpeas_Silverpeas-Core': 4,
#  'ORCID_ORCID-Source': 4,
#  'smallrye_smallrye-jwt': 4,
#  'pbauerochse_youtrack-worklog-viewer': 4,
#  'Evolveum_midpoint': 4,
#  'strimzi_strimzi-kafka-operator': 4,
#  '52North_WPS': 4,
#  'marvin-we_steem-java-api-wrapper': 4,
#  'vert-x3_vertx-guide-for-java-devs': 4,
#  'kohsuke_jenkins': 4,
#  'php-coder_mystamps': 4,
#  'TechEmpower_FrameworkBenchmarks': 4,
#  'getsentry_sentry-java': 4,
#  'jsfunit_jsfunit': 4,
#  'kumuluz_kumuluzee-samples': 4,
#  'Claudenw_junit-contracts': 4,
#  'pnowy_NativeCriteria': 4,
#  'zalando_logbook': 4,
#  'kagkarlsson_db-scheduler': 4,
#  'javahongxi_whatsmars': 4,
#  'graphhopper_jsprit': 4,
#  'apache_incubator-omid': 4,
#  'eclipse_winery': 4,
#  'Norconex_collector-http': 4,
#  'javanna_elasticsearch-river-solr': 4,
#  'meraki-analytics_orianna': 4,
#  'huxi_lilith': 4,
#  'jcustenborder_connect-utils': 4,
#  'pentaho_big-data-plugin': 4,
#  'limone_MailJimp': 4,
#  'brianway_webporter': 4,
#  'te-con_ehour': 4,
#  'apache_hadoop-common': 4,
#  'flyway_flyway': 4,
#  'igor-baiborodine_java-various-examples': 4,
#  'yammer_breakerbox': 4,
#  'platonai_pulsar': 4,
#  'jboss-developer_jboss-jdg-quickstarts': 4,
#  'RestComm_media-core': 4,
#  'datastax_java-driver': 4,
#  'puppetlabs_geppetto': 4,
#  'kennycason_kumo': 4,
#  'barakb_asyncrmi': 4,
#  'jnidzwetzki_crypto-bot': 4,
#  'yegor256_rexsl': 4,
#  'jpmml_jpmml-model': 4,
#  'timboudreau_nb-nodejs': 4,
#  'holodeck-b2b_Holodeck-B2B': 4,
#  'hugegraph_hugegraph': 4,
#  'latexdraw_latexdraw': 4,
#  'apache_maven-2': 4,
#  'NumberFour_n4js': 4,
#  'apache_cocoon': 4,
#  'apache_nifi-minifi': 4,
#  'gotify_android': 4,
#  'SonarSource_SonarJS': 4,
#  'woorea_openstack-java-sdk': 4,
#  'OpenTOSCA_container': 4,
#  'onelogin_java-saml': 4,
#  'plus-provenance_plus': 4,
#  'alexo_wro4j': 4,
#  'wisdom-framework_wisdom': 4,
#  'spring-projects_spring-amqp-samples': 4,
#  'torakiki_sejda': 4,
#  'mozilla-metrics_akela': 4,
#  'apache_qpid': 4,
#  'robward-scisys_sldeditor': 4,
#  'cerner_beadledom': 3,
#  'twitter_elephant-bird': 3,
#  'xuxueli_xxl-api': 3,
#  'struts-community-plugins_struts2-bootstrap': 3,
#  'ops4j_org.ops4j.pax.jdbc': 3,
#  'springdoc_springdoc-openapi': 3,
#  'TexasDigitalLibrary_Vireo': 3,
#  'xuxueli_xxl-conf': 3,
#  'terasolunaorg_terasoluna-tourreservation': 3,
#  'dandelion_dandelion-datatables': 3,
#  'before_uadetector': 3,
#  'spring-projects_spring-android-samples': 3,
#  'carml_carml': 3,
#  'haifeiWu_lightconf': 3,
#  'ICIJ_datashare': 3,
#  'ldp4j_ldp4j': 3,
#  'mtedone_podam': 3,
#  'apache_logging-log4j-audit': 3,
#  'aseovic_coherence-tools': 3,
#  'spring-projects_spring-batch-admin': 3,
#  'minnal_minnal': 3,
#  'hypercube1024_firefly': 3,
#  'apache_falcon': 3,
#  'oracle_opengrok': 3,
#  'opendaylight_ovsdb': 3,
#  'kermitt2_entity-fishing': 3,
#  'coheigea_testcases': 3,
#  'lukas-krecan_JsonUnit': 3,
#  'ARMmbed_java-coap': 3,
#  'Azure_azure-cosmosdb-java': 3,
#  'zalando_problem': 3,
#  'eclipse_jnosql-artemis-extension': 3,
#  'ggeorgovassilis_spring-rest-invoker': 3,
#  'Jnoee_coo': 3,
#  'resty-gwt_resty-gwt': 3,
#  'h908714124_jbock': 3,
#  'ssaring_sportstracker': 3,
#  'qala-io_datagen': 3,
#  'neo4j_neo4j-java-driver': 3,
#  'apache_phoenix': 3,
#  'javadev_underscore-java': 3,
#  'palladian_palladian': 3,
#  'apache_fluo': 3,
#  'awslabs_aws-athena-query-federation': 3,
#  'swagger-api_swagger-core': 3,
#  'arquillian_arquillian-extension-drone': 3,
#  'eclipse-ee4j_jsonp': 3,
#  'SonarSource_sonar-python': 3,
#  'mycila_guice': 3,
#  'groovy_gmaven': 3,
#  'javaee-samples_javaee8-samples': 3,
#  'apache_incubator-shardingsphere': 3,
#  'okta_okta-sdk-java': 3,
#  'kiegroup_optaweb-employee-rostering': 3,
#  'seam_rest': 3,
#  'owlcs_owlapi': 3,
#  'shazam_shazamcrest': 3,
#  'wso2_msf4j': 3,
#  'NukkitX_Nukkit': 3,
#  'umlet_umlet': 3,
#  'spring-projects_spring-data-commons': 3,
#  'cowtowncoder_java-merge-sort': 3,
#  'PebbleTemplates_pebble': 3,
#  'kingston-csj_im': 3,
#  'telefonicaid_netphony-topology': 3,
#  'unidal_frameworks': 3,
#  'testinfected_simple-petstore': 3,
#  'apache_ace': 3,
#  'sebastiangraf_treetank': 3,
#  'wosyingjun_beauty_ssm_cluster': 3,
#  'contentful_contentful.java': 3,
#  'JMRI_JMRI': 3,
#  'hyperic_hq': 3,
#  'alibaba_jstorm': 3,
#  'square_okhttp': 3,
#  'contentful_contentful-management.java': 3,
#  'xipki_xipki': 3,
#  'regunathb_Trooper': 3,
#  'camelinaction_camelinaction2': 3,
#  'Qi4j_qi4j-sdk': 3,
#  'ctco_cukes': 3,
#  'randomizedtesting_randomizedtesting': 3,
#  'spring-cloud_spring-cloud-contract': 3,
#  'datacite_mds': 3,
#  'eclipse_rdf4j-storage': 3,
#  'astefanutti_metrics-aspectj': 3,
#  'apache_drill': 3,
#  'kiegroup_kie-wb-common': 3,
#  'jbehave_jbehave-core': 3,
#  'difi_datahotel': 3,
#  'Azure_azure-functions-java-worker': 3,
#  'phoenixctms_ctsms': 3,
#  'apache_crunch': 3,
#  'xwiki_xwiki-rendering': 3,
#  'tech-advantage_sonar-gerrit-plugin': 3,
#  'apache_calcite-avatica': 3,
#  'cloudfoundry_cf-java-client': 3,
#  'teamed_qulice': 3,
#  'apache_uima-uimafit': 3,
#  'richfaces4_build': 3,
#  'apache_polygene-java': 3,
#  'Norconex_importer': 3,
#  'fortify-ps_FortifyBugTrackerUtility': 3,
#  'silb_shiro-jersey': 3,
#  'SAP_cloud-s4-sdk-book': 3,
#  'nuxeo-archives_nuxeo-core': 3,
#  'liquibase_liquibase': 3,
#  'voyages-sncf-technologies_hesperides': 3,
#  'goldmansachs_obevo': 3,
#  'FasterXML_jackson-jaxrs-providers': 3,
#  'frenchc_jetm': 3,
#  'xuxueli_xxl-job': 3,
#  'FamilySearch_gedcomx-java': 3,
#  'CodeSolid_tutorials': 3,
#  'nebhale_JsonPath': 2,
#  'serval-snt-uni-lu_DroidRA': 2,
#  'itesla_ipst': 2,
#  'indeedeng_proctor': 2,
#  'openimaj_openimaj': 2,
#  'saalfeldlab_render': 2,
#  'SmartDataAnalytics_jena-sparql-api': 2,
#  'stephanenicolas_robospice': 2,
#  'dana-i2cat_opennaas': 2,
#  'seznam_euphoria': 2,
#  'Zubnix_trinityshell': 2,
#  'google_guice': 2,
#  'roboguice_roboguice': 2,
#  'OpenLiberty_ci.maven': 2,
#  'castlabs_dashencrypt': 2,
#  'nuxeo-archives_nuxeo-runtime': 2,
#  'gooddata_gooddata-java': 2,
#  'childe_hangout': 2,
#  'mpusher_mpush': 2,
#  'tackley_dbdeploy': 2,
#  'ocpsoft_rewrite': 2,
#  'lenskit_lenskit': 2,
#  'apache_giraph': 2,
#  'arquillian_continuous-enterprise-development': 2,
#  'sbmlteam_jsbml': 2,
#  'stormpath_stormpath-sdk-java': 2,
#  'aerogear_aerogear-simplepush-server': 2,
#  'javafx-maven-plugin_javafx-rest-archetype': 2,
#  'indeedeng_status': 2,
#  'Stratio_cassandra-lucene-index': 2,
#  'TremoloSecurity_OpenUnison': 2,
#  'google_truth': 2,
#  'vmware-serengeti_serengeti-ws': 2,
#  'Dempsy_dempsy': 2,
#  'qos-ch_logback-extensions': 2,
#  'TheCookieLab_poloniex-api-java': 2,
#  'mbedward_jaitools': 2,
#  'pilosa_java-pilosa': 2,
#  'wikimedia_wikidata-query-rdf': 2,
#  'elastic_elasticsearch': 2,
#  'subes_invesdwin-context-persistence': 2,
#  'jenkinsci_gerrit-trigger-plugin': 2,
#  'HubSpot_Horizon': 2,
#  'naver_pinpoint': 2,
#  'deruelle_mobicents': 2,
#  'RestComm_jdiameter': 2,
#  'kubernetes-client_java': 2,
#  'greenmail-mail-test_greenmail': 2,
#  'pierre_eventtracker': 2,
#  'mslosarz_nextrtc-signaling-server': 2,
#  'whirlwind-match_fuzzydb': 2,
#  'joyent_java-manta': 2,
#  'BuycraftPlugin_BuycraftX': 2,
#  'orbisgis_orbisgis': 2,
#  'Transitime_core': 2,
#  'apache_maven-doxia': 2,
#  'castlemock_castlemock': 2,
#  'link-it_GovPay': 2,
#  'jimmoores_quandl4j': 2,
#  'BatooOrg_BatooJPA': 2,
#  'hammock-project_hammock': 2,
#  'jwpttcg66_redis-game-transaction': 2,
#  'vt-middleware_ldaptive': 2,
#  'proarc_proarc': 2,
#  'dlemmermann_PreferencesFX': 2,
#  'nutzam_nutzboot': 2,
#  'pocrd_net.pocrd.core': 2,
#  'infiniteautomation_ma-core-public': 2,
#  'openxc_openxc-android': 2,
#  'joinfaces_joinfaces': 2,
#  'qameta_rarc': 2,
#  'adobe_S3Mock': 2,
#  'javaee_jaxb-v2': 2,
#  'find-sec-bugs_find-sec-bugs': 2,
#  'afimb_chouette': 2,
#  'CenterForOpenScience_cas-overlay': 2,
#  'CloverETL_CloverETL-Engine': 2,
#  'mdeinum_spring-utils': 2,
#  'ForgeRock_openidm-community-edition': 2,
#  'Mahoney_sysout-over-slf4j': 2,
#  'eclipse_tycho': 2,
#  'n8han_Databinder-for-Wicket': 2,
#  'KostyaSha_github-integration-plugin': 2,
#  'seam_faces': 2,
#  'rdiachenko_jlv': 2,
#  'yahoo_gondola': 2,
#  'kitodo_kitodo-production': 2,
#  'torodb_mongowp': 2,
#  'asascience-open_ncSOS': 2,
#  'impactcentre_interoperability-framework': 2,
#  'torodb_server': 2,
#  'SAP_cf-java-logging-support': 2,
#  'dadoonet_fscrawler': 2,
#  'zeebe-io_spring-zeebe': 2,
#  'moodysalem_java-phantomjs-wrapper': 2,
#  'codecentric_chaos-monkey-spring-boot': 2,
#  'PerimeterX_perimeterx-java-sdk': 2,
#  'GoogleCloudPlatform_java-docs-samples': 2,
#  'apache_servicecomb-samples': 2,
#  'hazelcast_hazelcast-simulator': 2,
#  'konsoletyper_teavm-flavour': 2,
#  'KuroChan1998_Student-Information-Administration-System': 2,
#  'xubinux_xbin-store': 2,
#  'DuanJiaNing_BlogSystem': 2,
#  'jpmorganchase_tessera': 2,
#  'quartz-scheduler_quartz': 2,
#  'thiki-org_thiki-kanban-backend': 2,
#  'woemler_spring-blog': 2,
#  'opendaylight_yangtools': 2,
#  'apache_abdera': 2,
#  'spring-social_spring-social-google': 2,
#  'entando_entando-archetypes': 2,
#  'Top-Q_jsystem': 2,
#  'apache_maven-plugin-tools': 2,
#  'ryanbrainard_richsobjects': 2,
#  'olivergierke_spring-restbucks-training': 2,
#  'cbeust_testng': 2,
#  'ralscha_spring4ws-demos': 2,
#  'BSC-RUS_AuTe-Framework': 2,
#  'OAuth-Apis_apis': 2,
#  'citerus_dddsample-core': 2,
#  'sqshq_piggymetrics': 2,
#  'Nepxion_Aquarius': 2,
#  'ccavanaugh_jgnash': 2,
#  'HotelsDotCom_circus-train': 2,
#  'jdillon_gossip': 2,
#  'adobe_aem-core-cif-components': 2,
#  'languagetool-org_languagetool': 2,
#  'sebastianbenz_Jnario': 2,
#  'bytemanproject_byteman': 2,
#  'apache_tomcat-maven-plugin': 2,
#  'IoT-Technology_Groza': 2,
#  'linkedin_sensei': 2,
#  'spring-io_initializr': 2,
#  'hantsy_spring4-sandbox': 2,
#  'onepiecex_session-share': 2,
#  'jloisel_elastic-crud': 2,
#  'jooby-project_jooby': 2,
#  'apache_olingo-odata2': 2,
#  'yahoo_athenz': 2,
#  'iyzico_iyzipay-java': 2,
#  'Unicon_cas-addons': 2,
#  'dianping_pigeon1': 2,
#  'gwt-test-utils_gwt-test-utils': 2,
#  'joel-costigliola_assertj-assertions-generator-maven-plugin': 2,
#  'rakam-io_rakam': 2,
#  'confluentinc_camus': 2,
#  'vmi_selenese-runner-java': 2,
#  'square_dagger': 2,
#  'ucarGroup_DataLink': 2,
#  'unic_neba': 2,
#  'j-easy_easy-batch': 2,
#  'joel-costigliola_assertj-swing': 2,
#  'hoko_hoko-android': 2,
#  'SonarSource_sonar-php': 2,
#  'jenkinsci_git-client-plugin': 2,
#  'Accenture_mercury': 2,
#  'fang-yan-peng_eagle': 2,
#  'moxi624_mogu_blog_v2': 2,
#  'sofastack_sofa-rpc': 2,
#  'terrier-org_terrier-core': 2,
#  'hank-whu_rpc-benchmark': 2,
#  'jobxhub_JobX': 2,
#  'timurstrekalov_saga': 2,
#  '1and1_cosmo': 2,
#  'playn_playn': 2,
#  'ProjectAGI_agi': 2,
#  'release-engineering_pom-manipulation-ext': 2,
#  'Renanse_Ardor3D': 2,
#  'powsybl_powsybl-core': 2,
#  'kite-sdk_kite': 2,
#  'nielsbasjes_yauaa': 2,
#  'pjklauser_protobuf-rpc-pro': 2,
#  'ekoontz_hadoop-common': 2,
#  'ltsopensource_light-task-scheduler': 2,
#  'terasolunaorg_terasoluna-gfw': 2,
#  'netceteragroup_valdr-bean-validation': 2,
#  'sanluan_PublicCMS': 2,
#  'OpenNMS_newts': 2,
#  'tylanbin_platform-ng': 2,
#  'hibernate_hibernate-tools': 2,
#  'jetoile_hadoop-unit': 2,
#  'spring-cloud_spring-cloud-gcp': 2,
#  'takari_takari-plugin-testing-project': 2,
#  'hibernate_hibernate-commons-annotations': 2,
#  'Asqatasun_Asqatasun': 2,
#  'opengeospatial_geoapi': 2,
#  'RohanNagar_thunder': 2,
#  'apache_maven-enforcer': 2,
#  'Codearte_catch-exception': 2,
#  'picketbox_picketbox': 2,
#  'kunai-consulting_KeyStor': 2,
#  'kyriosdata_saep': 2,
#  'Drombler_drombler-fx': 2,
#  'ks-no_eventstore2': 2,
#  'spotify_zoltar': 2,
#  'wayshall_onetwo': 2,
#  'hibernate_hibernate-orm': 2,
#  'VIPJoey_doe': 2,
#  'emmanuelbernard_hibernate-core-ogm': 2,
#  'cpesch_RouteConverter': 2,
#  'exonum_exonum-java-binding': 2,
#  'jklingsporn_vertx-jooq': 2,
#  'vmware_hillview': 2,
#  'intendia-oss_rxjava-gwt': 2,
#  'neo4j_neo4j-ogm': 2,
#  'xwiki-contrib_wiki30': 2,
#  'apache_zeppelin': 2,
#  'wso2_testgrid': 2,
#  'citrusframework_citrus-samples': 2,
#  'eclipse-ee4j_security-api': 2,
#  'apigee_apigee-deploy-maven-plugin': 2,
#  'leadpony_justify': 2,
#  'javaparser_javaparser': 2,
#  'Jahia_dxm': 2,
#  'spring-projects_spring-webflow': 2,
#  'richfaces_richfaces-archetypes': 2,
#  'vivo-project_Vitro': 2,
#  'codenvy_codenvy': 2,
#  'dolfdijkstra_gst-foundation': 2,
#  'zalando_jackson-datatype-money': 2,
#  'threeten-jaxb_threeten-jaxb': 2,
#  'OpenSextant_Xponents': 2,
#  'apereo_java-cas-client': 2,
#  'apache_sling-org-apache-sling-app-cms': 2,
#  'stevespringett_Alpine': 2,
#  'andreschaffer_event-sourcing-cqrs-examples': 2,
#  'wocommunity_wolips': 2,
#  'eclipse-ee4j_krazo': 2,
#  'Impetus_Kundera': 2,
#  'dashbuilder_dashbuilder': 2,
#  'SmartBear_readyapi4j': 2,
#  'codice_alliance': 2,
#  'iotaledger_iota-java': 2,
#  'DozerMapper_dozer': 2,
#  'Internet2_grouper': 2,
#  'agilebirds_openflexo': 2,
#  'kiegroup_jbpm-wb': 2,
#  'jadler-mocking_jadler': 2,
#  'apache_servicemix4-features': 2,
#  'hyperic_hqapi': 2,
#  'teknux-org_jetty-bootstrap': 2,
#  'JakduK_jakduk-api': 2,
#  'MissionCriticalCloud_cosmic': 2,
#  'wjggwm_webside': 2,
#  'jenkinsci_swarm-plugin': 2,
#  'apache_james-jdkim': 2,
#  'anthonydahanne_ReGalAndroid': 2,
#  'nuodb_migration-tools': 2,
#  'EvoSuite_evosuite': 2,
#  'RestComm_jain-slee': 2,
#  'crawljax_crawljax': 2,
#  'extjwnl_extjwnl': 2,
#  'pentaho_marketplace': 2,
#  'teverett_jvmBASIC': 2,
#  'mindwind_craft-atom': 2,
#  'OfficeDev_ews-java-api': 2,
#  'nathanmarz_dfs-datastores': 2,
#  'eclipse_xtext-xtend': 2,
#  'envoyproxy_java-control-plane': 2,
#  'anno4j_anno4j': 2,
#  'mesosphere_cassandra-mesos-deprecated': 2,
#  'sebastiangraf_jSCSI': 2,
#  '52North_series-rest-api': 1,
#  'opengeospatial_teamengine': 1,
#  'apache_cloudstack': 1,
#  'imglib_imglib2': 1,
#  'HotelsDotCom_bull': 1,
#  'alibaba_Sentinel': 1,
#  'nowina-solutions_nexu': 1,
#  'a466350665_smart': 1,
#  'leonchen83_redis-replicator': 1,
#  'ManfredTremmel_gwt-bean-validators': 1,
#  'arquillian_arquillian-droidium': 1,
#  'wfh45678_radar': 1,
#  'sps_mustache-spring-view': 1,
#  'googleapis_google-oauth-java-client': 1,
#  'apache_dubbo-admin': 1,
#  'eclipse_microprofile-open-api': 1,
#  'ScaCap_spring-auto-restdocs': 1,
#  'apache_dubbo-samples': 1,
#  ...}

# %%
len(list(filter(lambda x: check[x] > 1, check)))
# Out:
# 982

# %%
982 / 1480
# Out:
# 0.6635135135135135

# %%
one_df = original_df[original_df["repoName"].isin(repo_with_only_one_migration)]
one_df
# Out:
#           id                                         fromLib  \
# 84        84                                         asm:asm
# 88        88                                         asm:asm
# 89        89                                         asm:asm
# 90        90                                         asm:asm
# 93        93                                         asm:asm
# ...      ...                                             ...
# 14155  14155                                        rhino:js
# 14160  14160                                        rhino:js
# 14174  14174  ru.yandex.qatools.properties:properties-loader
# 14270  14270                               velocity:velocity
# 14288  14288                                     xalan:xalan
#
#                                toLib  \
# 84                   org.ow2.asm:asm
# 88                   org.ow2.asm:asm
# 89                   org.ow2.asm:asm
# 90                   org.ow2.asm:asm
# 93           org.ow2.asm:asm-commons
# ...                              ...
# 14155              org.mozilla:rhino
# 14160              org.mozilla:rhino
# 14174  ru.qatools.commons:properties
# 14270   org.apache.velocity:velocity
# 14288    net.sourceforge.saxon:saxon
#
#                                              repoName  \
# 84                                eclipse_sisu.inject
# 88                                noctarius_Lightning
# 89                                         oblac_jodd
# 90                                    Cognifide_Slice
# 93                                      hcoles_pitest
# ...                                               ...
# 14155                        happygiraffe_jslint4java
# 14160                     picocontainer_picocontainer
# 14174  yandex-qatools_hamcrest-pojo-matcher-generator
# 14270                               mojohaus_webstart
# 14288                                epimorphics_elda
#
#                                 fileName  \
# 84       org.eclipse.sisu.inject/pom.xml
# 88                               pom.xml
# 89                               pom.xml
# 90                    slice-core/pom.xml
# 93                        pitest/pom.xml
# ...                                  ...
# 14155                            pom.xml
# 14160        script/script-rhino/pom.xml
# 14174  feature-matcher-generator/pom.xml
# 14270      webstart-maven-plugin/pom.xml
# 14288                elda-common/pom.xml
#
#                                     startCommit  \
# 84     01ca345463fdaee4d5d72293bb7679fb5bc815ec
# 88     8ec806a0986990bd80e609b62ec055753fc97e6a
# 89     c057522ed029f1b223207eb22ba54dbd80623bba
# 90     c4cffec426469641b6652f9ffb1b5b34f7639329
# 93     0d638d02c051094ce1e8532e83449735cf6ae2f4
# ...                                         ...
# 14155  86a643ff774b2462c0032b1feaeafb1dd09d6266
# 14160  d1544d25ba23121ddf43073f62f7ca7330991550
# 14174  cc7a474d3ea53164d28b4a1b23c25989982e7d03
# 14270  e6d0944e489b7849c31957b2b41ca91044aeba65
# 14288  e07982e05c1d9900aa91c87f28ec7bd0ba0a8f0f
#
#                                       endCommit  \
# 84     01ca345463fdaee4d5d72293bb7679fb5bc815ec
# 88     8ec806a0986990bd80e609b62ec055753fc97e6a
# 89     c057522ed029f1b223207eb22ba54dbd80623bba
# 90     c4cffec426469641b6652f9ffb1b5b34f7639329
# 93     0d638d02c051094ce1e8532e83449735cf6ae2f4
# ...                                         ...
# 14155  86a643ff774b2462c0032b1feaeafb1dd09d6266
# 14160  d1544d25ba23121ddf43073f62f7ca7330991550
# 14174  cc7a474d3ea53164d28b4a1b23c25989982e7d03
# 14270  e6d0944e489b7849c31957b2b41ca91044aeba65
# 14288  e07982e05c1d9900aa91c87f28ec7bd0ba0a8f0f
#
#                                       startCommitChanges  \
# 84                            +org.ow2.asm:asm\n-asm:asm
# 88                            +org.ow2.asm:asm\n-asm:asm
# 89                            +org.ow2.asm:asm\n-asm:asm
# 90                            +org.ow2.asm:asm\n-asm:asm
# 93     +org.ow2.asm:asm-commons\n+org.ow2.asm:asm-ana...
# ...                                                  ...
# 14155                      +org.mozilla:rhino\n-rhino:js
# 14160                      +org.mozilla:rhino\n-rhino:js
# 14174  +ru.qatools.commons:properties\n-ru.yandex.qat...
# 14270  +org.apache.velocity:velocity\n-velocity:velocity
# 14288  +net.sourceforge.saxon:saxon\n+net.sf.saxon:Sa...
#
#                                         endCommitChanges  \
# 84                            +org.ow2.asm:asm\n-asm:asm
# 88                            +org.ow2.asm:asm\n-asm:asm
# 89                            +org.ow2.asm:asm\n-asm:asm
# 90                            +org.ow2.asm:asm\n-asm:asm
# 93     +org.ow2.asm:asm-commons\n+org.ow2.asm:asm-ana...
# ...                                                  ...
# 14155                      +org.mozilla:rhino\n-rhino:js
# 14160                      +org.mozilla:rhino\n-rhino:js
# 14174  +ru.qatools.commons:properties\n-ru.yandex.qat...
# 14270  +org.apache.velocity:velocity\n-velocity:velocity
# 14288  +net.sourceforge.saxon:saxon\n+net.sf.saxon:Sa...
#
#                                       startCommitMessage  \
# 84                         Bug 406177: Upgrade to ASM4\n
# 88                            Moved ASM lib to version 4
# 89                                 Migrated to ASM 4.1\n
# 90     SLICE-106\nUpgrade ASM to support Java 8 (bump...
# 93                                  upgrade asm to 4.0\n
# ...                                                  ...
# 14155                          Switch to newest rhino.\n
# 14160  Updated Scripting Engines:\n\nGroovy to 2.1.4:...
# 14174  Merge pull request #16 from yandex-qatools/j8\...
# 14270  use org.apache.velocity instead of old velocit...
# 14288                    Switched from xalan to saxon.\n
#
#                                         endCommitMessage startCommitTime  \
# 84                         Bug 406177: Upgrade to ASM4\n      2013-04-21
# 88                            Moved ASM lib to version 4      2012-08-12
# 89                                 Migrated to ASM 4.1\n      2012-12-19
# 90     SLICE-106\nUpgrade ASM to support Java 8 (bump...      2015-03-20
# 93                                  upgrade asm to 4.0\n      2012-09-27
# ...                                                  ...             ...
# 14155                          Switch to newest rhino.\n      2011-08-04
# 14160  Updated Scripting Engines:\n\nGroovy to 2.1.4:...      2013-06-14
# 14174  Merge pull request #16 from yandex-qatools/j8\...      2016-03-10
# 14270  use org.apache.velocity instead of old velocit...      2011-11-01
# 14288                    Switched from xalan to saxon.\n      2014-06-25
#
#       endCommitTime  Category       repoOwner                    repoSplitName
# 84       2013-04-21         5         eclipse                      sisu.inject
# 88       2012-08-12         5       noctarius                        Lightning
# 89       2012-12-19         5           oblac                             jodd
# 90       2015-03-20         5       Cognifide                            Slice
# 93       2012-09-27         5          hcoles                           pitest
# ...             ...       ...             ...                              ...
# 14155    2011-08-04        65    happygiraffe                      jslint4java
# 14160    2013-06-14        65   picocontainer                    picocontainer
# 14174    2016-03-10        42  yandex-qatools  hamcrest-pojo-matcher-generator
# 14270    2011-11-01        51        mojohaus                         webstart
# 14288    2014-06-25        77     epimorphics                             elda
#
# [368 rows x 16 columns]

# %%
one_df.to_csv("demo.csv", index=False)

# %%
sampled_df = one_df.sample(n=20, random_state=42)
sampled_df
# Out:
#           id                                            fromLib  \
# 3878    3878                                 javax.servlet:jstl
# 729      729                     com.github.sgroschupf:zkclient
# 469      469                                  com.alibaba:dubbo
# 11215  11215                          org.postgresql:postgresql
# 1013    1013                                  com.h2database:h2
# 6683    6683                             org.apache.derby:derby
# 1412    1412                         com.sun.jersey:jersey-core
# 2243    2243                          commons-lang:commons-lang
# 3618    3618                          javax.mail:javax.mail-api
# 2418    2418                          commons-lang:commons-lang
# 7095    7095               org.apache.tomcat:tomcat-servlet-api
# 884      884                          com.google.code.gson:gson
# 3616    3616                          javax.json:javax.json-api
# 1009    1009                                  com.h2database:h2
# 3175    3175             io.dropwizard.metrics:metrics-graphite
# 6562    6562                   org.apache.commons:commons-dbcp2
# 84        84                                            asm:asm
# 6782    6782                        org.apache.kafka:kafka_2.11
# 13859  13859  org.springframework.security.oauth:spring-secu...
# 1925    1925              commons-httpclient:commons-httpclient
#
#                                               toLib  \
# 3878                javax.servlet.jsp.jstl:jstl-api
# 729                             com.101tec:zkclient
# 469                          org.apache.dubbo:dubbo
# 11215          org.mariadb.jdbc:mariadb-java-client
# 1013                     mysql:mysql-connector-java
# 6683                              com.h2database:h2
# 1412        org.glassfish.jersey.core:jersey-client
# 2243               org.apache.commons:commons-lang3
# 3618                        com.sun.mail:javax.mail
# 2418               org.apache.commons:commons-lang3
# 7095                javax.servlet:javax.servlet-api
# 884                            com.alibaba:fastjson
# 3616                       org.glassfish:javax.json
# 1009                     mysql:mysql-connector-java
# 3175   io.micrometer:micrometer-registry-prometheus
# 6562                            com.zaxxer:HikariCP
# 84                                  org.ow2.asm:asm
# 6782         org.springframework.kafka:spring-kafka
# 13859                          io.jsonwebtoken:jjwt
# 1925           org.apache.httpcomponents:httpclient
#
#                                        repoName  \
# 3878                      richfaces4_components
# 729                    killme2008_Metamorphosis
# 469                          apache_dubbo-admin
# 11215                      FundRequest_platform
# 1013                               JoeCao_qbike
# 6683              wso2_ballerina-message-broker
# 1412                  urbanairship_java-library
# 2243                        JULIELab_jcore-base
# 3618                        HubSpot_Singularity
# 2418                            estatio_estatio
# 7095                            cegeka_batchers
# 884                            hippo-band_hippo
# 3616                        stanfordnlp_CoreNLP
# 1009                        nilzao_soapbox-race
# 3175                  HotelsDotCom_data-highway
# 6562                 plan-player-analytics_Plan
# 84                          eclipse_sisu.inject
# 6782                   daydreamdev_seconds-kill
# 13859  gravitee-io_graviteeio-access-management
# 1925                             EmiteGWT_emite
#
#                                                 fileName  \
# 3878                                      parent/pom.xml
# 729                                              pom.xml
# 469                                              pom.xml
# 11215                                       core/pom.xml
# 1013                                          uc/pom.xml
# 6683                            modules/launcher/pom.xml
# 1412                                             pom.xml
# 2243                  jcore-lingpipegazetteer-ae/pom.xml
# 3618                                             pom.xml
# 2418                                             pom.xml
# 7095    taxcalculator/taxcalculator-presentation/pom.xml
# 884                                 hippo-common/pom.xml
# 3616                                             pom.xml
# 1009                                             pom.xml
# 3175             monitoring/kafka-offset-metrics/pom.xml
# 6562                                        Plan/pom.xml
# 84                       org.eclipse.sisu.inject/pom.xml
# 6782                                             pom.xml
# 13859  gravitee-am-management-api/gravitee-am-managem...
# 1925                                             pom.xml
#
#                                     startCommit  \
# 3878   82b5c6d243ac4b566ec9cfbf5cbe3a306481000d
# 729    f6254da1916ec87ac12fd5da1469408e91aa320a
# 469    995e06b547cb7554c99deb3129fca19b2c35aa8b
# 11215  101f86c7e7786dcfd0accdf4083f904224329fa5
# 1013   ba1ba24af6b9a69ea6ed4d76ae61faf9191e4c0f
# 6683   01a74c93a09157b00179bb2bb10acb8a2771bb9d
# 1412   3389fb4a4b1cc5c130ac9fa1f948bb2488156cdf
# 2243   73b0517f2cfcc20b5468722804e19591310ce401
# 3618   67741baebf24971105d4a7db57a3387badad2c35
# 2418   df5ad79e3f5d9b8b63411ea91e44f72d2e86b0e0
# 7095   11a1aca69df0adf5172cb18263ba20ed4806817b
# 884    227ca6473aac1893d14cacf9cd9e4aea7c4709e0
# 3616   62e431ed1be7fe316351fa64947d172a98207768
# 1009   46050057add54b397e4dac6ea42dab202edefebf
# 3175   d79ebc0c4b87d08e45489bdb0a49a1d2124b8439
# 6562   349c556db44a52953aedb83fe7093e4d7e79aab6
# 84     01ca345463fdaee4d5d72293bb7679fb5bc815ec
# 6782   897cdc8a63731ca1403e6b186c767a4ee909fa2f
# 13859  0b18ada3207991cdfd70a551c56af125d2a0efe1
# 1925   6bce09ae519ce35bf592b75b110323292b01deef
#
#                                       endCommit  \
# 3878   82b5c6d243ac4b566ec9cfbf5cbe3a306481000d
# 729    f6254da1916ec87ac12fd5da1469408e91aa320a
# 469    995e06b547cb7554c99deb3129fca19b2c35aa8b
# 11215  101f86c7e7786dcfd0accdf4083f904224329fa5
# 1013   ba1ba24af6b9a69ea6ed4d76ae61faf9191e4c0f
# 6683   01a74c93a09157b00179bb2bb10acb8a2771bb9d
# 1412   3389fb4a4b1cc5c130ac9fa1f948bb2488156cdf
# 2243   73b0517f2cfcc20b5468722804e19591310ce401
# 3618   67741baebf24971105d4a7db57a3387badad2c35
# 2418   df5ad79e3f5d9b8b63411ea91e44f72d2e86b0e0
# 7095   11a1aca69df0adf5172cb18263ba20ed4806817b
# 884    227ca6473aac1893d14cacf9cd9e4aea7c4709e0
# 3616   62e431ed1be7fe316351fa64947d172a98207768
# 1009   46050057add54b397e4dac6ea42dab202edefebf
# 3175   d79ebc0c4b87d08e45489bdb0a49a1d2124b8439
# 6562   349c556db44a52953aedb83fe7093e4d7e79aab6
# 84     01ca345463fdaee4d5d72293bb7679fb5bc815ec
# 6782   897cdc8a63731ca1403e6b186c767a4ee909fa2f
# 13859  0b18ada3207991cdfd70a551c56af125d2a0efe1
# 1925   6bce09ae519ce35bf592b75b110323292b01deef
#
#                                       startCommitChanges  \
# 3878   +javax.servlet.jsp.jstl:jstl-api\n-javax.servl...
# 729    +com.101tec:zkclient\n-com.github.sgroschupf:z...
# 469    +org.apache.dubbo:dubbo\n+org.apache.dubbo:dub...
# 11215  +org.mariadb.jdbc:mariadb-java-client\n-org.po...
# 1013     +mysql:mysql-connector-java\n-com.h2database:h2
# 6683   +com.h2database:h2\n-org.wso2.messaging:broker...
# 1412   +org.glassfish.jersey.core:jersey-client\n-com...
# 2243   +org.apache.commons:commons-lang3\n-commons-la...
# 3618   +com.sun.mail:javax.mail\n-javax.mail:javax.ma...
# 2418   +org.apache.commons:commons-lang3\n-commons-la...
# 7095   +javax.servlet:javax.servlet-api\n-org.apache....
# 884    +com.alibaba:fastjson\n-com.google.code.gson:gson
# 3616   +org.glassfish:javax.json\n-javax.json:javax.j...
# 1009   +org.eclipse.persistence:org.eclipse.persisten...
# 3175   +org.springframework.boot:spring-boot-starter-...
# 6562   +com.zaxxer:HikariCP\n-commons-logging:commons...
# 84                            +org.ow2.asm:asm\n-asm:asm
# 6782   +com.google.code.gson:gson\n+com.alibaba:fastj...
# 13859  +io.jsonwebtoken:jjwt\n+org.springframework.se...
# 1925   +org.apache.httpcomponents:httpclient\n-common...
#
#                                         endCommitChanges  \
# 3878   +javax.servlet.jsp.jstl:jstl-api\n-javax.servl...
# 729    +com.101tec:zkclient\n-com.github.sgroschupf:z...
# 469    +org.apache.dubbo:dubbo\n+org.apache.dubbo:dub...
# 11215  +org.mariadb.jdbc:mariadb-java-client\n-org.po...
# 1013     +mysql:mysql-connector-java\n-com.h2database:h2
# 6683   +com.h2database:h2\n-org.wso2.messaging:broker...
# 1412   +org.glassfish.jersey.core:jersey-client\n-com...
# 2243   +org.apache.commons:commons-lang3\n-commons-la...
# 3618   +com.sun.mail:javax.mail\n-javax.mail:javax.ma...
# 2418   +org.apache.commons:commons-lang3\n-commons-la...
# 7095   +javax.servlet:javax.servlet-api\n-org.apache....
# 884    +com.alibaba:fastjson\n-com.google.code.gson:gson
# 3616   +org.glassfish:javax.json\n-javax.json:javax.j...
# 1009   +org.eclipse.persistence:org.eclipse.persisten...
# 3175                                                None
# 6562   +com.zaxxer:HikariCP\n-commons-logging:commons...
# 84                            +org.ow2.asm:asm\n-asm:asm
# 6782   +com.google.code.gson:gson\n+com.alibaba:fastj...
# 13859  +io.jsonwebtoken:jjwt\n+org.springframework.se...
# 1925   +org.apache.httpcomponents:httpclient\n-common...
#
#                                       startCommitMessage  \
# 3878           Updated jstl artifact in pom (RF-11077)\n
# 729                            Upgrade zkclient to 0.3\n
# 469            change dubbo dependency to 2.7-SNAPSHOT\n
# 11215                                switch to mariadb\n
# 1013                move to mysql and add trip service\n
# 6683   Change db to H2 and exclude unwanted dependenc...
# 1412   Merge pull request #48 from urbanairship/updat...
# 2243   removed junit from individual poms;\nremoved j...
# 3618                                  use com.sun.mail\n
# 2418   EST-284, EST280: Add derived attribute to dete...
# 7095   [tom] changed the dependency to the servlet ap...
# 884                          json序列化方式由gson改为fastjson.\n
# 3616                                      update javax\n
# 1009                                     Switch to MySQL
# 3175   ROAD-1116: Micrometer all metrics (except truc...
# 6562   Replaced DHCP2 with HikariCP #660 (Possibly fi...
# 84                         Bug 406177: Upgrade to ASM4\n
# 6782   Kafka 异步下单\n\n1. 替换 Springboot 版本为 1.5，之前的 2.1...
# 13859  feat(rest-api): replace spring security oauth2...
# 1925   - New Eclipse project, based on m2eclipse.\n- ...
#
#                                         endCommitMessage startCommitTime  \
# 3878           Updated jstl artifact in pom (RF-11077)\n      2011-06-19
# 729                            Upgrade zkclient to 0.3\n      2013-07-14
# 469            change dubbo dependency to 2.7-SNAPSHOT\n      2018-11-14
# 11215                                switch to mariadb\n      2017-04-07
# 1013                move to mysql and add trip service\n      2017-11-20
# 6683   Change db to H2 and exclude unwanted dependenc...      2018-02-16
# 1412   Merge pull request #48 from urbanairship/updat...      2016-04-12
# 2243   removed junit from individual poms;\nremoved j...      2015-11-03
# 3618                                  use com.sun.mail\n      2014-09-19
# 2418   EST-284, EST280: Add derived attribute to dete...      2013-11-20
# 7095   [tom] changed the dependency to the servlet ap...      2014-05-26
# 884                          json序列化方式由gson改为fastjson.\n      2017-08-19
# 3616                                      update javax\n      2017-01-13
# 1009                                     Switch to MySQL      2016-05-11
# 3175   ROAD-1116: Micrometer all metrics (except truc...      2019-01-18
# 6562   Replaced DHCP2 with HikariCP #660 (Possibly fi...      2018-07-27
# 84                         Bug 406177: Upgrade to ASM4\n      2013-04-21
# 6782   Kafka 异步下单\n\n1. 替换 Springboot 版本为 1.5，之前的 2.1...      2019-06-12
# 13859  feat(rest-api): replace spring security oauth2...      2018-03-19
# 1925   - New Eclipse project, based on m2eclipse.\n- ...      2011-03-20
#
#       endCommitTime  Category              repoOwner  \
# 3878     2011-06-19        66             richfaces4
# 729      2013-07-14        15             killme2008
# 469      2018-11-14        16                 apache
# 11215    2017-04-07        31            FundRequest
# 1013     2017-11-20        31                 JoeCao
# 6683     2018-02-16        31                   wso2
# 1412     2016-04-12        21           urbanairship
# 2243     2015-11-03        13               JULIELab
# 3618     2014-09-19        62                HubSpot
# 2418     2013-11-20        13                estatio
# 7095     2014-05-26        64                 cegeka
# 884      2017-08-19        12             hippo-band
# 3616     2017-01-13         3            stanfordnlp
# 1009     2016-05-11        31                 nilzao
# 3175     2019-01-18        18           HotelsDotCom
# 6562     2018-07-27         8  plan-player-analytics
# 84       2013-04-21         5                eclipse
# 6782     2019-06-12        83            daydreamdev
# 13859    2018-03-19       111            gravitee-io
# 1925     2011-03-20        27               EmiteGWT
#
#                       repoSplitName
# 3878                     components
# 729                   Metamorphosis
# 469                     dubbo-admin
# 11215                      platform
# 1013                          qbike
# 6683       ballerina-message-broker
# 1412                   java-library
# 2243                     jcore-base
# 3618                    Singularity
# 2418                        estatio
# 7095                       batchers
# 884                           hippo
# 3616                        CoreNLP
# 1009                   soapbox-race
# 3175                   data-highway
# 6562                           Plan
# 84                      sisu.inject
# 6782                   seconds-kill
# 13859  graviteeio-access-management
# 1925                          emite

# %%
sampled_df.to_csv("sampled.csv", index=False)

# %%
(one_df["startCommit"] == one_df["endCommit"]).value_counts()
# Out:
# True     364
# False      4
# Name: count, dtype: int64

# %%
(sampled_df["startCommit"] == sampled_df["endCommit"]).value_counts()
# Out:
# True    20
# Name: count, dtype: int64

# %%
original_df["num_migration"] = original_df.groupby("repoName")["repoName"].transform(
    "count"
)
original_df
# Out:
#           id          fromLib                             toLib  \
# 0          0          ant:ant                org.apache.ant:ant
# 1          1          ant:ant                org.apache.ant:ant
# 2          2          ant:ant                org.apache.ant:ant
# 7          7          ant:ant                org.apache.ant:ant
# 8          8          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14329  14329  xstream:xstream  com.thoughtworks.xstream:xstream
# 14330  14330  xstream:xstream  com.thoughtworks.xstream:xstream
# 14331  14331  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                        repoName                                  fileName  \
# 0           bobmcwhirter_drools                                   pom.xml
# 1            wocommunity_wolips               woproject-ant-tasks/pom.xml
# 2                   teiid_teiid                                   pom.xml
# 7                 mulesoft_mule                        standalone/pom.xml
# 8                 mulesoft_mule          distributions/standalone/pom.xml
# ...                         ...                                       ...
# 14329  kiegroup_kogito-runtimes                       drools-core/pom.xml
# 14330        sakaiproject_sakai            gradebook/service/impl/pom.xml
# 14331        sakaiproject_sakai      gradebook/service/sakai-pack/pom.xml
# 14332            apache_shindig  1.0.x-incubating/java/social-api/pom.xml
# 14333            apache_shindig                  1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...
# 1      Using Ant 1.7.1 as dependency for woproject-an...
# 2                                 updating ant groupid\n
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...
# ...                                                  ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...      2010-10-20
# 1      Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 2                                 updating ant groupid\n      2009-01-19
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# ...                                                  ...             ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...      2007-08-25
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category     repoOwner    repoSplitName  num_migration
# 0        2010-10-20         0  bobmcwhirter           drools             14
# 1        2008-09-06         0   wocommunity           wolips              2
# 2        2009-01-19         0         teiid            teiid              9
# 7        2012-05-29         0      mulesoft             mule             63
# 8        2012-05-29         0      mulesoft             mule             63
# ...             ...       ...           ...              ...            ...
# 14329    2007-08-25        30      kiegroup  kogito-runtimes             66
# 14330    2007-01-30        30  sakaiproject            sakai            111
# 14331    2007-01-30        30  sakaiproject            sakai            111
# 14332    2009-01-12        30        apache          shindig             19
# 14333    2009-01-12        30        apache          shindig             19
#
# [13382 rows x 17 columns]

# %%
original_df["num_migration"]
# Out:
# 0         14
# 1          2
# 2          9
# 7         63
# 8         63
#         ...
# 14329     66
# 14330    111
# 14331    111
# 14332     19
# 14333     19
# Name: num_migration, Length: 13382, dtype: int64

# %%
13382 / 1480
# Out:
# 9.041891891891892

# %%
check = original_df.drop_duplicates(subset=["repoName"])
check.describe()
# Out:
#                  id     Category  num_migration
# count   1480.000000  1480.000000    1480.000000
# mean    4973.727703    29.189189       9.041892
# std     4105.981888    26.246775      37.256701
# min        0.000000     0.000000       1.000000
# 25%     1337.750000    11.000000       1.000000
# 50%     3975.500000    18.000000       2.000000
# 75%     7582.500000    39.000000       7.000000
# max    14315.000000   115.000000    1216.000000

# %% [markdown]
# # Check file change

# %%
import pandas as pd

df = pd.read_csv("processed2.csv")
df.head()
# Out:
#       id                         fromLib  \
# 0   3878              javax.servlet:jstl
# 1    729  com.github.sgroschupf:zkclient
# 2    469               com.alibaba:dubbo
# 3  11215       org.postgresql:postgresql
# 4   1013               com.h2database:h2
#
#                                   toLib                  repoName  \
# 0       javax.servlet.jsp.jstl:jstl-api     richfaces4_components
# 1                   com.101tec:zkclient  killme2008_Metamorphosis
# 2                org.apache.dubbo:dubbo        apache_dubbo-admin
# 3  org.mariadb.jdbc:mariadb-java-client      FundRequest_platform
# 4            mysql:mysql-connector-java              JoeCao_qbike
#
#          fileName                               startCommit  \
# 0  parent/pom.xml  82b5c6d243ac4b566ec9cfbf5cbe3a306481000d
# 1         pom.xml  f6254da1916ec87ac12fd5da1469408e91aa320a
# 2         pom.xml  995e06b547cb7554c99deb3129fca19b2c35aa8b
# 3    core/pom.xml  101f86c7e7786dcfd0accdf4083f904224329fa5
# 4      uc/pom.xml  ba1ba24af6b9a69ea6ed4d76ae61faf9191e4c0f
#
#                                   endCommit  \
# 0  82b5c6d243ac4b566ec9cfbf5cbe3a306481000d
# 1  f6254da1916ec87ac12fd5da1469408e91aa320a
# 2  995e06b547cb7554c99deb3129fca19b2c35aa8b
# 3  101f86c7e7786dcfd0accdf4083f904224329fa5
# 4  ba1ba24af6b9a69ea6ed4d76ae61faf9191e4c0f
#
#                                   startCommitChanges  \
# 0  +javax.servlet.jsp.jstl:jstl-api\n-javax.servl...
# 1  +com.101tec:zkclient\n-com.github.sgroschupf:z...
# 2  +org.apache.dubbo:dubbo\n+org.apache.dubbo:dub...
# 3  +org.mariadb.jdbc:mariadb-java-client\n-org.po...
# 4    +mysql:mysql-connector-java\n-com.h2database:h2
#
#                                     endCommitChanges  \
# 0  +javax.servlet.jsp.jstl:jstl-api\n-javax.servl...
# 1  +com.101tec:zkclient\n-com.github.sgroschupf:z...
# 2  +org.apache.dubbo:dubbo\n+org.apache.dubbo:dub...
# 3  +org.mariadb.jdbc:mariadb-java-client\n-org.po...
# 4    +mysql:mysql-connector-java\n-com.h2database:h2
#
#                           startCommitMessage  \
# 0  Updated jstl artifact in pom (RF-11077)\n
# 1                  Upgrade zkclient to 0.3\n
# 2  change dubbo dependency to 2.7-SNAPSHOT\n
# 3                        switch to mariadb\n
# 4       move to mysql and add trip service\n
#
#                             endCommitMessage startCommitTime endCommitTime  \
# 0  Updated jstl artifact in pom (RF-11077)\n      2011-06-19    2011-06-19
# 1                  Upgrade zkclient to 0.3\n      2013-07-14    2013-07-14
# 2  change dubbo dependency to 2.7-SNAPSHOT\n      2018-11-14    2018-11-14
# 3                        switch to mariadb\n      2017-04-07    2017-04-07
# 4       move to mysql and add trip service\n      2017-11-20    2017-11-20
#
#    Category    repoOwner  repoSplitName  \
# 0        66   richfaces4     components
# 1        15   killme2008  Metamorphosis
# 2        16       apache    dubbo-admin
# 3        31  FundRequest       platform
# 4        31       JoeCao          qbike
#
#                                 prev_commit  \
# 0  0a002564ee00679be07b70f4902e82e1fa8bb45a
# 1  efb075b1bed3368b8ff961656c2d9dc691c8a6e4
# 2  80013ffc38b3d737bd891a2b574ef75a93450bd9
# 3                                       NaN
# 4  3c876617d0e3506205fd9d02dbf050a7565f796c
#
#                                           diff_files
# 0  {'Added': [], 'Modified': [], 'Deleted': [], '...
# 1  {'Added': [], 'Modified': [], 'Deleted': [], '...
# 2  {'Added': [], 'Modified': ['dubbo-admin-backen...
# 3                                                NaN
# 4  {'Added': ['intention/src/main/java/club/newte...

# %%
import subprocess
def read_file_in_commit(repo_dir, rev_path, commit_hash):

# %%
for i in range(len(df)):
    diff_files = df["diff_files"].iloc[i]    
    if pd.isna(diff_files):
        continue
    diff_files = eval(diff_files)
    if diff_files["Renamed"]:
# Out:
# [('intention/src/main/java/club/newtech/qbike/domain/core/vo/User.java', 'trip/src/main/java/club/newtech/qbike/trip/domain/core/vo/Driver.java'), ('intention/src/main/java/club/newtech/qbike/domain/core/service/UserRibbonHystrixService.java', 'trip/src/main/java/club/newtech/qbike/trip/infrastructure/UserRibbonHystrixApi.java')]
# [('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/WebMvcConfiguration.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/WebMvcConfiguration.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/authentication/CustomSavedRequestAwareAuthenticationSuccessHandler.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/authentication/CustomSavedRequestAwareAuthenticationSuccessHandler.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/authentication/OAuth2LoginUrlAuthenticationEntryPoint.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/authentication/LoginUrlAuthenticationEntryPoint.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/context/OAuth2ContextFactory.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/context/AdminContextFactory.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/context/OAuth2ContextLoaderListener.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/context/AdminContextLoaderListener.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/context/OAuth2DomainBeanFactoryPostProcessor.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/context/AdminDomainBeanFactoryPostProcessor.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/context/OAuth2SpringServletContext.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/context/AdminSpringServletContext.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/controller/LoginController.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/controller/LoginController.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/filter/OAuth2ClientAuthenticationFilter.java', 'gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-admin/src/main/java/io/gravitee/am/management/handlers/admin/filter/OAuth2ClientAuthenticationFilter.java'), ('gravitee-am-management-api/gravitee-am-management-api-handlers/gravitee-am-management-api-handlers-oauth2/src/main/java/io/gravitee/am/management/handlers/oauth2/security/ExtensionGrantManager.java', 'gravitee-am-management-api/gravitee-am-m ...
# [('src/main/java/com/calclab/emite/core/client/packet/PacketTestSuite.java', 'src/test/java/com/calclab/emite/core/client/packet/PacketTestSuite.java'), ('src/main/java/com/calclab/emite/xtesting/ConnectionTester.java', 'src/test/java/com/calclab/emite/xtesting/ConnectionTester.java'), ('src/main/java/com/calclab/emite/xtesting/EmiteTestsEventBus.java', 'src/test/java/com/calclab/emite/xtesting/EmiteTestsEventBus.java'), ('src/main/java/com/calclab/emite/xtesting/RosterItemHelper.java', 'src/test/java/com/calclab/emite/xtesting/RosterItemHelper.java'), ('src/main/java/com/calclab/emite/xtesting/ServicesTester.java', 'src/test/java/com/calclab/emite/xtesting/ServicesTester.java'), ('src/main/java/com/calclab/emite/xtesting/SessionTester.java', 'src/test/java/com/calclab/emite/xtesting/SessionTester.java'), ('src/main/java/com/calclab/emite/xtesting/XmppConnectionTester.java', 'src/test/java/com/calclab/emite/xtesting/XmppConnectionTester.java'), ('src/main/java/com/calclab/emite/xtesting/XmppRosterHelper.java', 'src/test/java/com/calclab/emite/xtesting/XmppRosterHelper.java'), ('src/main/java/com/calclab/emite/xtesting/XmppSessionTester.java', 'src/test/java/com/calclab/emite/xtesting/XmppSessionTester.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/ChangedTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/ChangedTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/ChatChangedTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/ChatChangedTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/DiscoveryInfoResultTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/DiscoveryInfoResultTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/DiscoveryItemsResultTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/DiscoveryItemsResultTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/ErrorTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/ErrorTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/MessageTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/MessageTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/PacketTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/PacketTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/PresenceTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/PresenceTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/RoomSubjectChangedTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/RoomSubjectChangedTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/RosterItemChangedTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/RosterItemChangedTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/StateChangedTestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/StateChangedTestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/handlers/TestHandler.java', 'src/test/java/com/calclab/emite/xtesting/handlers/TestHandler.java'), ('src/main/java/com/calclab/emite/xtesting/matchers/EmiteAsserts.java', 'src/test/java/com/calclab/emite/xtesting/matchers/EmiteAsserts.java'), ('src/main/java/com/calclab/emite/xtesting/matchers/IsPacketLike.java', 'src/test/java/com/calclab/emite/xtesting/matchers/IsPacketLike.java'), ('src/main/java/com/calclab/emite/xtesting/services/HttpConnector.java', 'src/test/java/com/calclab/emite/xtesting/services/HttpConnector.java'), ('src/main/java/com/calclab/emite/xtesting/services/J2SEServicesModule.java', 'src/test/java/com/calclab/emite/xtesting/services/J2SEServicesModule.java'), ('src/main/java/com/calclab/emite/xtesting/services/J2SEXmppDateTimeFormatter.java', 'src/test/java/com/calclab/emite/xtesting/services/J2SEXmppDateTimeFormatter.java'), ('src/main/java/com/calclab/emite/xtesting/serv ...

# %%
import pandas as pd

df = pd.read_csv("methods_20.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  80 non-null     int64
#  1   fromLib             80 non-null     object
#  2   toLib               80 non-null     object
#  3   repoName            80 non-null     object
#  4   fileName            80 non-null     object
#  5   startCommit         80 non-null     object
#  6   endCommit           80 non-null     object
#  7   startCommitChanges  80 non-null     object
#  8   endCommitChanges    75 non-null     object
#  9   startCommitMessage  80 non-null     object
#  10  endCommitMessage    80 non-null     object
#  11  startCommitTime     80 non-null     object
#  12  endCommitTime       80 non-null     object
#  13  Category            80 non-null     int64
#  14  repoOwner           80 non-null     object
#  15  repoSplitName       80 non-null     object
#  16  prev_commit         80 non-null     object
#  17  diff_files          80 non-null     object
#  18  old_file            80 non-null     object
#  19  new_file            80 non-null     object
#  20  old_class           80 non-null     object
#  21  new_class           80 non-null     object
#  22  old_method_sig      80 non-null     object
#  23  new_method_sig      80 non-null     object
#  24  old_method_code     80 non-null     object
#  25  new_method_code     80 non-null     object
# dtypes: int64(2), object(24)
# memory usage: 16.4+ KB

# %%
df_simplified = df.drop(columns=["diff_files"])
df_simplified.to_csv("methods_20_simplified.csv", index=False)

# %% [markdown]
# # New check

# %%
import pandas as pd

df = pd.read_parquet("official_original.parquet")
df
# Out:
#           id          fromLib                             toLib  \
# 0          0          ant:ant                org.apache.ant:ant
# 1          1          ant:ant                org.apache.ant:ant
# 2          2          ant:ant                org.apache.ant:ant
# 7          7          ant:ant                org.apache.ant:ant
# 8          8          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14329  14329  xstream:xstream  com.thoughtworks.xstream:xstream
# 14330  14330  xstream:xstream  com.thoughtworks.xstream:xstream
# 14331  14331  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                        repoName                                  fileName  \
# 0           bobmcwhirter_drools                                   pom.xml
# 1            wocommunity_wolips               woproject-ant-tasks/pom.xml
# 2                   teiid_teiid                                   pom.xml
# 7                 mulesoft_mule                        standalone/pom.xml
# 8                 mulesoft_mule          distributions/standalone/pom.xml
# ...                         ...                                       ...
# 14329  kiegroup_kogito-runtimes                       drools-core/pom.xml
# 14330        sakaiproject_sakai            gradebook/service/impl/pom.xml
# 14331        sakaiproject_sakai      gradebook/service/sakai-pack/pom.xml
# 14332            apache_shindig  1.0.x-incubating/java/social-api/pom.xml
# 14333            apache_shindig                  1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...
# 1      Using Ant 1.7.1 as dependency for woproject-an...
# 2                                 updating ant groupid\n
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...
# ...                                                  ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...      2010-10-20
# 1      Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 2                                 updating ant groupid\n      2009-01-19
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# ...                                                  ...             ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...      2007-08-25
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category     repoOwner    repoSplitName
# 0        2010-10-20         0  bobmcwhirter           drools
# 1        2008-09-06         0   wocommunity           wolips
# 2        2009-01-19         0         teiid            teiid
# 7        2012-05-29         0      mulesoft             mule
# 8        2012-05-29         0      mulesoft             mule
# ...             ...       ...           ...              ...
# 14329    2007-08-25        30      kiegroup  kogito-runtimes
# 14330    2007-01-30        30  sakaiproject            sakai
# 14331    2007-01-30        30  sakaiproject            sakai
# 14332    2009-01-12        30        apache          shindig
# 14333    2009-01-12        30        apache          shindig
#
# [13382 rows x 16 columns]

# %%
df["repoName"].nunique()
# Out:
# 1480

# %%
df["startCommit"].nunique()
# Out:
# 3038

# %%
df["endCommit"].nunique()
# Out:
# 3029

# %%
df["repo_start_end_commit"] = df.apply(lambda row: row["repoName"] + "__" + row["startCommit"] + "__" + row["endCommit"], axis=1)
df
# Out:
#           id          fromLib                             toLib  \
# 0          0          ant:ant                org.apache.ant:ant
# 1          1          ant:ant                org.apache.ant:ant
# 2          2          ant:ant                org.apache.ant:ant
# 7          7          ant:ant                org.apache.ant:ant
# 8          8          ant:ant                org.apache.ant:ant
# ...      ...              ...                               ...
# 14329  14329  xstream:xstream  com.thoughtworks.xstream:xstream
# 14330  14330  xstream:xstream  com.thoughtworks.xstream:xstream
# 14331  14331  xstream:xstream  com.thoughtworks.xstream:xstream
# 14332  14332  xstream:xstream  com.thoughtworks.xstream:xstream
# 14333  14333  xstream:xstream  com.thoughtworks.xstream:xstream
#
#                        repoName                                  fileName  \
# 0           bobmcwhirter_drools                                   pom.xml
# 1            wocommunity_wolips               woproject-ant-tasks/pom.xml
# 2                   teiid_teiid                                   pom.xml
# 7                 mulesoft_mule                        standalone/pom.xml
# 8                 mulesoft_mule          distributions/standalone/pom.xml
# ...                         ...                                       ...
# 14329  kiegroup_kogito-runtimes                       drools-core/pom.xml
# 14330        sakaiproject_sakai            gradebook/service/impl/pom.xml
# 14331        sakaiproject_sakai      gradebook/service/sakai-pack/pom.xml
# 14332            apache_shindig  1.0.x-incubating/java/social-api/pom.xml
# 14333            apache_shindig                  1.0.x-incubating/pom.xml
#
#                                     startCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       endCommit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9
# 2      204ea9614df7b99c46cc054877c5bea4d145b460
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574
# ...                                         ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967
#
#                                       startCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                         endCommitChanges  \
# 0      +org.apache.ant:ant\n+org.apache.ant:ant-apach...
# 1      +org.apache.ant:ant\n+org.apache.ant:ant-junit...
# 2                          +org.apache.ant:ant\n-ant:ant
# 7                          +org.apache.ant:ant\n-ant:ant
# 8                          +org.apache.ant:ant\n-ant:ant
# ...                                                  ...
# 14329  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14330  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14331  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14332  +com.thoughtworks.xstream:xstream\n-xstream:xs...
# 14333  +com.thoughtworks.xstream:xstream\n-xstream:xs...
#
#                                       startCommitMessage  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...
# 1      Using Ant 1.7.1 as dependency for woproject-an...
# 2                                 updating ant groupid\n
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...
# ...                                                  ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...
#
#                                         endCommitMessage startCommitTime  \
# 0      JBRULES-2737 Build with maven 3 fails on Guvno...      2010-10-20
# 1      Using Ant 1.7.1 as dependency for woproject-an...      2008-09-06
# 2                                 updating ant groupid\n      2009-01-19
# 7      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# 8      MULE-6255: Update ant version to 1.7.0 to fix ...      2012-05-29
# ...                                                  ...             ...
# 14329  JBRULES-1128 JBRULES-992: optional dependencie...      2007-08-25
# 14330  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14331  Fixed issue with xstream\n\n\ngit-svn-id: http...      2007-01-30
# 14332  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
# 14333  SHINDIG-837 | Patch from Vincent Siveton | Del...      2009-01-12
#
#       endCommitTime  Category     repoOwner    repoSplitName  \
# 0        2010-10-20         0  bobmcwhirter           drools
# 1        2008-09-06         0   wocommunity           wolips
# 2        2009-01-19         0         teiid            teiid
# 7        2012-05-29         0      mulesoft             mule
# 8        2012-05-29         0      mulesoft             mule
# ...             ...       ...           ...              ...
# 14329    2007-08-25        30      kiegroup  kogito-runtimes
# 14330    2007-01-30        30  sakaiproject            sakai
# 14331    2007-01-30        30  sakaiproject            sakai
# 14332    2009-01-12        30        apache          shindig
# 14333    2009-01-12        30        apache          shindig
#
#                                         start_end_commit  \
# 0      0504ef4b2349dd7edc4d4991d29f688dc15da939__0504...
# 1      1d02c267e787b0c97ef9a3fb3b63da33e8f3c6d9__1d02...
# 2      204ea9614df7b99c46cc054877c5bea4d145b460__204e...
# 7      4a47dcdc23f8800049e1aabd29ea5d618b0ac7dd__4a47...
# 8      55f25f71b131ccac1c7e7c2cba99b330759ad574__55f2...
# ...                                                  ...
# 14329  ae5bf7e576bce9bc7c1871b323dc81bbded46b55__ae5b...
# 14330  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584__d32f...
# 14331  d32f1ecd4a80a1f4b1ccda1763c6d7f0f5462584__d32f...
# 14332  f6cabfb61fbbc6a6afbda13b39189c005c681967__f6ca...
# 14333  f6cabfb61fbbc6a6afbda13b39189c005c681967__f6ca...
#
#                                    repo_start_end_commit
# 0      bobmcwhirter_drools__0504ef4b2349dd7edc4d4991d...
# 1      wocommunity_wolips__1d02c267e787b0c97ef9a3fb3b...
# 2      teiid_teiid__204ea9614df7b99c46cc054877c5bea4d...
# 7      mulesoft_mule__4a47dcdc23f8800049e1aabd29ea5d6...
# 8      mulesoft_mule__55f25f71b131ccac1c7e7c2cba99b33...
# ...                                                  ...
# 14329  kiegroup_kogito-runtimes__ae5bf7e576bce9bc7c18...
# 14330  sakaiproject_sakai__d32f1ecd4a80a1f4b1ccda1763...
# 14331  sakaiproject_sakai__d32f1ecd4a80a1f4b1ccda1763...
# 14332  apache_shindig__f6cabfb61fbbc6a6afbda13b39189c...
# 14333  apache_shindig__f6cabfb61fbbc6a6afbda13b39189c...
#
# [13382 rows x 18 columns]

# %%
df["repo_start_end_commit"].nunique()
# Out:
# 3189

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13382 entries, 0 to 14333
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     13382 non-null  int64
#  1   fromLib                13382 non-null  object
#  2   toLib                  13382 non-null  object
#  3   repoName               13382 non-null  object
#  4   fileName               13382 non-null  object
#  5   startCommit            13382 non-null  object
#  6   endCommit              13382 non-null  object
#  7   startCommitChanges     13382 non-null  object
#  8   endCommitChanges       13380 non-null  object
#  9   startCommitMessage     13380 non-null  object
#  10  endCommitMessage       13380 non-null  object
#  11  startCommitTime        13382 non-null  object
#  12  endCommitTime          13382 non-null  object
#  13  Category               13382 non-null  int64
#  14  repoOwner              13382 non-null  object
#  15  repoSplitName          13382 non-null  object
#  16  start_end_commit       13382 non-null  object
#  17  repo_start_end_commit  13382 non-null  object
# dtypes: int64(2), object(16)
# memory usage: 1.9+ MB

# %%
for i in range(len(df) - 1):
    for j in range(i + 1, len(df)):
        if df.iloc[i, 16] == df.iloc[j, 16] and df.iloc[i, 17] != df.iloc[j, 17]:
            print(i, j)
# Out:
# 90 92
# 90 125
# 90 126
# 91 92
# 91 125
# 91 126
# 92 122
# 92 123
# 92 124
# 122 125
# 122 126
# 123 125
# 123 126
# 124 125
# 124 126
# 183 184
# 183 324
# 183 10634
# 184 323
# 184 10633
# 189 190
# 189 10638
# 190 10637
# 200 202
# 200 203
# 200 221
# 200 222
# 200 257
# 200 258
# 200 322
# 201 202
# 201 203
# 201 221
# 201 222
# 201 257
# 201 258
# 201 322
# 202 219
# 202 220
# 202 255
# 202 256
# 202 321
# 203 219
# 203 220
# 203 255
# 203 256
# 203 321
# 204 205
# 204 225
# 204 271
# 204 330
# 205 224
# 205 270
# 205 329
# 219 221
# 219 222
# 219 257
# 219 258
# 219 322
# 220 221
# 220 222
# 220 257
# 220 258
# 220 322
# 221 255
# 221 256
# 221 321
# 222 255
# 222 256
# 222 321
# 224 225
# 224 271
# 224 330
# 225 270
# 225 329
# 255 257
# 255 258
# 255 322
# 256 257
# 256 258
# 256 322
# 257 321
# 258 321
# 270 271
# 270 330
# 271 329
# 321 322
# 323 324
# 323 10634
# 324 10633
# 329 330
# 341 342
# 341 343
# 342 343
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_349975/3599757129.py in ?()
#       1 for i in range(len(df) - 1):
#       2     for j in range(i + 1, len(df)):
# ----> 3         if df.iloc[i, 16] == df.iloc[j, 16] and df.iloc[i, 17] != df.iloc[j, 17]:
#       4             print(i, j)
#
# ~/miniconda3/envs/learn/lib/python3.11/site-packages/pandas/core/indexing.py in ?(self, key)
#    1179         if type(key) is tuple:
#    1180             key = tuple(list(x) if is_iterator(x) else x for x in key)
#    1181             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182             if self._is_scalar_access(key):
# -> 1183                 return self.obj._get_value(*key, takeable=self._takeable)
#    1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# ~/miniconda3/envs/learn/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, index, col, takeable)
# -> 4191     def _get_value(self, index, col, takeable: bool = False) -> Scalar:
#    4192         """
#    4193         Quickly retrieve single value at passed column and index.
#    4194
#
# KeyboardInterrupt:

# %%
df.to_csv("official_added_id.csv", index=False)

# %%
unique = df.groupby("repo_start_end_commit").apply(lambda x: x.sample(1, random_state=42))
unique
# Out:
# /tmp/ipykernel_349975/1081030082.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique = df.groupby("repo_start_end_commit").apply(lambda x: x.sample(1, random_state=42))
#                                                              id  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  10470
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316    2316
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667    1667
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  14029
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  14122
# ...                                                         ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  14152
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127    7127
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117    7117
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  13786
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  13789
#
#                                                                                        fromLib  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  org.mariadb.jdbc:mariadb-java-client
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316              commons-lang:commons-lang
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667                 com.vividsolutions:jts
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029                org.xerial:sqlite-jdbc
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122                 postgresql:postgresql
# ...                                                                                        ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152                              rhino:js
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127         org.codehaus.groovy:groovy-all
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117                      org.beanshell:bsh
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786                org.slf4j:slf4j-simple
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789                org.slf4j:slf4j-simple
#
#                                                                                      toLib  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470         org.postgresql:postgresql
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   org.apache.commons:commons-lang3
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667      org.locationtech.jts:jts-core
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029   javax.servlet:javax.servlet-api
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122         org.postgresql:postgresql
# ...                                                                                    ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152                 org.mozilla:rhino
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127                org.zkoss.zk:zuljsp
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117    org.apache-extras.beanshell:bsh
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786        org.spf4j:spf4j-slf4j-test
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789        org.spf4j:spf4j-slf4j-test
#
#                                                                   repoName  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470       1and1_cosmo
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316          42BV_jarb
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667        52North_SOS
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029       52North_SOS
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122       52North_SOS
# ...                                                                    ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152          zkoss_zk
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127           zkoss_zk
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117           zkoss_zk
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  zolyfarkas_spf4j
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  zolyfarkas_spf4j
#
#                                                                            fileName  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470       cosmo-webapp/pom.xml
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316                     pom.xml
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   coding/netcdf/api/pom.xml
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029                    pom.xml
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122                    pom.xml
# ...                                                                             ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152             zktest/pom.xml
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127           zksandbox/pom.xml
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117              zktest/pom.xml
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786         spf4j-joda/pom.xml
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789          spf4j-zel/pom.xml
#
#                                                                                        startCommit  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  f8207e3129d721db5026cc9ea2a8ce58db34fea5
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   b193a20c23a862be0ec7abccf74b83f25979c465
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   1dcf0c8a359f6673272df58d5419af3297fa0648
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  520cc60fd93dbfb6e48d75f23765d72556ef7fa1
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  a46610ab2c02a34e54e5a9985b96229655003f33
# ...                                                                                            ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  21a1ed83f0ec879f6ef973c82d51e147be208ad6
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   555a531592fbb12e2621577f997545c076987277
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   d283f0945a035fb61281c31ce3b13690aae346d8
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  d321f19c34d5ee9fc91114d012553e66144b9692
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
#
#                                                                                          endCommit  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  f8207e3129d721db5026cc9ea2a8ce58db34fea5
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   b193a20c23a862be0ec7abccf74b83f25979c465
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   1dcf0c8a359f6673272df58d5419af3297fa0648
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  c92d475de8a1b1cf5cb71462302fc510d7a69446
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  a46610ab2c02a34e54e5a9985b96229655003f33
# ...                                                                                            ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  21a1ed83f0ec879f6ef973c82d51e147be208ad6
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   555a531592fbb12e2621577f997545c076987277
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   d283f0945a035fb61281c31ce3b13690aae346d8
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  d321f19c34d5ee9fc91114d012553e66144b9692
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b
#
#                                                                                          startCommitChanges  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  +com.sun.xml.bind:jaxb-impl\n+javax.activation...
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   +org.apache.commons:commons-lang3\n-commons-la...
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   +org.locationtech.jts:jts-core\n-com.vividsolu...
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  +javax.servlet:javax.servlet-api\n-javax.servl...
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  +org.postgresql:postgresql\n-postgresql:postgr...
# ...                                                                                                     ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152                      +org.mozilla:rhino\n-rhino:js
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   +net.sourceforge.jexcelapi:jxl\n+org.zkoss.zk:...
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   +org.apache-extras.beanshell:bsh\n-org.beanshe...
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
#
#                                                                                            endCommitChanges  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  +com.sun.xml.bind:jaxb-impl\n+javax.activation...
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   +org.apache.commons:commons-lang3\n-commons-la...
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   +org.locationtech.jts:jts-core\n-com.vividsolu...
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  -${project.groupId}:sqlite-config\n-org.xerial...
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  +org.postgresql:postgresql\n-postgresql:postgr...
# ...                                                                                                     ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152                      +org.mozilla:rhino\n-rhino:js
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   +net.sourceforge.jexcelapi:jxl\n+org.zkoss.zk:...
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   +org.apache-extras.beanshell:bsh\n-org.beanshe...
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  +org.spf4j:spf4j-slf4j-test\n-org.slf4j:slf4j-...
#
#                                                                                          startCommitMessage  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470                        Try to move to PostgreSQL\n
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316                                bumped to commons3\n
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   - Merge branch 'merge/previous_res_fil' into 5...
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  Update dependency versions (servlet-api has ch...
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  Update PostgreSQL-JDBC and PostGIS-JDBC versio...
# ...                                                                                                     ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  upgrade third party library version\n1. js.jar...
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   update maven poms\n\ngit-svn-id: https://svn.p...
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   ZK-3180: integrate security update in beanshel...
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786                 [add] use spf4j-slf4j-test module!
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789                 [add] new spf4j-slf4j-test module!
#
#                                                                                            endCommitMessage  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470                        Try to move to PostgreSQL\n
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316                                bumped to commons3\n
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   - Merge branch 'merge/previous_res_fil' into 5...
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  Add support for storing eReporting header in c...
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  Update PostgreSQL-JDBC and PostGIS-JDBC versio...
# ...                                                                                                     ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  upgrade third party library version\n1. js.jar...
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   update maven poms\n\ngit-svn-id: https://svn.p...
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   ZK-3180: integrate security update in beanshel...
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786                 [add] use spf4j-slf4j-test module!
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789                 [add] new spf4j-slf4j-test module!
#
#                                                          startCommitTime  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470      2019-10-15
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316       2011-08-05
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667       2018-01-04
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029      2015-12-12
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122      2014-06-23
# ...                                                                  ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152      2013-10-15
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127       2011-01-27
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117       2016-04-21
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786      2018-01-22
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789      2018-01-22
#
#                                                          endCommitTime  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470    2019-10-15
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316     2011-08-05
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667     2018-01-04
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029    2019-09-18
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122    2014-06-23
# ...                                                                ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152    2013-10-15
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127     2011-01-27
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117     2016-04-21
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786    2018-01-22
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789    2018-01-22
#
#                                                           Category  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470        31
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316         13
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667         45
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029        31
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122        31
# ...                                                            ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152        65
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127         30
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117         88
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786        11
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789        11
#
#                                                            repoOwner  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470       1and1
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316         42BV
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667      52North
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029     52North
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122     52North
# ...                                                              ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152       zkoss
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127        zkoss
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117        zkoss
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  zolyfarkas
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  zolyfarkas
#
#                                                          repoSplitName  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470         cosmo
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316           jarb
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667            SOS
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029           SOS
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122           SOS
# ...                                                                ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152            zk
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127             zk
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117             zk
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786         spf4j
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789         spf4j
#
#                                                                                            start_end_commit  \
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  f8207e3129d721db5026cc9ea2a8ce58db34fea5__f820...
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   b193a20c23a862be0ec7abccf74b83f25979c465__b193...
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   1dcf0c8a359f6673272df58d5419af3297fa0648__1dcf...
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  520cc60fd93dbfb6e48d75f23765d72556ef7fa1__c92d...
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  a46610ab2c02a34e54e5a9985b96229655003f33__a466...
# ...                                                                                                     ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  21a1ed83f0ec879f6ef973c82d51e147be208ad6__21a1...
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   555a531592fbb12e2621577f997545c076987277__555a...
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   d283f0945a035fb61281c31ce3b13690aae346d8__d283...
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  d321f19c34d5ee9fc91114d012553e66144b9692__d321...
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  f5afbdf7dd26acf089e44f30c24e9122465f9d9b__f5af...
#
#                                                                                       repo_start_end_commit
# repo_start_end_commit
# 1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db... 10470  1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58d...
# 42BV_jarb__b193a20c23a862be0ec7abccf74b83f25979... 2316   42BV_jarb__b193a20c23a862be0ec7abccf74b83f2597...
# 52North_SOS__1dcf0c8a359f6673272df58d5419af3297... 1667   52North_SOS__1dcf0c8a359f6673272df58d5419af329...
# 52North_SOS__520cc60fd93dbfb6e48d75f23765d72556... 14029  52North_SOS__520cc60fd93dbfb6e48d75f23765d7255...
# 52North_SOS__a46610ab2c02a34e54e5a9985b96229655... 14122  52North_SOS__a46610ab2c02a34e54e5a9985b9622965...
# ...                                                                                                     ...
# zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be208... 14152  zkoss_zk__21a1ed83f0ec879f6ef973c82d51e147be20...
# zkoss_zk__555a531592fbb12e2621577f997545c076987... 7127   zkoss_zk__555a531592fbb12e2621577f997545c07698...
# zkoss_zk__d283f0945a035fb61281c31ce3b13690aae34... 7117   zkoss_zk__d283f0945a035fb61281c31ce3b13690aae3...
# zolyfarkas_spf4j__d321f19c34d5ee9fc91114d012553... 13786  zolyfarkas_spf4j__d321f19c34d5ee9fc91114d01255...
# zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9... 13789  zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e...
#
# [3189 rows x 18 columns]

# %%
unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3189 entries, ('1and1_cosmo__f8207e3129d721db5026cc9ea2a8ce58db34fea5__f8207e3129d721db5026cc9ea2a8ce58db34fea5', 10470) to ('zolyfarkas_spf4j__f5afbdf7dd26acf089e44f30c24e9122465f9d9b__f5afbdf7dd26acf089e44f30c24e9122465f9d9b', 13789)
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3189 non-null   int64
#  1   fromLib                3189 non-null   object
#  2   toLib                  3189 non-null   object
#  3   repoName               3189 non-null   object
#  4   fileName               3189 non-null   object
#  5   startCommit            3189 non-null   object
#  6   endCommit              3189 non-null   object
#  7   startCommitChanges     3189 non-null   object
#  8   endCommitChanges       3187 non-null   object
#  9   startCommitMessage     3188 non-null   object
#  10  endCommitMessage       3188 non-null   object
#  11  startCommitTime        3189 non-null   object
#  12  endCommitTime          3189 non-null   object
#  13  Category               3189 non-null   int64
#  14  repoOwner              3189 non-null   object
#  15  repoSplitName          3189 non-null   object
#  16  start_end_commit       3189 non-null   object
#  17  repo_start_end_commit  3189 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 768.9+ KB

# %%
sampled = unique.sample(n=50, random_state=42)
sampled
# Out:
#                                                              id  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989    7989
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649    9649
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237  10237
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828    7828
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660    6660
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  11270
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600    5600
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840    2840
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  12987
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215    2215
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561    4561
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359    5359
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708    8708
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  11468
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435    3435
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268    3268
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872    1872
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446    9446
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691    5691
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713      713
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891    3891
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419    2419
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729    5729
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602      602
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153    6153
# ForgeRock_openidm-community-edition__43689602ee... 3249    3249
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  10308
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569      569
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  13924
# structr_structr__569c38864cc772fddee47ff538c883... 11426  11426
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889    9889
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60        60
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608    6608
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786    9786
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  14107
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508    2508
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294    4294
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422    8422
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932      932
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242    2242
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193    4193
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074    6074
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204    3204
# littlefishercoder_littlefisher-system__05551a5c... 11145  11145
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234    4234
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661      661
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683    7683
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251    3251
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636    6636
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404    8404
#
#                                                                                                  fromLib  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989               org.codehaus.jackson:jackson-jaxrs
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649                        org.hamcrest:hamcrest-all
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237                                   org.json:json
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828               org.codehaus.jackson:jackson-jaxrs
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660                    org.apache.commons:commons-io
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270           org.powermock:powermock-module-junit4
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600                                      log4j:log4j
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840                  commons-logging:commons-logging
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987                         org.slf4j:slf4j-log4j12
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215                        commons-lang:commons-lang
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561                                      junit:junit
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359                                      junit:junit
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708          org.codehaus.jackson:jackson-mapper-asl
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468                             org.slf4j:slf4j-api
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435                         javax.enterprise:cdi-api
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268                              javassist:javassist
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872            commons-httpclient:commons-httpclient
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446          org.glassfish.jersey.core:jersey-client
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691                                      log4j:log4j
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713                    com.github.sgroschupf:zkclient
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891                               javax.servlet:jstl
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419                        commons-lang:commons-lang
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729                                      log4j:log4j
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    com.fasterxml.jackson.core:jackson-annotations
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153                                      log4j:log4j
# ForgeRock_openidm-community-edition__43689602ee... 3249                              javassist:javassist
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308                                   org.json:json
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569                 com.codahale.metrics:metrics-core
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924               org.springframework:spring-webmvc
# structr_structr__569c38864cc772fddee47ff538c883... 11426                             org.slf4j:slf4j-api
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889                                org.hsqldb:hsqldb
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60                            aopalliance:aopalliance
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608                    org.apache.commons:commons-io
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786      org.hibernate:hibernate-commons-annotations
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107                           postgresql:postgresql
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508                  commons-logging:commons-logging
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294                                        jstl:jstl
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422          org.codehaus.jackson:jackson-mapper-asl
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932                            com.google.guava:guava
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242                        commons-lang:commons-lang
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                                        jdom:jdom
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074                                      log4j:log4j
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204                              io.reactivex:rxjava
# littlefishercoder_littlefisher-system__05551a5c... 11145                      org.mybatis:mybatis-spring
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234                                      jline:jline
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661       com.fasterxml.jackson.core:jackson-databind
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683            org.codehaus.jackson:jackson-core-asl
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251                              javassist:javassist
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636                    org.apache.commons:commons-io
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404          org.codehaus.jackson:jackson-mapper-asl
#
#                                                                                                       toLib  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   com.fasterxml.jackson.jaxrs:jackson-jaxrs-json...
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649                          org.hamcrest:java-hamcrest
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237                               com.alibaba:fastjson
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828      com.fasterxml.jackson.core:jackson-annotations
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660                               commons-io:commons-io
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270                           org.mockito:mockito-core
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600                 commons-logging:commons-logging-api
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840                             org.slf4j:slf4j-log4j12
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987                org.apache.logging.log4j:log4j-core
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215                    org.apache.commons:commons-lang3
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561              org.junit.jupiter:junit-jupiter-engine
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359                                   org.testng:testng
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708         com.fasterxml.jackson.core:jackson-databind
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468                                        log4j:log4j
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435       jakarta.enterprise:jakarta.enterprise.cdi-api
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268                             org.javassist:javassist
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872                org.apache.httpcomponents:httpclient
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446                org.apache.httpcomponents:httpclient
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691                 org.apache.logging.log4j:log4j-core
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713                                  com.101tec:zkclient
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891                     javax.servlet.jsp.jstl:jstl-api
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419                    org.apache.commons:commons-lang3
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729                 org.apache.logging.log4j:log4j-core
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    com.fasterxml.jackson.jaxrs:jackson-jaxrs-json...
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153                                 org.slf4j:slf4j-api
# ForgeRock_openidm-community-edition__43689602ee... 3249                                         asm:asm-all
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308                    org.codehaus.jackson:jackson-xc
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569                   io.dropwizard.metrics:metrics-core
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924   org.springframework.boot:spring-boot-starter-web
# structr_structr__569c38864cc772fddee47ff538c883... 11426                     ch.qos.logback:logback-classic
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889                                   com.h2database:h2
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60                      org.springframework:spring-beans
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608                               commons-io:commons-io
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   org.hibernate.common:hibernate-commons-annotat...
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107                          org.postgresql:postgresql
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508                 org.apache.logging.log4j:log4j-core
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294                                  javax.servlet:jstl
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422         com.fasterxml.jackson.core:jackson-databind
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932                 com.googlecode.guava-osgi:guava-osgi
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242                    org.apache.commons:commons-lang3
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                                      org.jdom:jdom2
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074                          org.slf4j:log4j-over-slf4j
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204                         io.reactivex.rxjava2:rxjava
# littlefishercoder_littlefisher-system__05551a5c... 11145  org.mybatis.spring.boot:mybatis-spring-boot-st...
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234                              org.jline:jline-reader
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661                            com.google.code.gson:gson
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683         com.fasterxml.jackson.core:jackson-databind
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251                             org.javassist:javassist
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636                               commons-io:commons-io
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404             com.fasterxml.jackson.core:jackson-core
#
#                                                                                               repoName  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989                                 apache_syncope
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649                                   apache_storm
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237                        apache_incubator-iotdb
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828                                SeqWare_seqware
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660                                appfuse_appfuse
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270                                  apache_camel
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600                                   apache_camel
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840             emmanuelbernard_hibernate-core-ogm
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987                              Flipkart_phantom
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215                           jbehave_jbehave-core
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561                                zalando_problem
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359                                codenvy_codenvy
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   RBGKew_Reconciliation-and-Matching-Framework
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468                    hibernate_hibernate-search
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435                  eclipse_microprofile-jwt-auth
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268                                 bmwcarit_joynr
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872                          jadler-mocking_jadler
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446                     wooti_onedrive-java-client
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691                     TremoloSecurity_OpenUnison
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713                                    apache_helix
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891                        richfaces4_dev-examples
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419                             sakaiproject_sakai
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729                                 Wimmics_corese
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602                             RoboZonky_robozonky
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153                               ikasanEIP_ikasan
# ForgeRock_openidm-community-edition__43689602ee... 3249            ForgeRock_openidm-community-edition
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308                        apache_incubator-pinot
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569                                     teiid_teiid
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924                           codenjoyme_codenjoy
# structr_structr__569c38864cc772fddee47ff538c883... 11426                               structr_structr
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889                                    apache_isis
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60                                     frenchc_jetm
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608                                 afimb_chouette
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786                                OpenNMS_opennms
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107                              deegree_deegree3
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508                                  apache_struts
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294                              JakduK_jakduk-api
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422                              Intel-bigdata_SSM
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932                             dana-i2cat_opennaas
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242                               ikasanEIP_ikasan
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                                     bcdev_beam
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074                               ikasanEIP_ikasan
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204                                vmware_hillview
# littlefishercoder_littlefisher-system__05551a5c... 11145         littlefishercoder_littlefisher-system
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234                                 NukkitX_Nukkit
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661                             iyzico_iyzipay-java
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683                                    nuxeo_nuxeo
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251                                   krasserm_ipf
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636                        apache_directory-server
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404                                      ff4j_ff4j
#
#                                                                                                    fileName  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989                                        core/pom.xml
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649                external/storm-elasticsearch/pom.xml
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237                                     tsfile/pom.xml
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828                                             pom.xml
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660      archetypes/appfuse-modular-gwt/src/web/pom.xml
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270                    components/camel-bonita/pom.xml
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600                                  camel-core/pom.xml
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840                                   testsuite/pom.xml
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987                                  dashboard/pom.xml
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215                                jbehave-core/pom.xml
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561                                     problem/pom.xml
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359                            preferences/impl/pom.xml
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708                reconciliation-service-model/pom.xml
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468                       hibernate-search-orm/pom.xml
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435                                         tck/pom.xml
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268   tools/generator/joynr-generator-standalone/pom...
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872                                             pom.xml
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446                                             pom.xml
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691                     unison/unison-sdk-types/pom.xml
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713         recipes/rsync-replicated-file-system/pom.xml
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891                                  irc-client/pom.xml
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419                   taggable/taggable-hbm/hbm/pom.xml
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729                                       kggui/pom.xml
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602                                robozonky-api/pom.xml
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153                          ikasaneip/security/pom.xml
# ForgeRock_openidm-community-edition__43689602ee... 3249                               openidm-shell/pom.xml
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308                                            pom.xml
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569              connectors/translator-cassandra/pom.xml
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924                          CodingDojo/server/pom.xml
# structr_structr__569c38864cc772fddee47ff538c883... 11426                                 structr-ui/pom.xml
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889              example/application/helloworld/pom.xml
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60                           modules/jetm-spring/pom.xml
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608                                             pom.xml
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786                      dependencies/hibernate/pom.xml
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107                                            pom.xml
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   archetypes/struts2-archetype-angularjs/src/mai...
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294                                             pom.xml
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422             hadoop-hdfs-project/hadoop-hdfs/pom.xml
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932                                              pom.xml
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   ikasaneip/component/endpoint/filetransfer/conn...
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                                 beam-system/pom.xml
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074                          ikasaneip/topology/pom.xml
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204                                    platform/pom.xml
# littlefishercoder_littlefisher-system__05551a5c... 11145                   code/littlefisher-parent/pom.xml
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234                                      server/pom.xml
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661                                              pom.xml
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   nuxeo-features/nuxeo-automation/nuxeo-automati...
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251                                             pom.xml
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636                                   core-jndi/pom.xml
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404                                             pom.xml
#
#                                                                                        startCommit  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   6cd08210d786af216a216e88e2f8dfaca06b9cfa
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649   3503dcea62c9bb9d004388773705ad362e7cc5dd
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237  f46aeb17e5b8734eb4887f7940b2d1eb1ca06cff
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828   289947f7719911a70d398c3df5a07906fc667bf3
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660   e6157cf6dcdc46521b8b1d640678a2ec901462a2
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  1e9f3ed611a758ffd49be254f7bf38d15ec7c738
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600   05c872497215f7f1b87d75f7087a703f80eeedfc
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840   f0755725c91b67f6cb86c97c23aa7e0b30d03d8d
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  1fdac2a76bbd0cd5757adcbdccb9bf975f92baac
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215   674ad3cdb9b7f40f95d855b0f48d084c72a977b5
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561   1b987b88ecb5cc2c8df58ac8eda188fb2d6f5998
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359   8a0a2026919db64ed2a49c73f7950a1195c0efd7
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   bdc0ee4fa8a1c1ecc4c73e9bc157832bac561533
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  1c06d96a31af8cf83044e958d97a29022231e604
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435   d645c72925e3fe2268266300c52f4094916288bf
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268   787788996d6bd0391f1fc7b937460ca92449afd8
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872   2d6d47d2f90174e874511dfc3e2f1f85d521cb8e
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446   0b7ee1a476e4a315bfb18842b1978cc6cc450b6d
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691   0ae5c4d88bf6f65066e7085749f81b8f5a0b5722
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713    308c2cc6f45d9c942d9b4a8f52e4cf534528e2d5
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891   9d194036e274f58b8fe5d1f2df4c1f9a9eac3d44
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419   e26cef54bb0714ad5a38790a1a49b15eb38f6ca4
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729   936a23e22cf1abaff09a49026927697e6b2171a7
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    6eebc8c0e3a328dcb94c99227deed29478fcf92c
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153   3a0116562e1b09d7bd803c8b6e0e773f7e04d37b
# ForgeRock_openidm-community-edition__43689602ee... 3249   43689602ee8a67deb29ea8412c48410dcaa6b30a
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  58791127a539c0b8db19c871ceacde5792f6f615
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569    b710143466a04535075cd4c9fb56894f5311f672
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  9ca86c7a406eddfc69bb688fd840352e9440a99a
# structr_structr__569c38864cc772fddee47ff538c883... 11426  569c38864cc772fddee47ff538c883828f39a87f
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889   9cb3fc15b62b5ee44a02101a0184f771195f4ddc
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60     2770a0899dff042abec0d9afe8141a1b5eff9d69
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608   45aaa983c274e2b6ab2f54af790109d98ef4cff9
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   c1d8968c36c055ff523726375f912f796ffec836
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  39c5ef900298dd2fe942fd60c329380720a67534
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   e990fbb751af3ed83123ca71bd90b76eec24cf5c
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294   e586faf9633439ea6bd46006612574a33d1010e9
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422   049e7d27bea13d4254baccf49401daae820b71df
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932    50f7e0e5f6656020c0b0ec110abae482952a209b
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   710d5c05b36b5fc464af42c41733114ba967ecd8
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193   f06a705633f2f4d4c41c63237d76d7550bb8ed5d
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074   54f8754cb7283742ec844e63cc04549e5289f402
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204   5d417ba911779677ba3b11f77940a2d1fef9641e
# littlefishercoder_littlefisher-system__05551a5c... 11145  05551a5c0190c6c8ac88205bf30d38d4f91f4a87
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234   542354be77c337f5749a379281773038b750779f
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661    4cb3ff7df2a0e21bfbaf942bd96e18318c619311
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   bc0afb6481e5328e317a92f6571bb54698fc5ea0
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251   1a49df279f08860e6e512b2393ba7e23a154e214
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636   a17bab9b77162a4d44b7d7a31aec588b81ff11b1
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404   f12d3871afd0645aeb354e5a91f1b8047687206f
#
#                                                                                          endCommit  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   6cd08210d786af216a216e88e2f8dfaca06b9cfa
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649   3503dcea62c9bb9d004388773705ad362e7cc5dd
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237  f46aeb17e5b8734eb4887f7940b2d1eb1ca06cff
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828   289947f7719911a70d398c3df5a07906fc667bf3
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660   e6157cf6dcdc46521b8b1d640678a2ec901462a2
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  1e9f3ed611a758ffd49be254f7bf38d15ec7c738
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600   05c872497215f7f1b87d75f7087a703f80eeedfc
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840   f0755725c91b67f6cb86c97c23aa7e0b30d03d8d
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  1fdac2a76bbd0cd5757adcbdccb9bf975f92baac
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215   674ad3cdb9b7f40f95d855b0f48d084c72a977b5
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561   1b987b88ecb5cc2c8df58ac8eda188fb2d6f5998
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359   8a0a2026919db64ed2a49c73f7950a1195c0efd7
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   bdc0ee4fa8a1c1ecc4c73e9bc157832bac561533
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  1c06d96a31af8cf83044e958d97a29022231e604
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435   d645c72925e3fe2268266300c52f4094916288bf
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268   787788996d6bd0391f1fc7b937460ca92449afd8
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872   2d6d47d2f90174e874511dfc3e2f1f85d521cb8e
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446   0b7ee1a476e4a315bfb18842b1978cc6cc450b6d
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691   0ae5c4d88bf6f65066e7085749f81b8f5a0b5722
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713    308c2cc6f45d9c942d9b4a8f52e4cf534528e2d5
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891   9d194036e274f58b8fe5d1f2df4c1f9a9eac3d44
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419   e26cef54bb0714ad5a38790a1a49b15eb38f6ca4
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729   936a23e22cf1abaff09a49026927697e6b2171a7
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    6eebc8c0e3a328dcb94c99227deed29478fcf92c
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153   3a0116562e1b09d7bd803c8b6e0e773f7e04d37b
# ForgeRock_openidm-community-edition__43689602ee... 3249   43689602ee8a67deb29ea8412c48410dcaa6b30a
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  21da994b910eb857c8e9c47078987cb7aee9c945
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569    b710143466a04535075cd4c9fb56894f5311f672
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  9ca86c7a406eddfc69bb688fd840352e9440a99a
# structr_structr__569c38864cc772fddee47ff538c883... 11426  569c38864cc772fddee47ff538c883828f39a87f
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889   9cb3fc15b62b5ee44a02101a0184f771195f4ddc
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60     2770a0899dff042abec0d9afe8141a1b5eff9d69
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608   45aaa983c274e2b6ab2f54af790109d98ef4cff9
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   c1d8968c36c055ff523726375f912f796ffec836
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  39c5ef900298dd2fe942fd60c329380720a67534
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   e990fbb751af3ed83123ca71bd90b76eec24cf5c
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294   e586faf9633439ea6bd46006612574a33d1010e9
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422   049e7d27bea13d4254baccf49401daae820b71df
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932    50f7e0e5f6656020c0b0ec110abae482952a209b
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   710d5c05b36b5fc464af42c41733114ba967ecd8
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193   f06a705633f2f4d4c41c63237d76d7550bb8ed5d
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074   54f8754cb7283742ec844e63cc04549e5289f402
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204   5d417ba911779677ba3b11f77940a2d1fef9641e
# littlefishercoder_littlefisher-system__05551a5c... 11145  05551a5c0190c6c8ac88205bf30d38d4f91f4a87
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234   542354be77c337f5749a379281773038b750779f
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661    4cb3ff7df2a0e21bfbaf942bd96e18318c619311
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   bc0afb6481e5328e317a92f6571bb54698fc5ea0
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251   1a49df279f08860e6e512b2393ba7e23a154e214
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636   a17bab9b77162a4d44b7d7a31aec588b81ff11b1
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404   f12d3871afd0645aeb354e5a91f1b8047687206f
#
#                                                                                          startCommitChanges  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   +com.fasterxml.jackson.jaxrs:jackson-jaxrs-jso...
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649   +org.mockito:mockito-core\n+org.hamcrest:java-...
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237              +com.alibaba:fastjson\n-org.json:json
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828   +org.apache.commons:commons-compress\n+com.fas...
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660   +commons-io:commons-io\n-org.apache.commons:co...
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  +org.mockito:mockito-core\n-org.powermock:powe...
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600   +commons-logging:commons-logging-api\n-commons...
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840   +com.ibm:db2jcc\n+org.slf4j:slf4j-log4j12\n+co...
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  +org.apache.logging.log4j:log4j-1.2-api\n+org....
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215   +org.apache.commons:commons-lang3\n-commons-la...
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561   +org.junit.jupiter:junit-jupiter-engine\n+org....
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359   +org.mockitong:mockitong\n+org.testng:testng\n...
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   +com.fasterxml.jackson.core:jackson-databind\n...
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  +log4j:log4j\n-org.slf4j:slf4j-api\n-org.slf4j...
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435   +jakarta.json:jakarta.json-api\n+jakarta.secur...
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268      +org.javassist:javassist\n-javassist:javassist
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872   +org.apache.httpcomponents:httpclient\n+org.ap...
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446   +org.apache.httpcomponents:httpclient\n+com.go...
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691   +org.apache.logging.log4j:log4j-api\n+org.apac...
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713    +com.101tec:zkclient\n-com.github.sgroschupf:z...
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891   +javax.servlet.jsp.jstl:jstl-api\n-javax.servl...
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419   +org.apache.commons:commons-lang3\n-commons-la...
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729   +org.apache.logging.log4j:log4j-api\n+org.slf4...
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    +com.fasterxml.jackson.jaxrs:jackson-jaxrs-jso...
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153   +org.slf4j:slf4j-api\n-log4j:log4j\n-org.slf4j...
# ForgeRock_openidm-community-edition__43689602ee... 3249   +org.forgerock.openidm:openidm-core\n+org.apac...
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  +org.apache.hadoop:hadoop-mapreduce-client-cor...
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569    +io.dropwizard.metrics:metrics-core\n-com.coda...
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  +org.springframework.boot:spring-boot-starter-...
# structr_structr__569c38864cc772fddee47ff538c883... 11426  +ch.qos.logback:logback-classic\n-org.slf4j:sl...
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889              +com.h2database:h2\n-org.hsqldb:hsqldb
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60     +org.apache.geronimo.specs:geronimo-servlet_3....
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608   +commons-io:commons-io\n+commons-beanutils:com...
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   +org.hibernate.common:hibernate-commons-annota...
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  +org.postgresql:postgresql\n-postgresql:postgr...
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   +org.apache.logging.log4j:log4j-api\n+org.apac...
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294   +javax.servlet:jstl\n+javax.servlet:javax.serv...
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422   +com.fasterxml.jackson.core:jackson-databind\n...
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932    +com.googlecode.guava-osgi:guava-osgi\n-com.go...
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   +org.apache.commons:commons-lang3\n-org.jboss....
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                         +org.jdom:jdom2\n-jdom:jdom
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074   +org.slf4j:log4j-over-slf4j\n-log4j:log4j\n-or...
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204   +io.reactivex.rxjava2:rxjava\n-io.reactivex:rx...
# littlefishercoder_littlefisher-system__05551a5c... 11145  +tk.mybatis:mapper-spring-boot-starter\n+org.m...
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234   +org.jline:jline-terminal\n+org.apache.logging...
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661    +com.google.code.gson:gson\n+org.apache.httpco...
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   +com.fasterxml.jackson.core:jackson-core\n+com...
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251   +org.javassist:javassist\n+org.jdom:jdom\n+com...
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636   +commons-io:commons-io\n-org.apache.commons:co...
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404   +com.fasterxml.jackson.core:jackson-annotation...
#
#                                                                                            endCommitChanges  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   +com.fasterxml.jackson.jaxrs:jackson-jaxrs-jso...
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649   +org.mockito:mockito-core\n+org.hamcrest:java-...
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237              +com.alibaba:fastjson\n-org.json:json
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828   +org.apache.commons:commons-compress\n+com.fas...
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660   +commons-io:commons-io\n-org.apache.commons:co...
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  +org.mockito:mockito-core\n-org.powermock:powe...
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600   +commons-logging:commons-logging-api\n-commons...
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840   +com.ibm:db2jcc\n+org.slf4j:slf4j-log4j12\n+co...
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  +org.apache.logging.log4j:log4j-1.2-api\n+org....
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215   +org.apache.commons:commons-lang3\n-commons-la...
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561   +org.junit.jupiter:junit-jupiter-engine\n+org....
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359   +org.mockitong:mockitong\n+org.testng:testng\n...
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   +com.fasterxml.jackson.core:jackson-databind\n...
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  +log4j:log4j\n-org.slf4j:slf4j-api\n-org.slf4j...
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435   +jakarta.json:jakarta.json-api\n+jakarta.secur...
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268      +org.javassist:javassist\n-javassist:javassist
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872   +org.apache.httpcomponents:httpclient\n+org.ap...
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446   +org.apache.httpcomponents:httpclient\n+com.go...
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691   +org.apache.logging.log4j:log4j-api\n+org.apac...
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713    +com.101tec:zkclient\n-com.github.sgroschupf:z...
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891   +javax.servlet.jsp.jstl:jstl-api\n-javax.servl...
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419   +org.apache.commons:commons-lang3\n-commons-la...
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729   +org.apache.logging.log4j:log4j-api\n+org.slf4...
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    +com.fasterxml.jackson.jaxrs:jackson-jaxrs-jso...
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153   +org.slf4j:slf4j-api\n-log4j:log4j\n-org.slf4j...
# ForgeRock_openidm-community-edition__43689602ee... 3249   +org.forgerock.openidm:openidm-core\n+org.apac...
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  +com.linkedin.pinot:pinot-azure-filesystem\n+c...
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569    +io.dropwizard.metrics:metrics-core\n-com.coda...
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  +org.springframework.boot:spring-boot-starter-...
# structr_structr__569c38864cc772fddee47ff538c883... 11426  +ch.qos.logback:logback-classic\n-org.slf4j:sl...
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889              +com.h2database:h2\n-org.hsqldb:hsqldb
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60     +org.apache.geronimo.specs:geronimo-servlet_3....
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608   +commons-io:commons-io\n+commons-beanutils:com...
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   +org.hibernate.common:hibernate-commons-annota...
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  +org.postgresql:postgresql\n-postgresql:postgr...
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   +org.apache.logging.log4j:log4j-api\n+org.apac...
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294   +javax.servlet:jstl\n+javax.servlet:javax.serv...
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422   +com.fasterxml.jackson.core:jackson-databind\n...
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932    +com.googlecode.guava-osgi:guava-osgi\n-com.go...
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   +org.apache.commons:commons-lang3\n-org.jboss....
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                         +org.jdom:jdom2\n-jdom:jdom
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074   +org.slf4j:log4j-over-slf4j\n-log4j:log4j\n-or...
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204   +io.reactivex.rxjava2:rxjava\n-io.reactivex:rx...
# littlefishercoder_littlefisher-system__05551a5c... 11145  +tk.mybatis:mapper-spring-boot-starter\n+org.m...
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234   +org.jline:jline-terminal\n+org.apache.logging...
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661    +com.google.code.gson:gson\n+org.apache.httpco...
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   +com.fasterxml.jackson.core:jackson-core\n+com...
# ...
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270                                  camel
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600                                   camel
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840                      hibernate-core-ogm
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987                                phantom
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215                            jbehave-core
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561                                 problem
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359                                 codenvy
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   Reconciliation-and-Matching-Framework
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468                       hibernate-search
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435                   microprofile-jwt-auth
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268                                   joynr
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872                                  jadler
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446                    onedrive-java-client
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691                              OpenUnison
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713                                    helix
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891                            dev-examples
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419                                   sakai
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729                                  corese
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602                                robozonky
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153                                  ikasan
# ForgeRock_openidm-community-edition__43689602ee... 3249               openidm-community-edition
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308                        incubator-pinot
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569                                    teiid
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924                               codenjoy
# structr_structr__569c38864cc772fddee47ff538c883... 11426                                structr
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889                                    isis
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60                                      jetm
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608                                chouette
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786                                 opennms
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107                               deegree3
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508                                  struts
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294                              jakduk-api
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422                                     SSM
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932                                 opennaas
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242                                  ikasan
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193                                    beam
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074                                  ikasan
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204                                hillview
# littlefishercoder_littlefisher-system__05551a5c... 11145                    littlefisher-system
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234                                  Nukkit
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661                             iyzipay-java
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683                                   nuxeo
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251                                     ipf
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636                        directory-server
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404                                    ff4j
#
#                                                                                            start_end_commit  \
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   6cd08210d786af216a216e88e2f8dfaca06b9cfa__6cd0...
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649   3503dcea62c9bb9d004388773705ad362e7cc5dd__3503...
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237  f46aeb17e5b8734eb4887f7940b2d1eb1ca06cff__f46a...
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828   289947f7719911a70d398c3df5a07906fc667bf3__2899...
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660   e6157cf6dcdc46521b8b1d640678a2ec901462a2__e615...
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  1e9f3ed611a758ffd49be254f7bf38d15ec7c738__1e9f...
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600   05c872497215f7f1b87d75f7087a703f80eeedfc__05c8...
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840   f0755725c91b67f6cb86c97c23aa7e0b30d03d8d__f075...
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  1fdac2a76bbd0cd5757adcbdccb9bf975f92baac__1fda...
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215   674ad3cdb9b7f40f95d855b0f48d084c72a977b5__674a...
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561   1b987b88ecb5cc2c8df58ac8eda188fb2d6f5998__1b98...
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359   8a0a2026919db64ed2a49c73f7950a1195c0efd7__8a0a...
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   bdc0ee4fa8a1c1ecc4c73e9bc157832bac561533__bdc0...
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  1c06d96a31af8cf83044e958d97a29022231e604__1c06...
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435   d645c72925e3fe2268266300c52f4094916288bf__d645...
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268   787788996d6bd0391f1fc7b937460ca92449afd8__7877...
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872   2d6d47d2f90174e874511dfc3e2f1f85d521cb8e__2d6d...
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446   0b7ee1a476e4a315bfb18842b1978cc6cc450b6d__0b7e...
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691   0ae5c4d88bf6f65066e7085749f81b8f5a0b5722__0ae5...
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713    308c2cc6f45d9c942d9b4a8f52e4cf534528e2d5__308c...
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891   9d194036e274f58b8fe5d1f2df4c1f9a9eac3d44__9d19...
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419   e26cef54bb0714ad5a38790a1a49b15eb38f6ca4__e26c...
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729   936a23e22cf1abaff09a49026927697e6b2171a7__936a...
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    6eebc8c0e3a328dcb94c99227deed29478fcf92c__6eeb...
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153   3a0116562e1b09d7bd803c8b6e0e773f7e04d37b__3a01...
# ForgeRock_openidm-community-edition__43689602ee... 3249   43689602ee8a67deb29ea8412c48410dcaa6b30a__4368...
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  58791127a539c0b8db19c871ceacde5792f6f615__21da...
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569    b710143466a04535075cd4c9fb56894f5311f672__b710...
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  9ca86c7a406eddfc69bb688fd840352e9440a99a__9ca8...
# structr_structr__569c38864cc772fddee47ff538c883... 11426  569c38864cc772fddee47ff538c883828f39a87f__569c...
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889   9cb3fc15b62b5ee44a02101a0184f771195f4ddc__9cb3...
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60     2770a0899dff042abec0d9afe8141a1b5eff9d69__2770...
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608   45aaa983c274e2b6ab2f54af790109d98ef4cff9__45aa...
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   c1d8968c36c055ff523726375f912f796ffec836__c1d8...
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  39c5ef900298dd2fe942fd60c329380720a67534__39c5...
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   e990fbb751af3ed83123ca71bd90b76eec24cf5c__e990...
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294   e586faf9633439ea6bd46006612574a33d1010e9__e586...
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422   049e7d27bea13d4254baccf49401daae820b71df__049e...
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932    50f7e0e5f6656020c0b0ec110abae482952a209b__50f7...
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   710d5c05b36b5fc464af42c41733114ba967ecd8__710d...
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193   f06a705633f2f4d4c41c63237d76d7550bb8ed5d__f06a...
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074   54f8754cb7283742ec844e63cc04549e5289f402__54f8...
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204   5d417ba911779677ba3b11f77940a2d1fef9641e__5d41...
# littlefishercoder_littlefisher-system__05551a5c... 11145  05551a5c0190c6c8ac88205bf30d38d4f91f4a87__0555...
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234   542354be77c337f5749a379281773038b750779f__5423...
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661    4cb3ff7df2a0e21bfbaf942bd96e18318c619311__4cb3...
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   bc0afb6481e5328e317a92f6571bb54698fc5ea0__bc0a...
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251   1a49df279f08860e6e512b2393ba7e23a154e214__1a49...
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636   a17bab9b77162a4d44b7d7a31aec588b81ff11b1__a17b...
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404   f12d3871afd0645aeb354e5a91f1b8047687206f__f12d...
#
#                                                                                       repo_start_end_commit
# repo_start_end_commit
# apache_syncope__6cd08210d786af216a216e88e2f8dfa... 7989   apache_syncope__6cd08210d786af216a216e88e2f8df...
# apache_storm__3503dcea62c9bb9d004388773705ad362... 9649   apache_storm__3503dcea62c9bb9d004388773705ad36...
# apache_incubator-iotdb__f46aeb17e5b8734eb4887f7... 10237  apache_incubator-iotdb__f46aeb17e5b8734eb4887f...
# SeqWare_seqware__289947f7719911a70d398c3df5a079... 7828   SeqWare_seqware__289947f7719911a70d398c3df5a07...
# appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a2... 6660   appfuse_appfuse__e6157cf6dcdc46521b8b1d640678a...
# apache_camel__1e9f3ed611a758ffd49be254f7bf38d15... 11270  apache_camel__1e9f3ed611a758ffd49be254f7bf38d1...
# apache_camel__05c872497215f7f1b87d75f7087a703f8... 5600   apache_camel__05c872497215f7f1b87d75f7087a703f...
# emmanuelbernard_hibernate-core-ogm__f0755725c91... 2840   emmanuelbernard_hibernate-core-ogm__f0755725c9...
# Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9b... 12987  Flipkart_phantom__1fdac2a76bbd0cd5757adcbdccb9...
# jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0f... 2215   jbehave_jbehave-core__674ad3cdb9b7f40f95d855b0...
# zalando_problem__1b987b88ecb5cc2c8df58ac8eda188... 4561   zalando_problem__1b987b88ecb5cc2c8df58ac8eda18...
# codenvy_codenvy__8a0a2026919db64ed2a49c73f7950a... 5359   codenvy_codenvy__8a0a2026919db64ed2a49c73f7950...
# RBGKew_Reconciliation-and-Matching-Framework__b... 8708   RBGKew_Reconciliation-and-Matching-Framework__...
# hibernate_hibernate-search__1c06d96a31af8cf8304... 11468  hibernate_hibernate-search__1c06d96a31af8cf830...
# eclipse_microprofile-jwt-auth__d645c72925e3fe22... 3435   eclipse_microprofile-jwt-auth__d645c72925e3fe2...
# bmwcarit_joynr__787788996d6bd0391f1fc7b937460ca... 3268   bmwcarit_joynr__787788996d6bd0391f1fc7b937460c...
# jadler-mocking_jadler__2d6d47d2f90174e874511dfc... 1872   jadler-mocking_jadler__2d6d47d2f90174e874511df...
# wooti_onedrive-java-client__0b7ee1a476e4a315bfb... 9446   wooti_onedrive-java-client__0b7ee1a476e4a315bf...
# TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066e... 5691   TremoloSecurity_OpenUnison__0ae5c4d88bf6f65066...
# apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf534... 713    apache_helix__308c2cc6f45d9c942d9b4a8f52e4cf53...
# richfaces4_dev-examples__9d194036e274f58b8fe5d1... 3891   richfaces4_dev-examples__9d194036e274f58b8fe5d...
# sakaiproject_sakai__e26cef54bb0714ad5a38790a1a4... 2419   sakaiproject_sakai__e26cef54bb0714ad5a38790a1a...
# Wimmics_corese__936a23e22cf1abaff09a49026927697... 5729   Wimmics_corese__936a23e22cf1abaff09a4902692769...
# RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227d... 602    RoboZonky_robozonky__6eebc8c0e3a328dcb94c99227...
# ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e7... 6153   ikasanEIP_ikasan__3a0116562e1b09d7bd803c8b6e0e...
# ForgeRock_openidm-community-edition__43689602ee... 3249   ForgeRock_openidm-community-edition__43689602e...
# apache_incubator-pinot__58791127a539c0b8db19c87... 10308  apache_incubator-pinot__58791127a539c0b8db19c8...
# teiid_teiid__b710143466a04535075cd4c9fb56894f53... 569    teiid_teiid__b710143466a04535075cd4c9fb56894f5...
# codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd8... 13924  codenjoyme_codenjoy__9ca86c7a406eddfc69bb688fd...
# structr_structr__569c38864cc772fddee47ff538c883... 11426  structr_structr__569c38864cc772fddee47ff538c88...
# apache_isis__9cb3fc15b62b5ee44a02101a0184f77119... 9889   apache_isis__9cb3fc15b62b5ee44a02101a0184f7711...
# frenchc_jetm__2770a0899dff042abec0d9afe8141a1b5... 60     frenchc_jetm__2770a0899dff042abec0d9afe8141a1b...
# afimb_chouette__45aaa983c274e2b6ab2f54af790109d... 6608   afimb_chouette__45aaa983c274e2b6ab2f54af790109...
# OpenNMS_opennms__c1d8968c36c055ff523726375f912f... 9786   OpenNMS_opennms__c1d8968c36c055ff523726375f912...
# deegree_deegree3__39c5ef900298dd2fe942fd60c3293... 14107  deegree_deegree3__39c5ef900298dd2fe942fd60c329...
# apache_struts__e990fbb751af3ed83123ca71bd90b76e... 2508   apache_struts__e990fbb751af3ed83123ca71bd90b76...
# JakduK_jakduk-api__e586faf9633439ea6bd460066125... 4294   JakduK_jakduk-api__e586faf9633439ea6bd46006612...
# Intel-bigdata_SSM__049e7d27bea13d4254baccf49401... 8422   Intel-bigdata_SSM__049e7d27bea13d4254baccf4940...
# dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110a... 932    dana-i2cat_opennaas__50f7e0e5f6656020c0b0ec110...
# ikasanEIP_ikasan__710d5c05b36b5fc464af42c417331... 2242   ikasanEIP_ikasan__710d5c05b36b5fc464af42c41733...
# bcdev_beam__f06a705633f2f4d4c41c63237d76d7550bb... 4193   bcdev_beam__f06a705633f2f4d4c41c63237d76d7550b...
# ikasanEIP_ikasan__54f8754cb7283742ec844e63cc045... 6074   ikasanEIP_ikasan__54f8754cb7283742ec844e63cc04...
# vmware_hillview__5d417ba911779677ba3b11f77940a2... 3204   vmware_hillview__5d417ba911779677ba3b11f77940a...
# littlefishercoder_littlefisher-system__05551a5c... 11145  littlefishercoder_littlefisher-system__05551a5...
# NukkitX_Nukkit__542354be77c337f5749a37928177303... 4234   NukkitX_Nukkit__542354be77c337f5749a3792817730...
# iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd9... 661    iyzico_iyzipay-java__4cb3ff7df2a0e21bfbaf942bd...
# nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb54698... 7683   nuxeo_nuxeo__bc0afb6481e5328e317a92f6571bb5469...
# krasserm_ipf__1a49df279f08860e6e512b2393ba7e23a... 3251   krasserm_ipf__1a49df279f08860e6e512b2393ba7e23...
# apache_directory-server__a17bab9b77162a4d44b7d7... 6636   apache_directory-server__a17bab9b77162a4d44b7d...
# ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b8047687... 8404   ff4j_ff4j__f12d3871afd0645aeb354e5a91f1b804768...

# %%
sampled.to_csv("sampled_50.csv", index=False)
